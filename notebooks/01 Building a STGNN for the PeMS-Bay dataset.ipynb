# %% [markdown]
# <center>
#     <h1>Verbal Explanation of Spatial Temporal GNNs for Traffic Forecasting</h1>
#     <h2>Building a STGNN for the PeMS-Bay dataset</h2>
#     <h3>Riccardo Spolaor</h3>
#     <h4>riccardo.spolaor@studio.unibo.it - rspolaor@tudelft.nl</h4>
# </center>
#
# ---
#
# In this notebook the *Spatial Temporal Graph Neural Network (STGNN)* proposed in the paper *Traffic Flow Prediction via Spatial Temporal Graph Neural Network* <a name="cite_paper"></a>[<sup>[1]</sup>](#note_paper) is built, trained and evaluated on the *PeMS-Bay* dataset.
#
# Firstly, the data is pre-processed for the task and its distribution is analysed. Next, the model is built and it is trained on the processed data. Finally the model is tested on a subset of the data not used in the training procedure.
#
# For more detailed informations about the used functions, look into the corresponding docstrings inside the python files, inside the `src` folder.
#
# The dataset used in the work is the one presented in the experiment providing the original benchmark, which code is available at the following link: https://github.com/liyaguang/DCRNN.
#
# The architecture of the model proposed for the task takes inspiration from the one provided at the following link: https://github.com/LMissher/STGNN. although it presents certain architectural differences.
#
# ---
# <small>
#
# <a name="note_paper"></a>[1] Xiaoyang Wang et al. “Traffic Flow Prediction via Spatial Temporal Graph Neural Network”. In:
# *Proceedings of The Web Conference 2020*. WWW ’20. Taipei, Taiwan: Association for Computing
# Machinery, 2020, pp. 1082–1092. ISBN: 9781450370233. DOI: 10.1145/3366423.3380186. URL:
# https://doi.org/10.1145/3366423.3380186.
#
# </small>

# %%
import sys
import os

# Set the main path in the root folder of the project.
sys.path.append(os.path.join('..'))

# %%
# Settings for autoreloading.
# %load_ext autoreload
# %autoreload 2

# %%
from src.utils.seed import set_random_seed

# Set the random seed for deterministic operations.
SEED = 42
set_random_seed(SEED)

# %%
import torch

# Set the device for training and querying the model.
DEVICE = 'cuda' if torch.cuda.is_available() else 'cpu'
print(f'The selected device is: "{DEVICE}"')
# Out:
# The selected device is: "cuda"

# %% [markdown]
# DEPENDENCY Pytables

# %% [markdown]
# # 1 Data Preparation
# The ***PeMS-Bay*** traffic dataset is collected by *California Transportation Agencies (CalTrans) Performance Measurement System (PeMS)*. $325$ sensors are selected in the Bay Area and data is collected ranging from Jan $1^{st}$ $2017$ to May $31^{th}$ $2017$ for the experiment.
#
# The traffic speed readings are aggregated in $5$ minutes windows.
#
# The total number of observed traffic data points is $16,937,179$.

# %%
# Set the base data directory.
BASE_DATA_DIR = os.path.join('..', 'data', 'pems-bay')

# %% [markdown]
# ## 1.1 Dataset Extraction and Preparation
# Firstly, the dataset illustrating the speed of the nodes at different timestamps is extracted along with the adjacency matrix containing the spatial correlation among the different nodes.
#
# Next, the time information is encoded and integrated in the dataset containing the node values in order to guarantee its format is suitable for the model operations.
#
# ---
# *Note: In order to obtain comparable results for the evaluation task, the speed information and the adjacency matrix computed distances consider the original metrics of the experiment (miles/hour and miles respectively).*

# %%
# Set the base data directory.
BASE_DATA_DIR = os.path.join('..', 'data', 'pems-bay')

# %% [markdown]
# The obtained data has the following structure:
# * The node values dataset is in the form $\mathbb{R}^{T \times N \times F}$.
# * The adjacency matrix is in the form $\mathbb{R}^{N \times N}$.
#
# Where $T$ is the number of timestamps, $N$ is the number of nodes and $F$ the number of features.
#
# In this experiment the feature used for the *PeMS-Bay* dataset are in the order:
# * Speed in miles/hour observed by the node at a certain timestamp.
# * The encoded hour of the day of the observed speed.
# * The encoded minute of the our of the observed speed.

# %%
from src.data.data_extraction import get_node_values_dataframe

# Get the dataframe containing the node values at different timestamps.
node_values_df = get_node_values_dataframe(
    os.path.join(BASE_DATA_DIR, 'pems-bay.h5'), turn_in_kmph=False)

# %%
from src.data.data_processing import get_node_values_numpy_matrix

# Set the methods in which the time is aggregated and encoded
TIME_AGGREGATIONS = [ 'time_of_day', 'day_of_week' ]

# Get the numpy matrix encoding the speed of the nodes and time
# information about the hour of the day and the minute of the hour.
node_values = get_node_values_numpy_matrix(
    node_values_df, time_aggregations=TIME_AGGREGATIONS)

# %%
print('Shape of the node value matrix:', node_values.shape)
# Out:
# Shape of the node value matrix: (52116, 325, 9)

# %% [markdown]
# Finally, the data is divided into train, validation and test datasets which will be structured in other sections in order to meet the problem requisites.
#
# The adjacency matrix is built by exploiting the pairwise road network distances between sensors through a thresholded Gaussian kernel.
#
# $$
# W_{ij} = \begin{cases}
# \text{exp} \left ( - \frac{\text{dist}(v_i - v_j)^2}{\sigma^2} \right ) & \text{if} \ \leq k \\
# 0 & \text{otherwise}\\
# \end{cases}
# $$
#
# Where $W_{ij}$ represents the edge weight between sensor $v_i$ and sensor $v_j$, $\text{dist}(v_i - v_j)$ denotes the road network distance from sensor $v_i$ to sensor $v_j$ . $\sigma$ is the standard deviation of distances and $k$ ($0.1$ in the original experiment) is the threshold.

# %%
from src.data.data_extraction import get_adjacency_matrix

# Get the adjacency matrix
adj_matrix_structure = get_adjacency_matrix(
    os.path.join(BASE_DATA_DIR, 'adj_mx_pems_bay.pkl'))

# Get the header of the adjacency matrix and the matrix itself.
header, _, adj_matrix = adj_matrix_structure

# %%
# Assert that the adjacency matrix header nodes order corresponds to
# the order of the columns node header of the node values dataframe.
assert all(header == node_values_df.columns.values), \
'The columns of the node values dataframe are not ordered in the ' +\
'same fashion as the adjacency matrix header.'

# %%
print('Shape of the adjacency matrix:', adj_matrix.shape)
# Out:
# Shape of the adjacency matrix: (325, 325)

# %% [markdown]
# The dataset is split in *train*, *validation* and *test*, following the ratios $0.7$ $0.1$ and $0.2$ respectively.

# %%
from src.data.dataset_builder import train_test_val_split

# Split the dataset in train, validation and test.
train_dataset, val_dataset, test_dataset = train_test_val_split(
    node_values, test_size=.2, val_size=.1)

# %% [markdown]
# ## 1.2 Data Pre-Processing
# In this section the data is preprocessed in order to better fit the model structure.
#
# The data standardization procedure is explained, and the datasets are divided in input data and ground truth data for the self-supervised regression task through the use of a sliding window.

# %% [markdown]
# First of all, a `scaler` is created to apply *Standard Scaling* to the data. This procedure leads the model to better performances.
#
# Given an instance $x$ and considering that a feature of $x$ is denoted as $x_f$, its processed version $x'_f$ is obtained as:
# $$ \forall \ f \ \text{of} \ x, \ x'_f = \frac{x_f - \mu_f}{\sigma_f}$$
# Where $\mu_f$ is the mean of the feature $f$ and $\sigma_f$ its standard deviation.
#
# The mean and standard deviation are estimated on the data that is used for training the model.

# %%
from src.data.data_processing import Scaler

# Fit the standard scaler with the train_dataset values.
scaler = Scaler(torch.tensor(train_dataset, dtype=torch.float32),
                has_day_of_week=True)

# %%
import pickle

with open(os.path.join(BASE_DATA_DIR, 'processed', 'scaler.pkl'), 'wb') as f:
    pickle.dump(scaler, f)

# %%
print('The scaler mean values:', scaler.mean.cpu().numpy())
print('The scaler standard deviation values:', scaler.std.cpu().numpy())
# Out:
# The scaler mean values: [62.712536    0.49789244  0.          0.          0.          0.
#   0.          0.          0.        ]
# The scaler standard deviation values: [9.482161  0.2890016 1.        1.        1.        1.        1.
#  1.        1.       ]

# %% [markdown]
# The statistics of the original training data are observed.
#
# We can see that in the original data no feature has mean in $0$ and standard deviation in $1$ and it is hence no normalized. By observing the distribution of the features, it is clear how the `speed` feature presents a left skewed normal distribution. This is expected, as speed in highways tend to be closer to high values than to lower speeds.
#
# The features encoding time present a uniform distribution. This is also an expected behavior as the train dataset covers a large period of time and present a timestamp every $5$ minutes without skipping any specific day or hour of the day.

# %%
from src.data.data_analysis import get_node_values_statistics_dataframe

statistics_df = get_node_values_statistics_dataframe(
    train_dataset, feature_names=['speed', 'time of the day',
                                  'day of the week'],
    has_day_of_the_week=True)

# %%
statistics_df.describe()
# Out:
#               speed  time of the day  day of the week
# count  1.219465e+07     1.219465e+07     1.219465e+07
# mean   6.271254e+01     4.978925e-01     2.976014e+00
# std    9.482160e+00     2.890016e-01     2.010357e+00
# min    0.000000e+00     0.000000e+00     0.000000e+00
# 25%    6.220000e+01     2.466991e-01     1.000000e+00
# 50%    6.530000e+01     4.968728e-01     3.000000e+00
# 75%    6.750000e+01     7.470466e-01     5.000000e+00
# max    8.510000e+01     9.972203e-01     6.000000e+00

# %%
from src.data.data_analysis import plot_features_distribution

plot_features_distribution(
    statistics_df, bins=[200, 24 + 60 // 5, 7], 
    x_labels=['Speed (miles/h)', 'Encoded time of the day',
              'Encoded day of the week'],
    title='Distribution of the training features.')

# %%
# Scale the train dataset through standard scaling.
scaled_train_dataset = scaler.scale(
    torch.tensor(train_dataset, dtype=torch.float32))

# %% [markdown]
# The statistics of the scaled training data are observed.
#
# The distributions are the same as the ones present in the un-scaled dataset, although we can observe that every variable has mean in $0$ and standard deviation in $1$ and it is thus normalized.

# %%
from src.data.data_analysis import get_node_values_statistics_dataframe

statistics_df = get_node_values_statistics_dataframe(
    scaled_train_dataset, feature_names=['speed', 'time of the day',
                                         'day of the week'],
    has_day_of_the_week=True)

# %%
statistics_df.describe()
# Out:
#               speed  time of the day  day of the week
# count  1.219465e+07     1.219465e+07     1.219465e+07
# mean   2.259559e-07     1.248401e-07     2.976014e+00
# std    1.000000e+00     1.000000e+00     2.010357e+00
# min   -6.613739e+00    -1.722802e+00     0.000000e+00
# 25%   -5.405257e-02    -8.691763e-01     1.000000e+00
# 50%    2.728774e-01    -3.527998e-03     3.000000e+00
# 75%    5.048917e-01     8.621203e-01     5.000000e+00
# max    2.361009e+00     1.727768e+00     6.000000e+00

# %%
from src.data.data_analysis import plot_features_distribution

plot_features_distribution(
    statistics_df, bins=[200, 24 + 60 // 5, 7], 
    x_labels=['Scaled speed (miles/h)', 'Scaled encoded time of the day',
              'Scaled encoded day of the week'],
    title='Distribution of the training features after scaling.')

# %% [markdown]
# Next, a sliding window of size $(T_{in} + T_{out})$ is applied to each dataset, in order to obtain a self-supervised version of it, where in each window:
# * The first $T_{in}$ elements are part of the input variables.
# * The last $T_{out}$ elements are part of the ground truth.
#
# For the experiment, both $T_{in}$ and $T_{out}$ are set to $12$

# %%
# Set the number of input and output timesteps.
N_IN_TIMESTEPS = 12
N_OUT_TIMESTEPS = 12

# %%
from src.data.data_processing import get_dataset_by_sliding_window

# Get self-supervised training validation and test sets.
x_train, y_train = get_dataset_by_sliding_window(
    train_dataset, x_stepsize=N_IN_TIMESTEPS, y_stepsize=N_OUT_TIMESTEPS)
x_val, y_val = get_dataset_by_sliding_window(
    val_dataset, x_stepsize=N_IN_TIMESTEPS, y_stepsize=N_OUT_TIMESTEPS)
x_test, y_test = get_dataset_by_sliding_window(
    test_dataset, x_stepsize=N_IN_TIMESTEPS, y_stepsize=N_OUT_TIMESTEPS)

# %%
print('Train dataset shapes:', x_train.shape, y_train.shape)
print('Validation dataset shapes:', x_val.shape, y_val.shape)
print('Test dataset shapes:', x_test.shape, y_test.shape)
# Out:
# Train dataset shapes: (1563, 12, 325, 9) (1563, 12, 325, 9)
# Validation dataset shapes: (173, 12, 325, 9) (173, 12, 325, 9)
# Test dataset shapes: (434, 12, 325, 9) (434, 12, 325, 9)

# %% [markdown]
# The time encoding features are removed from the ground truth data, as we are interested in predicting solely the speed value.
#
# Thus the resulting datasets have the shape:
# * $x \in \mathbb{R}^{T \times N \times (1 + F)}$
# * $y \in \mathbb{R}^{T \times N \times 1}$
#
# Where $x$ is the input data and $y$ the ground truth of the train, validation or test dataset. $T$ corresponds to the number of timesteps, $N$ to the number of nodes and $F$ indicates the amount of features that represent an encoding of the time steps.

# %%
# Remove the time encoding features from the ground truth.
y_train = y_train[..., :1]
y_val = y_val[..., :1]
y_test = y_test[..., :1]

# %%
from numpy import save

# Save the processed datasets.
save(os.path.join(BASE_DATA_DIR, 'processed', 'x_train.npy'), x_train)
save(os.path.join(BASE_DATA_DIR, 'processed', 'y_train.npy'), y_train)
save(os.path.join(BASE_DATA_DIR, 'processed', 'x_val.npy'), x_val)
save(os.path.join(BASE_DATA_DIR, 'processed', 'y_val.npy'), y_val)
save(os.path.join(BASE_DATA_DIR, 'processed', 'x_test.npy'), x_test)
save(os.path.join(BASE_DATA_DIR, 'processed', 'y_test.npy'), y_test)

# %%
print('Adjusted train dataset shapes:', x_train.shape, y_train.shape)
print('Adjusted validation dataset shapes:', x_val.shape, y_val.shape)
print('Adjusted test dataset shapes:', x_test.shape, y_test.shape)
# Out:
# Adjusted train dataset shapes: (1563, 12, 325, 9) (1563, 12, 325, 1)
# Adjusted validation dataset shapes: (173, 12, 325, 9) (173, 12, 325, 1)
# Adjusted test dataset shapes: (434, 12, 325, 9) (434, 12, 325, 1)

# %% [markdown]
# # 2 Model definition and training procedure
# In this section the model is defined and the training procedure is performed.

# %% [markdown]
# ## 2.1 Model definition
# The *Spatial Temporal Graph Neural Network* model is created.
#
# Its aim is to predict future traffic speed for each node of the graph according to historical speed information.
# In particular, it predicts the next $T_{out}$ consecutive time representations of the graph with respect to the previous consecutive $T_{in}$ historical representations of the graph.
#
# The model architecture consists in:
# * An encoder that extracts hidden features from the input sequence of graphs.
# * A series of *Spatial Graph Neural Network (S-GNN)* blocks, that extract information by modeling the spatial structure of each input instance of the graph with respect to the feature information. Furthermore, the adjacency matrix is used to help in the task.
# * A series of *Gated Recurrent Units (GRU)* blocks to extract information about the temporal realtion among successive time steps of the input graphs. The resulting output of a *GRU* block is passed as the hidden input state of the next *GRU* block and processed along with the next time step of the graph. The output of each *GRU* block is processed through a *S-GNN* block before being given to the next *GRU* block.
# * A *Transformer* block performing *Multi-Head Attention* in order to compute the global temporal relation among each time step. The outputs of the *GRU* are stacked together and concatenated with their *positional encoding*.
# * A *multi layer* regression head to infer the speed of the output $T_{out}$ sequences.
# <center>
#
# ![](../images/stgnn.png)
#
# </center>

# %%
from src.spatial_temporal_gnn.model import SpatialTemporalGNN

model = SpatialTemporalGNN(9, 1, N_IN_TIMESTEPS, N_OUT_TIMESTEPS, adj_matrix,
                           DEVICE, 64)

# %%
from torchinfo import summary

print(summary(model, input_size=(64, *x_train.shape[1:])))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# SpatialTemporalGNN                       [64, 12, 325, 1]          --
# ├─Linear: 1-1                            [64, 12, 325, 64]         576
# ├─ModuleList: 1-34                       --                        (recursive)
# │    └─S_GNN: 2-1                        [64, 325, 64]             --
# │    │    └─Sequential: 3-1              [64, 325, 32]             6,144
# │    │    └─Linear: 3-2                  [64, 325, 64]             4,096
# ├─ModuleList: 1-36                       --                        (recursive)
# │    └─GRU: 2-2                          [64, 325, 64]             --
# │    │    └─Linear: 3-3                  [64, 325, 64]             4,096
# │    │    └─Linear: 3-4                  [64, 325, 64]             4,096
# │    │    └─Linear: 3-5                  [64, 325, 64]             4,096
# │    │    └─Linear: 3-6                  [64, 325, 64]             4,096
# │    │    └─Linear: 3-7                  [64, 325, 64]             4,096
# │    │    └─Linear: 3-8                  [64, 325, 64]             4,096
# ├─ModuleList: 1-34                       --                        (recursive)
# │    └─S_GNN: 2-3                        [64, 325, 64]             --
# │    │    └─Sequential: 3-9              [64, 325, 32]             6,144
# │    │    └─Linear: 3-10                 [64, 325, 64]             4,096
# ├─ModuleList: 1-35                       --                        (recursive)
# │    └─S_GNN: 2-4                        [64, 325, 64]             --
# │    │    └─Sequential: 3-11             [64, 325, 32]             6,144
# │    │    └─Linear: 3-12                 [64, 325, 64]             4,096
# ├─ModuleList: 1-36                       --                        (recursive)
# │    └─GRU: 2-5                          [64, 325, 64]             --
# │    │    └─Linear: 3-13                 [64, 325, 64]             4,096
# │    │    └─Linear: 3-14                 [64, 325, 64]             4,096
# │    │    └─Linear: 3-15                 [64, 325, 64]             4,096
# │    │    └─Linear: 3-16                 [64, 325, 64]             4,096
# │    │    └─Linear: 3-17                 [64, 325, 64]             4,096
# │    │    └─Linear: 3-18                 [64, 325, 64]             4,096
# ├─ModuleList: 1-34                       --                        (recursive)
# │    └─S_GNN: 2-6                        [64, 325, 64]             --
# │    │    └─Sequential: 3-19             [64, 325, 32]             6,144
# │    │    └─Linear: 3-20                 [64, 325, 64]             4,096
# ├─ModuleList: 1-35                       --                        (recursive)
# │    └─S_GNN: 2-7                        [64, 325, 64]             --
# │    │    └─Sequential: 3-21             [64, 325, 32]             6,144
# │    │    └─Linear: 3-22                 [64, 325, 64]             4,096
# ├─ModuleList: 1-36                       --                        (recursive)
# │    └─GRU: 2-8                          [64, 325, 64]             --
# │    │    └─Linear: 3-23                 [64, 325, 64]             4,096
# │    │    └─Linear: 3-24                 [64, 325, 64]             4,096
# │    │    └─Linear: 3-25                 [64, 325, 64]             4,096
# │    │    └─Linear: 3-26                 [64, 325, 64]             4,096
# │    │    └─Linear: 3-27                 [64, 325, 64]             4,096
# │    │    └─Linear: 3-28                 [64, 325, 64]             4,096
# ├─ModuleList: 1-34                       --                        (recursive)
# │    └─S_GNN: 2-9                        [64, 325, 64]             --
# │    │    └─Sequential: 3-29             [64, 325, 32]             6,144
# │    │    └─Linear: 3-30                 [64, 325, 64]             4,096
# ├─ModuleList: 1-35                       --                        (recursive)
# │    └─S_GNN: 2-10                       [64, 325, 64]             --
# │    │    └─Sequential: 3-31             [64, 325, 32]             6,144
# │    │    └─Linear: 3-32                 [64, 325, 64]             4,096
# ├─ModuleList: 1-36                       --                        (recursive)
# │    └─GRU: 2-11                         [64, 325, 64]             --
# │    │    └─Linear: 3-33                 [64, 325, 64]             4,096
# │    │    └─Linear: 3-34                 [64, 325, 64]             4,096
# │    │    └─Linear: 3-35                 [64, 325, 64]             4,096
# │    │    └─Linear: 3-36                 [64, 325, 64]             4,096
# │    │    └─Linear: 3-37                 [64, 325, 64]             4,096
# │    │    └─Linear: 3-38                 [64, 325, 64]             4,096
# ├─ModuleList: 1-34                       --                        (recursive)
# │    └─S_GNN: 2-12                       [64, 325, 64]             --
# │    │    └─Sequential: 3-39             [64, 325, 32]             6,144
# │    │    └─Linear: 3-40                 [64, 325, 64]             4,096
# ├─ModuleList: 1-35                       --                        (recursive)
# │    └─S_GNN: 2-13                       [64, 325, 64]             --
# │    │    └─Sequential: 3-41             [64, 325, 32]             6,144
# │    │    └─Linear: 3-42                 [64, 325, 64]             4,096
# ├─ModuleList: 1-36                       --                        (recursive)
# │    └─GRU: 2-14                         [64, 325, 64]             --
# │    │    └─Linear: 3-43                 [64, 325, 64]             4,096
# │    │    └─Linear: 3-44                 [64, 325, 64]             4,096
# │    │    └─Linear: 3-45                 [64, 325, 64]             4,096
# │    │    └─Linear: 3-46                 [64, 325, 64]             4,096
# │    │    └─Linear: 3-47                 [64, 325, 64]             4,096
# │    │    └─Linear: 3-48                 [64, 325, 64]             4,096
# ├─ModuleList: 1-34                       --                        (recursive)
# │    └─S_GNN: 2-15                       [64, 325, 64]             --
# │    │    └─Sequential: 3-49             [64, 325, 32]             6,144
# │    │    └─Linear: 3-50                 [64, 325, 64]             4,096
# ├─ModuleList: 1-35                       --                        (recursive)
# │    └─S_GNN: 2-16                       [64, 325, 64]             --
# │    │    └─Sequential: 3-51             [64, 325, 32]             6,144
# │    │    └─Linear: 3-52                 [64, 325, 64]             4,096
# ├─ModuleList: 1-36                       --                        (recursive)
# │    └─GRU: 2-17                         [64, 325, 64]             --
# │    │    └─Linear: 3-53                 [64, 325, 64]             4,096
# │    │    └─Linear: 3-54                 [64, 325, 64]             4,096
# │    │    └─Linear: 3-55                 [64, 325, 64]             4,096
# │    │    └─Linear: 3-56                 [64, 325, 64]             4,096
# │    │    └─Linear: 3-57                 [64, 325, 64]             4,096
# │    │    └─Linear: 3-58                 [64, 325, 64]             4,096
# ├─ModuleList: 1-34                       --                        (recursive)
# │    └─S_GNN: 2-18                       [64, 325, 64]             --
# │    │    └─Sequential: 3-59             [64, 325, 32]             6,144
# │    │    └─Linear: 3-60                 [64, 325, 64]             4,096
# ├─ModuleList: 1-35                       --                        (recursive)
# │    └─S_GNN: 2-19                       [64, 325, 64]             --
# │    │    └─Sequential: 3-61             [64, 325, 32]             6,144
# │    │    └─Linear: 3-62                 [64, 325, 64]             4,096
# ├─ModuleList: 1-36                       --                        (recursive)
# │    └─GRU: 2-20                         [64, 325, 64]             --
# │    │    └─Linear: 3-63                 [64, 325, 64]             4,096
# │    │    └─Linear: 3-64                 [64, 325, 64]             4,096
# │    │    └─Linear: 3-65                 [64, 325, 64]             4,096
# │    │    └─Linear: 3-66                 [64, 325, 64]             4,096
# │    │    └─Linear: 3-67                 [64, 325, 64]             4,096
# │    │    └─Linear: 3-68                 [64, 325, 64]             4,096
# ├─ModuleList: 1-34                       --                        (recursive)
# │    └─S_GNN: 2-21                       [64, 325, 64]             --
# │    │    └─Sequential: 3-69             [64, 325, 32]             6,144
# │    │    └─Linear: 3-70                 [64, 325, 64]             4,096
# ├─ModuleList: 1-35                       --                        (recursive)
# │    └─S_GNN: 2-22                       [64, 325, 64]             --
# │    │    └─Sequential: 3-71             [64, 325, 32]             6,144
# │    │    └─Linear: 3-72                 [64, 325, 64]             4,096
# ├─ModuleList: 1-36                       --                        (recursive)
# │    └─GRU: 2-23                         [64, 325, 64]             --
# │    │    └─Linear: 3-73                 [64, 325, 64]             4,096
# │    │    └─Linear: 3-74                 [64, 325, 64]             4,096
# │    │    └─Linear: 3-75                 [64, 325, 64]             4,096
# │    │    └─Linear: 3-76                 [64, 325, 64]             4,096
# │    │    └─Linear: 3-77                 [64, 325, 64]             4,096
# │    │    └─Linear: 3-78                 [64, 325, 64]             4,096
# ├─ModuleList: 1-34                       --                        (recursive)
# │    └─S_GNN: 2-24                       [64, 325, 64]             --
# │    │    └─Sequential: 3-79             [64, 325, 32]             6,144
# │    │    └─Linear: 3-80                 [64, 325, 64]             4,096
# ├─ModuleList: 1-35                       --                        (recursive)
# │    └─S_GNN: 2-25                       [64, 325, 64]             --
# │    │    └─Sequential: 3-81             [64, 325, 32]             6,144
# │    │    └─Linear: 3-82                 [64, 325, 64]             4,096
# ├─ModuleList: 1-36                       --                        (recursive)
# │    └─GRU: 2-26                         [64, 325, 64]             --
# │    │    └─Linear: 3-83                 [64, 325, 64]             4,096
# │    │    └─Linear: 3-84                 [64, 325, 64]             4,096
# │    │    └─Linear: 3-85                 [64, 325, 64]             4,096
# │    │    └─Linear: 3-86                 [64, 325, 64]             4,096
# │    │    └─Linear: 3-87                 [64, 325, 64]             4,096
# │    │    └─Linear: 3-88                 [64, 325, 64]             4,096
# ├─ModuleList: 1-34                       --                        (recursive)
# │    └─S_GNN: 2-27                       [64, 325, 64]             --
# │    │    └─Sequential: 3-89             [64, 325, 32]             6,144
# │    │    └─Linear: 3-90                 [64, 325, 64]             4,096
# ├─ModuleList: 1-35                       --                        (recursive)
# │    └─S_GNN: 2-28                       [64, 325, 64]             --
# │    │    └─Sequential: 3-91             [64, 325, 32]             6,144
# │    │    └─Linear: 3-92                 [64, 325, 64]             4,096
# ├─ModuleList: 1-36                       --                        (recursive)
# │    └─GRU: 2-29                         [64, 325, 64]             --
# │    │    └─Linear: 3-93                 [64, 325, 64]             4,096
# │    │    └─Linear: 3-94                 [64, 325, 64]             4,096
# │    │    └─Linear: 3-95                 [64, 325, 64]             4,096
# │    │    └─Linear: 3-96                 [64, 325, 64]             4,096
# │    │    └─Linear: 3-97                 [64, 325, 64]             4,096
# │    │    └─Linear: 3-98                 [64, 325, 64]             4,096
# ├─ModuleList: 1-34                       --                        (recursive)
# │    └─S_GNN: 2-30                       [64, 325, 64]             --
# │    │    └─Sequential: 3-99             [64, 325, 32]             6,144
# │    │    └─Linear: 3-100                [64, 325, 64]             4,096
# ├─ModuleList: 1-35                       --                        (recursive)
# │    └─S_GNN: 2-31                       [64, 325, 64]             --
# │    │    └─Sequential: 3-101            [64, 325, 32]             6,144
# │    │    └─Linear: 3-102                [64, 325, 64]             4,096
# ├─ModuleList: 1-36                       --                        (recursive)
# │    └─GRU: 2-32                         [64, 325, 64]             --
# │    │    └─Linear: 3-103                [64, 325, 64]             4,096
# │    │    └─Linear: 3-104                [64, 325, 64]             4,096
# │    │    └─Linear: 3-105                [64, 325, 64]             4,096
# │    │    └─Linear: 3-106                [64, 325, 64]             4,096
# │    │    └─Linear: 3-107                [64, 325, 64]             4,096
# │    │    └─Linear: 3-108                [64, 325, 64]             4,096
# ├─ModuleList: 1-34                       --                        (recursive)
# │    └─S_GNN: 2-33                       [64, 325, 64]             --
# │    │    └─Sequential: 3-109            [64, 325, 32]             6,144
# │    │    └─Linear: 3-110                [64, 325, 64]             4,096
# ├─ModuleList: 1-35                       --                        (recursive)
# │    └─S_GNN: 2-34                       [64, 325, 64]             --
# │    │    └─Sequential: 3-111            [64, 325, 32]             6,144
# │    │    └─Linear: 3-112                [64, 325, 64]             4,096
# ├─ModuleList: 1-36                       --                        (recursive)
# │    └─GRU: 2-35                         [64, 325, 64]             --
# │    │    └─Linear: 3-113                [64, 325, 64]             4,096
# │    │    └─Linear: 3-114                [64, 325, 64]             4,096
# │    │    └─Linear: 3-115                [64, 325, 64]             4,096
# │    │    └─Linear: 3-116                [64, 325, 64]             4,096
# │    │    └─Linear: 3-117                [64, 325, 64]             4,096
# │    │    └─Linear: 3-118                [64, 325, 64]             4,096
# ├─PositionalEncoder: 1-37                [64, 12, 325, 64]         --
# ├─Transformer: 1-38                      [64, 12, 325, 64]         --
# │    └─Linear: 2-36                      [64, 12, 325, 64]         4,096
# │    └─Linear: 2-37                      [64, 12, 325, 64]         4,096
# │    └─Linear: 2-38                      [64, 12, 325, 64]         4,096
# │    └─BatchNorm2d: 2-39                 [64, 12, 325, 64]         24
# │    └─Sequential: 2-40                  [64, 12, 325, 64]         --
# │    │    └─Linear: 3-119                [64, 12, 325, 64]         4,096
# │    │    └─ReLU: 3-120                  [64, 12, 325, 64]         --
# │    │    └─Linear: 3-121                [64, 12, 325, 64]         4,096
# │    └─BatchNorm2d: 2-41                 [64, 12, 325, 64]         24
# ├─Sequential: 1-39                       [64, 12, 325, 1]          --
# │    └─Linear: 2-42                      [64, 12, 325, 64]         4,096
# │    └─ReLU: 2-43                        [64, 12, 325, 64]         --
# │    └─Linear: 2-44                      [64, 12, 325, 1]          64
# ==========================================================================================
# Total params: 555,696
# Trainable params: 555,696
# Non-trainable params: 0
# Total mult-adds (M): 35.56
# ==========================================================================================
# Input size (MB): 8.99
# Forward/backward pass size (MB): 2531.28
# Params size (MB): 2.22
# Estimated Total Size (MB): 2542.49
# ==========================================================================================
# c:\Users\riccardo\AppData\Local\Programs\Python\Python310\lib\site-packages\torchinfo\torchinfo.py:477: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   action_fn=lambda data: sys.getsizeof(data.storage()),
# c:\Users\riccardo\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\storage.py:665: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return super().__sizeof__() + self.nbytes()

# %% [markdown]
# ## 2.2 Training procedure
# In this section the training of the model is performed. In addition, the train validation and test dataloaders are built and the important parameters and training utilities are set.

# %% [markdown]
# The train, validation and test dataloaders are built. Solely the data of the train dataloader is shuffled, in order for the model to overfit less, guaranteeing a more generalized training procedure.

# %%
from src.data.dataloaders import get_dataloader

train_dataloader = get_dataloader(x_train, y_train, batch_size=32,
                                  shuffle=True)
val_dataloader = get_dataloader(x_val, y_val, batch_size=64,
                                shuffle=False)
test_dataloader = get_dataloader(x_test, y_test, batch_size=64,
                                 shuffle=False)

# %% [markdown]
# The training utilities and parameters are assigned.
# * `Adam` is used as an optimizer with learning rate $1e-3$ and weight decay $2e-6$.
# * A checkpoint monitor is initialized to control the performances of the model on the validation set, by saving the best resulting weights which consist in the minimal error computed as the sum of the *Mean Absolute Error (MAE)*, the *Root Mean Squared Error (RMSE)* and the *Mean Absolute Percentage Error (MAPE)*.
# * The number of *epochs* is set to $200$.

# %%
from src.spatial_temporal_gnn.training import Checkpoint

optimizer = torch.optim.Adam(model.parameters(), lr=1e-3, weight_decay=2e-6)

lr_scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
    optimizer, mode='min', factor=.1, patience=10, verbose=False,
    threshold=.001, threshold_mode='rel', cooldown=0, min_lr=1e-3, eps=1e-08)

checkpoint_file_path = os.path.join('..', 'models', 'checkpoints',
                                    'st_gnn_pems_bay.pth')
checkpoint = Checkpoint(checkpoint_file_path)

EPOCHS = 200

# %% [markdown]
# The training procedure is performed. The loss criterion is the *Mean Absolute Error (MAE)* computed on the unscaled speed predictins and ground truths.
#
# Even the *Root Mean Squared Error (RMSE)* and the *Mean Absolute Percentage Error (MAPE)* are tracked which respect to the train and validation prediction performances.
#
# The model is trained on scaled data and evaluated on unscaled data. The reason behind this decision is found in the increased performance of the model under this situation. Furthermore, the computation of the loss function on unscaled data consists in a more severe error penality and a more faithful comparison to the results of the original experiment.

# %%
from src.spatial_temporal_gnn.training import train

history = train(model, optimizer, train_dataloader, val_dataloader, scaler,
                EPOCHS, DEVICE, checkpoint=checkpoint, 
                lr_scheduler=lr_scheduler, reload_best_weights=True)
# Out:
# Epoch 1/200
# [49/49] - 12s - train: { MAE (loss): 3.72 - RMSE: 7.45 - MAPE: 9.81% } - val: { MAE: 3.11 - RMSE: 7.02 - MAPE: 7.67% } - lr: 0.001 - weight decay: 2e-06
# Epoch 2/200
# [49/49] - 12s - train: { MAE (loss): 2.35 - RMSE: 5.23 - MAPE: 5.36% } - val: { MAE: 2.55 - RMSE: 5.77 - MAPE: 6.26% } - lr: 0.001 - weight decay: 2e-06
# Epoch 3/200
# [49/49] - 12s - train: { MAE (loss): 2.21 - RMSE: 4.98 - MAPE: 4.93% } - val: { MAE: 2.49 - RMSE: 5.69 - MAPE: 6.12% } - lr: 0.001 - weight decay: 2e-06
# Epoch 4/200
# [49/49] - 12s - train: { MAE (loss): 2.17 - RMSE: 4.92 - MAPE: 4.84% } - val: { MAE: 2.53 - RMSE: 5.63 - MAPE: 6.48% } - lr: 0.001 - weight decay: 2e-06
# Epoch 5/200
# [49/49] - 12s - train: { MAE (loss): 2.18 - RMSE: 4.91 - MAPE: 4.88% } - val: { MAE: 2.47 - RMSE: 5.74 - MAPE: 5.87% } - lr: 0.001 - weight decay: 2e-06
# Epoch 6/200
# [49/49] - 12s - train: { MAE (loss): 2.15 - RMSE: 4.9 - MAPE: 4.78% } - val: { MAE: 2.43 - RMSE: 5.6 - MAPE: 5.98% } - lr: 0.001 - weight decay: 2e-06
# Epoch 7/200
# [49/49] - 12s - train: { MAE (loss): 2.16 - RMSE: 4.9 - MAPE: 4.82% } - val: { MAE: 2.52 - RMSE: 5.68 - MAPE: 6.38% } - lr: 0.001 - weight decay: 2e-06
# Epoch 8/200
# [49/49] - 12s - train: { MAE (loss): 2.18 - RMSE: 4.89 - MAPE: 4.95% } - val: { MAE: 2.42 - RMSE: 5.63 - MAPE: 5.89% } - lr: 0.001 - weight decay: 2e-06
# Epoch 9/200
# [49/49] - 12s - train: { MAE (loss): 2.13 - RMSE: 4.87 - MAPE: 4.78% } - val: { MAE: 2.43 - RMSE: 5.58 - MAPE: 5.89% } - lr: 0.001 - weight decay: 2e-06
# Epoch 10/200
# [49/49] - 12s - train: { MAE (loss): 2.13 - RMSE: 4.85 - MAPE: 4.76% } - val: { MAE: 2.44 - RMSE: 5.77 - MAPE: 5.74% } - lr: 0.001 - weight decay: 2e-06
# Epoch 11/200
# [49/49] - 12s - train: { MAE (loss): 2.14 - RMSE: 4.87 - MAPE: 4.79% } - val: { MAE: 2.41 - RMSE: 5.63 - MAPE: 5.84% } - lr: 0.001 - weight decay: 2e-06
# Epoch 12/200
# [49/49] - 12s - train: { MAE (loss): 2.13 - RMSE: 4.84 - MAPE: 4.75% } - val: { MAE: 2.48 - RMSE: 5.53 - MAPE: 6.43% } - lr: 0.001 - weight decay: 2e-06
# Epoch 13/200
# [49/49] - 12s - train: { MAE (loss): 2.14 - RMSE: 4.85 - MAPE: 4.85% } - val: { MAE: 2.43 - RMSE: 5.68 - MAPE: 5.81% } - lr: 0.001 - weight decay: 2e-06
# Epoch 14/200
# [49/49] - 12s - train: { MAE (loss): 2.13 - RMSE: 4.86 - MAPE: 4.77% } - val: { MAE: 2.39 - RMSE: 5.52 - MAPE: 5.85% } - lr: 0.001 - weight decay: 2e-06
# Epoch 15/200
# [49/49] - 12s - train: { MAE (loss): 2.11 - RMSE: 4.82 - MAPE: 4.72% } - val: { MAE: 2.41 - RMSE: 5.74 - MAPE: 5.7% } - lr: 0.001 - weight decay: 2e-06
# Epoch 16/200
# [49/49] - 12s - train: { MAE (loss): 2.1 - RMSE: 4.8 - MAPE: 4.71% } - val: { MAE: 2.41 - RMSE: 5.48 - MAPE: 5.9% } - lr: 0.001 - weight decay: 2e-06
# Epoch 17/200
# [49/49] - 12s - train: { MAE (loss): 2.11 - RMSE: 4.79 - MAPE: 4.75% } - val: { MAE: 2.36 - RMSE: 5.52 - MAPE: 5.7% } - lr: 0.001 - weight decay: 2e-06
# Epoch 18/200
# [49/49] - 12s - train: { MAE (loss): 2.09 - RMSE: 4.76 - MAPE: 4.68% } - val: { MAE: 2.35 - RMSE: 5.38 - MAPE: 5.88% } - lr: 0.001 - weight decay: 2e-06
# Epoch 19/200
# [49/49] - 12s - train: { MAE (loss): 2.09 - RMSE: 4.76 - MAPE: 4.7% } - val: { MAE: 2.41 - RMSE: 5.72 - MAPE: 5.61% } - lr: 0.001 - weight decay: 2e-06
# Epoch 20/200
# [49/49] - 12s - train: { MAE (loss): 2.1 - RMSE: 4.78 - MAPE: 4.72% } - val: { MAE: 2.38 - RMSE: 5.41 - MAPE: 5.94% } - lr: 0.001 - weight decay: 2e-06
# Epoch 21/200
# [49/49] - 12s - train: { MAE (loss): 2.1 - RMSE: 4.78 - MAPE: 4.73% } - val: { MAE: 2.38 - RMSE: 5.45 - MAPE: 5.94% } - lr: 0.001 - weight decay: 2e-06
# Epoch 22/200
# [49/49] - 12s - train: { MAE (loss): 2.09 - RMSE: 4.76 - MAPE: 4.71% } - val: { MAE: 2.38 - RMSE: 5.44 - MAPE: 5.9% } - lr: 0.001 - weight decay: 2e-06
# Epoch 23/200
# [49/49] - 12s - train: { MAE (loss): 2.08 - RMSE: 4.74 - MAPE: 4.68% } - val: { MAE: 2.31 - RMSE: 5.3 - MAPE: 5.69% } - lr: 0.001 - weight decay: 2e-06
# Epoch 24/200
# [49/49] - 12s - train: { MAE (loss): 2.05 - RMSE: 4.67 - MAPE: 4.59% } - val: { MAE: 2.29 - RMSE: 5.28 - MAPE: 5.6% } - lr: 0.001 - weight decay: 2e-06
# Epoch 25/200
# [49/49] - 12s - train: { MAE (loss): 2.04 - RMSE: 4.61 - MAPE: 4.56% } - val: { MAE: 2.27 - RMSE: 5.22 - MAPE: 5.43% } - lr: 0.001 - weight decay: 2e-06
# Epoch 26/200
# [49/49] - 12s - train: { MAE (loss): 2.01 - RMSE: 4.55 - MAPE: 4.52% } - val: { MAE: 2.31 - RMSE: 5.45 - MAPE: 5.36% } - lr: 0.001 - weight decay: 2e-06
# Epoch 27/200
# [49/49] - 12s - train: { MAE (loss): 2 - RMSE: 4.54 - MAPE: 4.47% } - val: { MAE: 2.22 - RMSE: 5.05 - MAPE: 5.53% } - lr: 0.001 - weight decay: 2e-06
# Epoch 28/200
# [49/49] - 12s - train: { MAE (loss): 2 - RMSE: 4.53 - MAPE: 4.5% } - val: { MAE: 2.21 - RMSE: 5.04 - MAPE: 5.38% } - lr: 0.001 - weight decay: 2e-06
# Epoch 29/200
# [49/49] - 12s - train: { MAE (loss): 2.01 - RMSE: 4.52 - MAPE: 4.52% } - val: { MAE: 2.19 - RMSE: 5.04 - MAPE: 5.28% } - lr: 0.001 - weight decay: 2e-06
# Epoch 30/200
# [49/49] - 12s - train: { MAE (loss): 1.98 - RMSE: 4.43 - MAPE: 4.42% } - val: { MAE: 2.2 - RMSE: 4.94 - MAPE: 5.55% } - lr: 0.001 - weight decay: 2e-06
# Epoch 31/200
# [49/49] - 12s - train: { MAE (loss): 1.97 - RMSE: 4.42 - MAPE: 4.41% } - val: { MAE: 2.19 - RMSE: 5.04 - MAPE: 5.29% } - lr: 0.001 - weight decay: 2e-06
# Epoch 32/200
# [49/49] - 12s - train: { MAE (loss): 1.97 - RMSE: 4.45 - MAPE: 4.44% } - val: { MAE: 2.2 - RMSE: 4.98 - MAPE: 5.27% } - lr: 0.001 - weight decay: 2e-06
# Epoch 33/200
# [49/49] - 12s - train: { MAE (loss): 1.97 - RMSE: 4.42 - MAPE: 4.43% } - val: { MAE: 2.18 - RMSE: 5.04 - MAPE: 5.22% } - lr: 0.001 - weight decay: 2e-06
# Epoch 34/200
# [49/49] - 12s - train: { MAE (loss): 1.95 - RMSE: 4.37 - MAPE: 4.38% } - val: { MAE: 2.16 - RMSE: 4.91 - MAPE: 5.24% } - lr: 0.001 - weight decay: 2e-06
# Epoch 35/200
# [49/49] - 12s - train: { MAE (loss): 1.96 - RMSE: 4.37 - MAPE: 4.4% } - val: { MAE: 2.13 - RMSE: 4.83 - MAPE: 5.22% } - lr: 0.001 - weight decay: 2e-06
# Epoch 36/200
# [49/49] - 12s - train: { MAE (loss): 1.96 - RMSE: 4.4 - MAPE: 4.42% } - val: { MAE: 2.16 - RMSE: 4.83 - MAPE: 5.3% } - lr: 0.001 - weight decay: 2e-06
# Epoch 37/200
# [49/49] - 12s - train: { MAE (loss): 1.94 - RMSE: 4.34 - MAPE: 4.36% } - val: { MAE: 2.18 - RMSE: 4.9 - MAPE: 5.55% } - lr: 0.001 - weight decay: 2e-06
# Epoch 38/200
# [49/49] - 12s - train: { MAE (loss): 1.95 - RMSE: 4.36 - MAPE: 4.41% } - val: { MAE: 2.13 - RMSE: 4.84 - MAPE: 5.17% } - lr: 0.001 - weight decay: 2e-06
# Epoch 39/200
# [49/49] - 12s - train: { MAE (loss): 1.93 - RMSE: 4.32 - MAPE: 4.36% } - val: { MAE: 2.18 - RMSE: 5 - MAPE: 5.12% } - lr: 0.001 - weight decay: 2e-06
# Epoch 40/200
# [49/49] - 12s - train: { MAE (loss): 1.94 - RMSE: 4.34 - MAPE: 4.38% } - val: { MAE: 2.14 - RMSE: 4.85 - MAPE: 5.17% } - lr: 0.001 - weight decay: 2e-06
# Epoch 41/200
# [49/49] - 12s - train: { MAE (loss): 1.92 - RMSE: 4.28 - MAPE: 4.32% } - val: { MAE: 2.16 - RMSE: 4.95 - MAPE: 5.21% } - lr: 0.001 - weight decay: 2e-06
# Epoch 42/200
# [49/49] - 12s - train: { MAE (loss): 1.94 - RMSE: 4.35 - MAPE: 4.39% } - val: { MAE: 2.16 - RMSE: 4.93 - MAPE: 5.32% } - lr: 0.001 - weight decay: 2e-06
# Epoch 43/200
# [49/49] - 12s - train: { MAE (loss): 1.92 - RMSE: 4.31 - MAPE: 4.34% } - val: { MAE: 2.12 - RMSE: 4.82 - MAPE: 5.24% } - lr: 0.001 - weight decay: 2e-06
# Epoch 44/200
# [49/49] - 12s - train: { MAE (loss): 1.91 - RMSE: 4.29 - MAPE: 4.3% } - val: { MAE: 2.13 - RMSE: 4.9 - MAPE: 5.12% } - lr: 0.001 - weight decay: 2e-06
# Epoch 45/200
# [49/49] - 12s - train: { MAE (loss): 1.9 - RMSE: 4.25 - MAPE: 4.26% } - val: { MAE: 2.11 - RMSE: 4.82 - MAPE: 5.19% } - lr: 0.001 - weight decay: 2e-06
# Epoch 46/200
# [49/49] - 12s - train: { MAE (loss): 1.9 - RMSE: 4.25 - MAPE: 4.29% } - val: { MAE: 2.13 - RMSE: 4.82 - MAPE: 5.27% } - lr: 0.001 - weight decay: 2e-06
# Epoch 47/200
# [49/49] - 12s - train: { MAE (loss): 1.91 - RMSE: 4.29 - MAPE: 4.3% } - val: { MAE: 2.11 - RMSE: 4.79 - MAPE: 5.15% } - lr: 0.001 - weight decay: 2e-06
# Epoch 48/200
# [49/49] - 12s - train: { MAE (loss): 1.9 - RMSE: 4.25 - MAPE: 4.28% } - val: { MAE: 2.15 - RMSE: 4.89 - MAPE: 5.26% } - lr: 0.001 - weight decay: 2e-06
# Epoch 49/200
# [49/49] - 12s - train: { MAE (loss): 1.9 - RMSE: 4.24 - MAPE: 4.28% } - val: { MAE: 2.11 - RMSE: 4.76 - MAPE: 5.19% } - lr: 0.001 - weight decay: 2e-06
# Epoch 50/200
# [49/49] - 12s - train: { MAE (loss): 1.9 - RMSE: 4.24 - MAPE: 4.29% } - val: { MAE: 2.1 - RMSE: 4.78 - MAPE: 5.02% } - lr: 0.001 - weight decay: 2e-06
# Epoch 51/200
# [49/49] - 12s - train: { MAE (loss): 1.89 - RMSE: 4.23 - MAPE: 4.27% } - val: { MAE: 2.13 - RMSE: 4.89 - MAPE: 5.03% } - lr: 0.001 - weight decay: 2e-06
# Epoch 52/200
# [49/49] - 12s - train: { MAE (loss): 1.9 - RMSE: 4.26 - MAPE: 4.28% } - val: { MAE: 2.12 - RMSE: 4.8 - MAPE: 5.01% } - lr: 0.001 - weight decay: 2e-06
# Epoch 53/200
# [49/49] - 12s - train: { MAE (loss): 1.89 - RMSE: 4.25 - MAPE: 4.26% } - val: { MAE: 2.13 - RMSE: 4.84 - MAPE: 5.04% } - lr: 0.001 - weight decay: 2e-06
# Epoch 54/200
# [49/49] - 12s - train: { MAE (loss): 1.89 - RMSE: 4.23 - MAPE: 4.27% } - val: { MAE: 2.11 - RMSE: 4.81 - MAPE: 5.22% } - lr: 0.001 - weight decay: 2e-06
# Epoch 55/200
# [49/49] - 12s - train: { MAE (loss): 1.88 - RMSE: 4.21 - MAPE: 4.25% } - val: { MAE: 2.1 - RMSE: 4.76 - MAPE: 5.02% } - lr: 0.001 - weight decay: 2e-06
# Epoch 56/200
# [49/49] - 12s - train: { MAE (loss): 1.88 - RMSE: 4.21 - MAPE: 4.23% } - val: { MAE: 2.1 - RMSE: 4.8 - MAPE: 5.03% } - lr: 0.001 - weight decay: 2e-06
# Epoch 57/200
# [49/49] - 12s - train: { MAE (loss): 1.88 - RMSE: 4.22 - MAPE: 4.24% } - val: { MAE: 2.08 - RMSE: 4.78 - MAPE: 4.99% } - lr: 0.001 - weight decay: 2e-06
# Epoch 58/200
# [49/49] - 12s - train: { MAE (loss): 1.91 - RMSE: 4.29 - MAPE: 4.29% } - val: { MAE: 2.16 - RMSE: 4.94 - MAPE: 5.08% } - lr: 0.001 - weight decay: 2e-06
# Epoch 59/200
# [49/49] - 12s - train: { MAE (loss): 1.9 - RMSE: 4.27 - MAPE: 4.28% } - val: { MAE: 2.1 - RMSE: 4.79 - MAPE: 5% } - lr: 0.001 - weight decay: 2e-06
# Epoch 60/200
# [49/49] - 12s - train: { MAE (loss): 1.9 - RMSE: 4.24 - MAPE: 4.28% } - val: { MAE: 2.16 - RMSE: 4.83 - MAPE: 5.44% } - lr: 0.001 - weight decay: 2e-06
# Epoch 61/200
# [49/49] - 12s - train: { MAE (loss): 1.9 - RMSE: 4.23 - MAPE: 4.29% } - val: { MAE: 2.11 - RMSE: 4.84 - MAPE: 5.08% } - lr: 0.001 - weight decay: 2e-06
# Epoch 62/200
# [49/49] - 12s - train: { MAE (loss): 1.89 - RMSE: 4.24 - MAPE: 4.25% } - val: { MAE: 2.12 - RMSE: 4.8 - MAPE: 5.1% } - lr: 0.001 - weight decay: 2e-06
# Epoch 63/200
# [49/49] - 12s - train: { MAE (loss): 1.88 - RMSE: 4.22 - MAPE: 4.23% } - val: { MAE: 2.08 - RMSE: 4.76 - MAPE: 4.96% } - lr: 0.001 - weight decay: 2e-06
# Epoch 64/200
# [49/49] - 12s - train: { MAE (loss): 1.89 - RMSE: 4.23 - MAPE: 4.26% } - val: { MAE: 2.14 - RMSE: 4.79 - MAPE: 5.28% } - lr: 0.001 - weight decay: 2e-06
# Epoch 65/200
# [49/49] - 12s - train: { MAE (loss): 1.88 - RMSE: 4.23 - MAPE: 4.24% } - val: { MAE: 2.08 - RMSE: 4.73 - MAPE: 5.07% } - lr: 0.001 - weight decay: 2e-06
# Epoch 66/200
# [49/49] - 12s - train: { MAE (loss): 1.88 - RMSE: 4.2 - MAPE: 4.24% } - val: { MAE: 2.1 - RMSE: 4.77 - MAPE: 5.09% } - lr: 0.001 - weight decay: 2e-06
# Epoch 67/200
# [49/49] - 12s - train: { MAE (loss): 1.89 - RMSE: 4.22 - MAPE: 4.26% } - val: { MAE: 2.11 - RMSE: 4.77 - MAPE: 5.17% } - lr: 0.001 - weight decay: 2e-06
# Epoch 68/200
# [49/49] - 12s - train: { MAE (loss): 1.88 - RMSE: 4.21 - MAPE: 4.25% } - val: { MAE: 2.14 - RMSE: 4.87 - MAPE: 5.07% } - lr: 0.001 - weight decay: 2e-06
# Epoch 69/200
# [49/49] - 12s - train: { MAE (loss): 1.91 - RMSE: 4.3 - MAPE: 4.32% } - val: { MAE: 2.12 - RMSE: 4.82 - MAPE: 5.28% } - lr: 0.001 - weight decay: 2e-06
# Epoch 70/200
# [49/49] - 12s - train: { MAE (loss): 1.89 - RMSE: 4.22 - MAPE: 4.25% } - val: { MAE: 2.08 - RMSE: 4.76 - MAPE: 5.02% } - lr: 0.001 - weight decay: 2e-06
# Epoch 71/200
# [49/49] - 12s - train: { MAE (loss): 1.89 - RMSE: 4.22 - MAPE: 4.25% } - val: { MAE: 2.09 - RMSE: 4.74 - MAPE: 5.14% } - lr: 0.001 - weight decay: 2e-06
# Epoch 72/200
# [49/49] - 12s - train: { MAE (loss): 1.88 - RMSE: 4.23 - MAPE: 4.23% } - val: { MAE: 2.1 - RMSE: 4.74 - MAPE: 5.13% } - lr: 0.001 - weight decay: 2e-06
# Epoch 73/200
# [49/49] - 12s - train: { MAE (loss): 1.87 - RMSE: 4.18 - MAPE: 4.21% } - val: { MAE: 2.08 - RMSE: 4.75 - MAPE: 4.98% } - lr: 0.001 - weight decay: 2e-06
# Epoch 74/200
# [49/49] - 12s - train: { MAE (loss): 1.87 - RMSE: 4.2 - MAPE: 4.2% } - val: { MAE: 2.09 - RMSE: 4.77 - MAPE: 5.05% } - lr: 0.001 - weight decay: 2e-06
# Epoch 75/200
# [49/49] - 12s - train: { MAE (loss): 1.86 - RMSE: 4.18 - MAPE: 4.19% } - val: { MAE: 2.09 - RMSE: 4.72 - MAPE: 4.98% } - lr: 0.001 - weight decay: 2e-06
# Epoch 76/200
# [49/49] - 12s - train: { MAE (loss): 1.86 - RMSE: 4.18 - MAPE: 4.18% } - val: { MAE: 2.13 - RMSE: 4.97 - MAPE: 4.97% } - lr: 0.001 - weight decay: 2e-06
# Epoch 77/200
# [49/49] - 12s - train: { MAE (loss): 1.88 - RMSE: 4.22 - MAPE: 4.24% } - val: { MAE: 2.08 - RMSE: 4.76 - MAPE: 4.94% } - lr: 0.001 - weight decay: 2e-06
# Epoch 78/200
# [49/49] - 12s - train: { MAE (loss): 1.86 - RMSE: 4.2 - MAPE: 4.19% } - val: { MAE: 2.1 - RMSE: 4.69 - MAPE: 5.05% } - lr: 0.001 - weight decay: 2e-06
# Epoch 79/200
# [49/49] - 12s - train: { MAE (loss): 1.87 - RMSE: 4.18 - MAPE: 4.21% } - val: { MAE: 2.09 - RMSE: 4.76 - MAPE: 5.09% } - lr: 0.001 - weight decay: 2e-06
# Epoch 80/200
# [49/49] - 12s - train: { MAE (loss): 1.85 - RMSE: 4.17 - MAPE: 4.17% } - val: { MAE: 2.08 - RMSE: 4.82 - MAPE: 4.89% } - lr: 0.001 - weight decay: 2e-06
# Epoch 81/200
# [49/49] - 12s - train: { MAE (loss): 1.87 - RMSE: 4.19 - MAPE: 4.22% } - val: { MAE: 2.07 - RMSE: 4.68 - MAPE: 5.07% } - lr: 0.001 - weight decay: 2e-06
# Epoch 82/200
# [49/49] - 12s - train: { MAE (loss): 1.87 - RMSE: 4.2 - MAPE: 4.2% } - val: { MAE: 2.11 - RMSE: 4.78 - MAPE: 5.16% } - lr: 0.001 - weight decay: 2e-06
# Epoch 83/200
# [49/49] - 12s - train: { MAE (loss): 1.87 - RMSE: 4.18 - MAPE: 4.2% } - val: { MAE: 2.1 - RMSE: 4.77 - MAPE: 5.22% } - lr: 0.001 - weight decay: 2e-06
# Epoch 84/200
# [49/49] - 12s - train: { MAE (loss): 1.86 - RMSE: 4.17 - MAPE: 4.17% } - val: { MAE: 2.08 - RMSE: 4.75 - MAPE: 4.93% } - lr: 0.001 - weight decay: 2e-06
# Epoch 85/200
# [49/49] - 12s - train: { MAE (loss): 1.85 - RMSE: 4.16 - MAPE: 4.17% } - val: { MAE: 2.08 - RMSE: 4.73 - MAPE: 5.04% } - lr: 0.001 - weight decay: 2e-06
# Epoch 86/200
# [49/49] - 12s - train: { MAE (loss): 1.85 - RMSE: 4.17 - MAPE: 4.18% } - val: { MAE: 2.07 - RMSE: 4.71 - MAPE: 5.09% } - lr: 0.001 - weight decay: 2e-06
# Epoch 87/200
# [49/49] - 12s - train: { MAE (loss): 1.87 - RMSE: 4.22 - MAPE: 4.24% } - val: { MAE: 2.11 - RMSE: 4.78 - MAPE: 5.14% } - lr: 0.001 - weight decay: 2e-06
# Epoch 88/200
# [49/49] - 12s - train: { MAE (loss): 1.87 - RMSE: 4.2 - MAPE: 4.23% } - val: { MAE: 2.1 - RMSE: 4.75 - MAPE: 5.06% } - lr: 0.001 - weight decay: 2e-06
# Epoch 89/200
# [49/49] - 12s - train: { MAE (loss): 1.85 - RMSE: 4.16 - MAPE: 4.15% } - val: { MAE: 2.08 - RMSE: 4.8 - MAPE: 4.92% } - lr: 0.001 - weight decay: 2e-06
# Epoch 90/200
# [49/49] - 12s - train: { MAE (loss): 1.85 - RMSE: 4.15 - MAPE: 4.15% } - val: { MAE: 2.1 - RMSE: 4.78 - MAPE: 5.16% } - lr: 0.001 - weight decay: 2e-06
# Epoch 91/200
# [49/49] - 12s - train: { MAE (loss): 1.85 - RMSE: 4.17 - MAPE: 4.17% } - val: { MAE: 2.1 - RMSE: 4.7 - MAPE: 5.24% } - lr: 0.001 - weight decay: 2e-06
# Epoch 92/200
# [49/49] - 12s - train: { MAE (loss): 1.85 - RMSE: 4.16 - MAPE: 4.17% } - val: { MAE: 2.08 - RMSE: 4.71 - MAPE: 5.08% } - lr: 0.001 - weight decay: 2e-06
# Epoch 93/200
# [49/49] - 12s - train: { MAE (loss): 1.86 - RMSE: 4.18 - MAPE: 4.19% } - val: { MAE: 2.09 - RMSE: 4.72 - MAPE: 5.15% } - lr: 0.001 - weight decay: 2e-06
# Epoch 94/200
# [49/49] - 12s - train: { MAE (loss): 1.86 - RMSE: 4.18 - MAPE: 4.18% } - val: { MAE: 2.08 - RMSE: 4.73 - MAPE: 4.96% } - lr: 0.001 - weight decay: 2e-06
# Epoch 95/200
# [49/49] - 12s - train: { MAE (loss): 1.85 - RMSE: 4.15 - MAPE: 4.15% } - val: { MAE: 2.07 - RMSE: 4.7 - MAPE: 4.97% } - lr: 0.001 - weight decay: 2e-06
# Epoch 96/200
# [49/49] - 12s - train: { MAE (loss): 1.86 - RMSE: 4.17 - MAPE: 4.17% } - val: { MAE: 2.09 - RMSE: 4.79 - MAPE: 4.95% } - lr: 0.001 - weight decay: 2e-06
# Epoch 97/200
# [49/49] - 12s - train: { MAE (loss): 1.84 - RMSE: 4.15 - MAPE: 4.14% } - val: { MAE: 2.12 - RMSE: 4.89 - MAPE: 5.05% } - lr: 0.001 - weight decay: 2e-06
# Epoch 98/200
# [49/49] - 12s - train: { MAE (loss): 1.85 - RMSE: 4.15 - MAPE: 4.15% } - val: { MAE: 2.08 - RMSE: 4.74 - MAPE: 4.95% } - lr: 0.001 - weight decay: 2e-06
# Epoch 99/200
# [49/49] - 12s - train: { MAE (loss): 1.84 - RMSE: 4.14 - MAPE: 4.13% } - val: { MAE: 2.09 - RMSE: 4.71 - MAPE: 5.13% } - lr: 0.001 - weight decay: 2e-06
# Epoch 100/200
# [49/49] - 12s - train: { MAE (loss): 1.85 - RMSE: 4.16 - MAPE: 4.15% } - val: { MAE: 2.11 - RMSE: 4.73 - MAPE: 5.31% } - lr: 0.001 - weight decay: 2e-06
# Epoch 101/200
# [49/49] - 12s - train: { MAE (loss): 1.88 - RMSE: 4.22 - MAPE: 4.27% } - val: { MAE: 2.11 - RMSE: 4.85 - MAPE: 4.94% } - lr: 0.001 - weight decay: 2e-06
# Epoch 102/200
# [49/49] - 12s - train: { MAE (loss): 1.85 - RMSE: 4.15 - MAPE: 4.14% } - val: { MAE: 2.08 - RMSE: 4.8 - MAPE: 4.97% } - lr: 0.001 - weight decay: 2e-06
# Epoch 103/200
# [49/49] - 12s - train: { MAE (loss): 1.85 - RMSE: 4.18 - MAPE: 4.16% } - val: { MAE: 2.09 - RMSE: 4.76 - MAPE: 5.12% } - lr: 0.001 - weight decay: 2e-06
# Epoch 104/200
# [49/49] - 12s - train: { MAE (loss): 1.85 - RMSE: 4.16 - MAPE: 4.16% } - val: { MAE: 2.1 - RMSE: 4.8 - MAPE: 4.98% } - lr: 0.001 - weight decay: 2e-06
# Epoch 105/200
# [49/49] - 12s - train: { MAE (loss): 1.84 - RMSE: 4.15 - MAPE: 4.13% } - val: { MAE: 2.09 - RMSE: 4.7 - MAPE: 5.23% } - lr: 0.001 - weight decay: 2e-06
# Epoch 106/200
# [49/49] - 12s - train: { MAE (loss): 1.84 - RMSE: 4.13 - MAPE: 4.13% } - val: { MAE: 2.07 - RMSE: 4.74 - MAPE: 4.99% } - lr: 0.001 - weight decay: 2e-06
# Epoch 107/200
# [49/49] - 12s - train: { MAE (loss): 1.84 - RMSE: 4.15 - MAPE: 4.13% } - val: { MAE: 2.09 - RMSE: 4.73 - MAPE: 5% } - lr: 0.001 - weight decay: 2e-06
# Epoch 108/200
# [49/49] - 12s - train: { MAE (loss): 1.84 - RMSE: 4.13 - MAPE: 4.13% } - val: { MAE: 2.11 - RMSE: 4.82 - MAPE: 5.05% } - lr: 0.001 - weight decay: 2e-06
# Epoch 109/200
# [49/49] - 12s - train: { MAE (loss): 1.84 - RMSE: 4.15 - MAPE: 4.14% } - val: { MAE: 2.07 - RMSE: 4.68 - MAPE: 5.07% } - lr: 0.001 - weight decay: 2e-06
# Epoch 110/200
# [49/49] - 12s - train: { MAE (loss): 1.84 - RMSE: 4.15 - MAPE: 4.14% } - val: { MAE: 2.09 - RMSE: 4.75 - MAPE: 5.09% } - lr: 0.001 - weight decay: 2e-06
# Epoch 111/200
# [49/49] - 12s - train: { MAE (loss): 1.84 - RMSE: 4.15 - MAPE: 4.13% } - val: { MAE: 2.09 - RMSE: 4.82 - MAPE: 4.94% } - lr: 0.001 - weight decay: 2e-06
# Epoch 112/200
# [49/49] - 12s - train: { MAE (loss): 1.84 - RMSE: 4.14 - MAPE: 4.13% } - val: { MAE: 2.08 - RMSE: 4.75 - MAPE: 5.01% } - lr: 0.001 - weight decay: 2e-06
# Epoch 113/200
# [49/49] - 12s - train: { MAE (loss): 1.84 - RMSE: 4.14 - MAPE: 4.13% } - val: { MAE: 2.08 - RMSE: 4.74 - MAPE: 4.96% } - lr: 0.001 - weight decay: 2e-06
# Epoch 114/200
# [49/49] - 12s - train: { MAE (loss): 1.84 - RMSE: 4.15 - MAPE: 4.12% } - val: { MAE: 2.08 - RMSE: 4.76 - MAPE: 5.1% } - lr: 0.001 - weight decay: 2e-06
# Epoch 115/200
# [49/49] - 12s - train: { MAE (loss): 1.84 - RMSE: 4.14 - MAPE: 4.14% } - val: { MAE: 2.1 - RMSE: 4.76 - MAPE: 5.04% } - lr: 0.001 - weight decay: 2e-06
# Epoch 116/200
# [49/49] - 12s - train: { MAE (loss): 1.84 - RMSE: 4.17 - MAPE: 4.14% } - val: { MAE: 2.09 - RMSE: 4.69 - MAPE: 5.17% } - lr: 0.001 - weight decay: 2e-06
# Epoch 117/200
# [49/49] - 12s - train: { MAE (loss): 1.83 - RMSE: 4.12 - MAPE: 4.11% } - val: { MAE: 2.09 - RMSE: 4.78 - MAPE: 5.04% } - lr: 0.001 - weight decay: 2e-06
# Epoch 118/200
# [49/49] - 12s - train: { MAE (loss): 1.83 - RMSE: 4.14 - MAPE: 4.13% } - val: { MAE: 2.07 - RMSE: 4.73 - MAPE: 5.01% } - lr: 0.001 - weight decay: 2e-06
# Epoch 119/200
# [49/49] - 12s - train: { MAE (loss): 1.83 - RMSE: 4.13 - MAPE: 4.11% } - val: { MAE: 2.1 - RMSE: 4.84 - MAPE: 4.96% } - lr: 0.001 - weight decay: 2e-06
# Epoch 120/200
# [49/49] - 12s - train: { MAE (loss): 1.84 - RMSE: 4.14 - MAPE: 4.14% } - val: { MAE: 2.08 - RMSE: 4.74 - MAPE: 4.93% } - lr: 0.001 - weight decay: 2e-06
# Epoch 121/200
# [49/49] - 12s - train: { MAE (loss): 1.83 - RMSE: 4.12 - MAPE: 4.1% } - val: { MAE: 2.07 - RMSE: 4.69 - MAPE: 5.04% } - lr: 0.001 - weight decay: 2e-06
# Epoch 122/200
# [49/49] - 12s - train: { MAE (loss): 1.83 - RMSE: 4.13 - MAPE: 4.11% } - val: { MAE: 2.06 - RMSE: 4.71 - MAPE: 4.91% } - lr: 0.001 - weight decay: 2e-06
# Epoch 123/200
# [49/49] - 12s - train: { MAE (loss): 1.85 - RMSE: 4.18 - MAPE: 4.19% } - val: { MAE: 2.14 - RMSE: 4.85 - MAPE: 4.93% } - lr: 0.001 - weight decay: 2e-06
# Epoch 124/200
# [49/49] - 12s - train: { MAE (loss): 1.85 - RMSE: 4.18 - MAPE: 4.17% } - val: { MAE: 2.08 - RMSE: 4.72 - MAPE: 5.07% } - lr: 0.001 - weight decay: 2e-06
# Epoch 125/200
# [49/49] - 12s - train: { MAE (loss): 1.83 - RMSE: 4.13 - MAPE: 4.12% } - val: { MAE: 2.08 - RMSE: 4.69 - MAPE: 5.12% } - lr: 0.001 - weight decay: 2e-06
# Epoch 126/200
# [49/49] - 12s - train: { MAE (loss): 1.83 - RMSE: 4.11 - MAPE: 4.09% } - val: { MAE: 2.06 - RMSE: 4.66 - MAPE: 5.1% } - lr: 0.001 - weight decay: 2e-06
# Epoch 127/200
# [49/49] - 12s - train: { MAE (loss): 1.84 - RMSE: 4.13 - MAPE: 4.13% } - val: { MAE: 2.06 - RMSE: 4.66 - MAPE: 4.93% } - lr: 0.001 - weight decay: 2e-06
# Epoch 128/200
# [49/49] - 12s - train: { MAE (loss): 1.82 - RMSE: 4.11 - MAPE: 4.1% } - val: { MAE: 2.07 - RMSE: 4.76 - MAPE: 4.97% } - lr: 0.001 - weight decay: 2e-06
# Epoch 129/200
# [49/49] - 12s - train: { MAE (loss): 1.83 - RMSE: 4.12 - MAPE: 4.11% } - val: { MAE: 2.07 - RMSE: 4.7 - MAPE: 5% } - lr: 0.001 - weight decay: 2e-06
# Epoch 130/200
# [49/49] - 12s - train: { MAE (loss): 1.83 - RMSE: 4.11 - MAPE: 4.1% } - val: { MAE: 2.08 - RMSE: 4.77 - MAPE: 4.91% } - lr: 0.001 - weight decay: 2e-06
# Epoch 131/200
# [49/49] - 12s - train: { MAE (loss): 1.83 - RMSE: 4.13 - MAPE: 4.1% } - val: { MAE: 2.08 - RMSE: 4.7 - MAPE: 5.14% } - lr: 0.001 - weight decay: 2e-06
# Epoch 132/200
# [49/49] - 12s - train: { MAE (loss): 1.83 - RMSE: 4.14 - MAPE: 4.11% } - val: { MAE: 2.12 - RMSE: 4.76 - MAPE: 5.32% } - lr: 0.001 - weight decay: 2e-06
# Epoch 133/200
# [49/49] - 12s - train: { MAE (loss): 1.83 - RMSE: 4.14 - MAPE: 4.14% } - val: { MAE: 2.08 - RMSE: 4.76 - MAPE: 5.03% } - lr: 0.001 - weight decay: 2e-06
# Epoch 134/200
# [49/49] - 12s - train: { MAE (loss): 1.84 - RMSE: 4.16 - MAPE: 4.15% } - val: { MAE: 2.12 - RMSE: 4.79 - MAPE: 5.09% } - lr: 0.001 - weight decay: 2e-06
# Epoch 135/200
# [49/49] - 12s - train: { MAE (loss): 1.84 - RMSE: 4.15 - MAPE: 4.14% } - val: { MAE: 2.07 - RMSE: 4.71 - MAPE: 4.91% } - lr: 0.001 - weight decay: 2e-06
# Epoch 136/200
# [49/49] - 12s - train: { MAE (loss): 1.83 - RMSE: 4.12 - MAPE: 4.12% } - val: { MAE: 2.08 - RMSE: 4.71 - MAPE: 5.13% } - lr: 0.001 - weight decay: 2e-06
# Epoch 137/200
# [49/49] - 12s - train: { MAE (loss): 1.84 - RMSE: 4.12 - MAPE: 4.13% } - val: { MAE: 2.07 - RMSE: 4.7 - MAPE: 4.88% } - lr: 0.001 - weight decay: 2e-06
# Epoch 138/200
# [49/49] - 12s - train: { MAE (loss): 1.82 - RMSE: 4.1 - MAPE: 4.07% } - val: { MAE: 2.05 - RMSE: 4.65 - MAPE: 5% } - lr: 0.001 - weight decay: 2e-06
# Epoch 139/200
# [49/49] - 12s - train: { MAE (loss): 1.82 - RMSE: 4.1 - MAPE: 4.08% } - val: { MAE: 2.09 - RMSE: 4.78 - MAPE: 4.94% } - lr: 0.001 - weight decay: 2e-06
# Epoch 140/200
# [49/49] - 12s - train: { MAE (loss): 1.81 - RMSE: 4.09 - MAPE: 4.08% } - val: { MAE: 2.06 - RMSE: 4.67 - MAPE: 4.98% } - lr: 0.001 - weight decay: 2e-06
# Epoch 141/200
# [49/49] - 12s - train: { MAE (loss): 1.82 - RMSE: 4.1 - MAPE: 4.08% } - val: { MAE: 2.08 - RMSE: 4.8 - MAPE: 4.86% } - lr: 0.001 - weight decay: 2e-06
# Epoch 142/200
# [49/49] - 12s - train: { MAE (loss): 1.83 - RMSE: 4.14 - MAPE: 4.11% } - val: { MAE: 2.06 - RMSE: 4.7 - MAPE: 4.99% } - lr: 0.001 - weight decay: 2e-06
# Epoch 143/200
# [49/49] - 12s - train: { MAE (loss): 1.82 - RMSE: 4.11 - MAPE: 4.08% } - val: { MAE: 2.08 - RMSE: 4.77 - MAPE: 4.96% } - lr: 0.001 - weight decay: 2e-06
# Epoch 144/200
# [49/49] - 12s - train: { MAE (loss): 1.82 - RMSE: 4.1 - MAPE: 4.07% } - val: { MAE: 2.07 - RMSE: 4.74 - MAPE: 4.89% } - lr: 0.001 - weight decay: 2e-06
# Epoch 145/200
# [49/49] - 12s - train: { MAE (loss): 1.81 - RMSE: 4.09 - MAPE: 4.08% } - val: { MAE: 2.05 - RMSE: 4.71 - MAPE: 4.92% } - lr: 0.001 - weight decay: 2e-06
# Epoch 146/200
# [49/49] - 12s - train: { MAE (loss): 1.8 - RMSE: 4.07 - MAPE: 4.04% } - val: { MAE: 2.05 - RMSE: 4.66 - MAPE: 4.9% } - lr: 0.001 - weight decay: 2e-06
# Epoch 147/200
# [49/49] - 12s - train: { MAE (loss): 1.81 - RMSE: 4.1 - MAPE: 4.07% } - val: { MAE: 2.11 - RMSE: 4.89 - MAPE: 5.01% } - lr: 0.001 - weight decay: 2e-06
# Epoch 148/200
# [49/49] - 12s - train: { MAE (loss): 1.81 - RMSE: 4.09 - MAPE: 4.06% } - val: { MAE: 2.06 - RMSE: 4.73 - MAPE: 4.95% } - lr: 0.001 - weight decay: 2e-06
# Epoch 149/200
# [49/49] - 12s - train: { MAE (loss): 1.82 - RMSE: 4.1 - MAPE: 4.09% } - val: { MAE: 2.11 - RMSE: 4.77 - MAPE: 5.24% } - lr: 0.001 - weight decay: 2e-06
# Epoch 150/200
# [49/49] - 12s - train: { MAE (loss): 1.81 - RMSE: 4.08 - MAPE: 4.07% } - val: { MAE: 2.07 - RMSE: 4.72 - MAPE: 4.96% } - lr: 0.001 - weight decay: 2e-06
# Epoch 151/200
# [49/49] - 12s - train: { MAE (loss): 1.8 - RMSE: 4.07 - MAPE: 4.03% } - val: { MAE: 2.05 - RMSE: 4.7 - MAPE: 4.93% } - lr: 0.001 - weight decay: 2e-06
# Epoch 152/200
# [49/49] - 12s - train: { MAE (loss): 1.81 - RMSE: 4.09 - MAPE: 4.06% } - val: { MAE: 2.06 - RMSE: 4.68 - MAPE: 4.99% } - lr: 0.001 - weight decay: 2e-06
# Epoch 153/200
# [49/49] - 12s - train: { MAE (loss): 1.82 - RMSE: 4.1 - MAPE: 4.09% } - val: { MAE: 2.12 - RMSE: 4.76 - MAPE: 5.36% } - lr: 0.001 - weight decay: 2e-06
# Epoch 154/200
# [49/49] - 12s - train: { MAE (loss): 1.83 - RMSE: 4.1 - MAPE: 4.11% } - val: { MAE: 2.07 - RMSE: 4.67 - MAPE: 5.03% } - lr: 0.001 - weight decay: 2e-06
# Epoch 155/200
# [49/49] - 12s - train: { MAE (loss): 1.81 - RMSE: 4.09 - MAPE: 4.07% } - val: { MAE: 2.08 - RMSE: 4.77 - MAPE: 4.97% } - lr: 0.001 - weight decay: 2e-06
# Epoch 156/200
# [49/49] - 12s - train: { MAE (loss): 1.82 - RMSE: 4.09 - MAPE: 4.07% } - val: { MAE: 2.06 - RMSE: 4.65 - MAPE: 5.05% } - lr: 0.001 - weight decay: 2e-06
# Epoch 157/200
# [49/49] - 12s - train: { MAE (loss): 1.8 - RMSE: 4.05 - MAPE: 4.02% } - val: { MAE: 2.09 - RMSE: 4.86 - MAPE: 4.93% } - lr: 0.001 - weight decay: 2e-06
# Epoch 158/200
# [49/49] - 12s - train: { MAE (loss): 1.82 - RMSE: 4.1 - MAPE: 4.07% } - val: { MAE: 2.07 - RMSE: 4.67 - MAPE: 4.95% } - lr: 0.001 - weight decay: 2e-06
# Epoch 159/200
# [49/49] - 12s - train: { MAE (loss): 1.8 - RMSE: 4.07 - MAPE: 4.03% } - val: { MAE: 2.07 - RMSE: 4.7 - MAPE: 5.1% } - lr: 0.001 - weight decay: 2e-06
# Epoch 160/200
# [49/49] - 12s - train: { MAE (loss): 1.81 - RMSE: 4.1 - MAPE: 4.08% } - val: { MAE: 2.07 - RMSE: 4.74 - MAPE: 4.92% } - lr: 0.001 - weight decay: 2e-06
# Epoch 161/200
# [49/49] - 12s - train: { MAE (loss): 1.81 - RMSE: 4.08 - MAPE: 4.04% } - val: { MAE: 2.05 - RMSE: 4.73 - MAPE: 4.95% } - lr: 0.001 - weight decay: 2e-06
# Epoch 162/200
# [49/49] - 12s - train: { MAE (loss): 1.81 - RMSE: 4.08 - MAPE: 4.06% } - val: { MAE: 2.06 - RMSE: 4.66 - MAPE: 4.99% } - lr: 0.001 - weight decay: 2e-06
# Epoch 163/200
# [49/49] - 12s - train: { MAE (loss): 1.8 - RMSE: 4.07 - MAPE: 4.04% } - val: { MAE: 2.07 - RMSE: 4.66 - MAPE: 4.95% } - lr: 0.001 - weight decay: 2e-06
# Epoch 164/200
# [49/49] - 12s - train: { MAE (loss): 1.81 - RMSE: 4.06 - MAPE: 4.05% } - val: { MAE: 2.05 - RMSE: 4.65 - MAPE: 4.93% } - lr: 0.001 - weight decay: 2e-06
# Epoch 165/200
# [49/49] - 12s - train: { MAE (loss): 1.81 - RMSE: 4.07 - MAPE: 4.04% } - val: { MAE: 2.06 - RMSE: 4.66 - MAPE: 4.93% } - lr: 0.001 - weight decay: 2e-06
# Epoch 166/200
# [49/49] - 12s - train: { MAE (loss): 1.8 - RMSE: 4.06 - MAPE: 4.04% } - val: { MAE: 2.06 - RMSE: 4.67 - MAPE: 5% } - lr: 0.001 - weight decay: 2e-06
# Epoch 167/200
# [49/49] - 12s - train: { MAE (loss): 1.8 - RMSE: 4.07 - MAPE: 4.04% } - val: { MAE: 2.06 - RMSE: 4.72 - MAPE: 4.89% } - lr: 0.001 - weight decay: 2e-06
# Epoch 168/200
# [49/49] - 12s - train: { MAE (loss): 1.82 - RMSE: 4.1 - MAPE: 4.07% } - val: { MAE: 2.09 - RMSE: 4.72 - MAPE: 5.13% } - lr: 0.001 - weight decay: 2e-06
# Epoch 169/200
# [49/49] - 12s - train: { MAE (loss): 1.81 - RMSE: 4.08 - MAPE: 4.05% } - val: { MAE: 2.06 - RMSE: 4.71 - MAPE: 5.11% } - lr: 0.001 - weight decay: 2e-06
# Epoch 170/200
# [49/49] - 12s - train: { MAE (loss): 1.81 - RMSE: 4.07 - MAPE: 4.05% } - val: { MAE: 2.07 - RMSE: 4.78 - MAPE: 4.92% } - lr: 0.001 - weight decay: 2e-06
# Epoch 171/200
# [49/49] - 12s - train: { MAE (loss): 1.8 - RMSE: 4.07 - MAPE: 4.04% } - val: { MAE: 2.1 - RMSE: 4.84 - MAPE: 4.99% } - lr: 0.001 - weight decay: 2e-06
# Epoch 172/200
# [49/49] - 12s - train: { MAE (loss): 1.81 - RMSE: 4.09 - MAPE: 4.05% } - val: { MAE: 2.06 - RMSE: 4.68 - MAPE: 5.08% } - lr: 0.001 - weight decay: 2e-06
# Epoch 173/200
# [49/49] - 12s - train: { MAE (loss): 1.79 - RMSE: 4.04 - MAPE: 4.02% } - val: { MAE: 2.08 - RMSE: 4.76 - MAPE: 4.86% } - lr: 0.001 - weight decay: 2e-06
# Epoch 174/200
# [49/49] - 12s - train: { MAE (loss): 1.8 - RMSE: 4.06 - MAPE: 4.04% } - val: { MAE: 2.09 - RMSE: 4.71 - MAPE: 5.16% } - lr: 0.001 - weight decay: 2e-06
# Epoch 175/200
# [49/49] - 12s - train: { MAE (loss): 1.8 - RMSE: 4.04 - MAPE: 4.02% } - val: { MAE: 2.08 - RMSE: 4.8 - MAPE: 4.95% } - lr: 0.001 - weight decay: 2e-06
# Epoch 176/200
# [49/49] - 12s - train: { MAE (loss): 1.8 - RMSE: 4.05 - MAPE: 4.02% } - val: { MAE: 2.09 - RMSE: 4.75 - MAPE: 5.02% } - lr: 0.001 - weight decay: 2e-06
# Epoch 177/200
# [49/49] - 12s - train: { MAE (loss): 1.8 - RMSE: 4.07 - MAPE: 4.04% } - val: { MAE: 2.1 - RMSE: 4.83 - MAPE: 4.89% } - lr: 0.001 - weight decay: 2e-06
# Epoch 178/200
# [49/49] - 12s - train: { MAE (loss): 1.82 - RMSE: 4.11 - MAPE: 4.08% } - val: { MAE: 2.07 - RMSE: 4.74 - MAPE: 4.91% } - lr: 0.001 - weight decay: 2e-06
# Epoch 179/200
# [49/49] - 12s - train: { MAE (loss): 1.79 - RMSE: 4.03 - MAPE: 4.01% } - val: { MAE: 2.09 - RMSE: 4.73 - MAPE: 5.01% } - lr: 0.001 - weight decay: 2e-06
# Epoch 180/200
# [49/49] - 12s - train: { MAE (loss): 1.8 - RMSE: 4.05 - MAPE: 4.04% } - val: { MAE: 2.09 - RMSE: 4.74 - MAPE: 5.11% } - lr: 0.001 - weight decay: 2e-06
# Epoch 181/200
# [49/49] - 12s - train: { MAE (loss): 1.81 - RMSE: 4.09 - MAPE: 4.05% } - val: { MAE: 2.08 - RMSE: 4.66 - MAPE: 5.07% } - lr: 0.001 - weight decay: 2e-06
# Epoch 182/200
# [49/49] - 12s - train: { MAE (loss): 1.79 - RMSE: 4.02 - MAPE: 4% } - val: { MAE: 2.05 - RMSE: 4.64 - MAPE: 4.93% } - lr: 0.001 - weight decay: 2e-06
# Epoch 183/200
# [49/49] - 12s - train: { MAE (loss): 1.8 - RMSE: 4.04 - MAPE: 4.02% } - val: { MAE: 2.07 - RMSE: 4.64 - MAPE: 4.97% } - lr: 0.001 - weight decay: 2e-06
# Epoch 184/200
# [49/49] - 12s - train: { MAE (loss): 1.81 - RMSE: 4.09 - MAPE: 4.03% } - val: { MAE: 2.06 - RMSE: 4.66 - MAPE: 5.04% } - lr: 0.001 - weight decay: 2e-06
# Epoch 185/200
# [49/49] - 12s - train: { MAE (loss): 1.79 - RMSE: 4.03 - MAPE: 4% } - val: { MAE: 2.05 - RMSE: 4.67 - MAPE: 4.94% } - lr: 0.001 - weight decay: 2e-06
# Epoch 186/200
# [49/49] - 12s - train: { MAE (loss): 1.79 - RMSE: 4.02 - MAPE: 4% } - val: { MAE: 2.07 - RMSE: 4.71 - MAPE: 4.84% } - lr: 0.001 - weight decay: 2e-06
# Epoch 187/200
# [49/49] - 12s - train: { MAE (loss): 1.8 - RMSE: 4.05 - MAPE: 4.04% } - val: { MAE: 2.06 - RMSE: 4.62 - MAPE: 5% } - lr: 0.001 - weight decay: 2e-06
# Epoch 188/200
# [49/49] - 12s - train: { MAE (loss): 1.8 - RMSE: 4.05 - MAPE: 4.03% } - val: { MAE: 2.09 - RMSE: 4.71 - MAPE: 4.99% } - lr: 0.001 - weight decay: 2e-06
# Epoch 189/200
# [49/49] - 12s - train: { MAE (loss): 1.82 - RMSE: 4.09 - MAPE: 4.06% } - val: { MAE: 2.11 - RMSE: 4.76 - MAPE: 5% } - lr: 0.001 - weight decay: 2e-06
# Epoch 190/200
# [49/49] - 12s - train: { MAE (loss): 1.84 - RMSE: 4.12 - MAPE: 4.11% } - val: { MAE: 2.11 - RMSE: 4.81 - MAPE: 4.91% } - lr: 0.001 - weight decay: 2e-06
# Epoch 191/200
# [49/49] - 12s - train: { MAE (loss): 1.82 - RMSE: 4.1 - MAPE: 4.06% } - val: { MAE: 2.09 - RMSE: 4.77 - MAPE: 5.02% } - lr: 0.001 - weight decay: 2e-06
# Epoch 192/200
# [49/49] - 12s - train: { MAE (loss): 1.8 - RMSE: 4.06 - MAPE: 4.03% } - val: { MAE: 2.08 - RMSE: 4.73 - MAPE: 4.9% } - lr: 0.001 - weight decay: 2e-06
# Epoch 193/200
# [49/49] - 12s - train: { MAE (loss): 1.8 - RMSE: 4.05 - MAPE: 4.01% } - val: { MAE: 2.06 - RMSE: 4.78 - MAPE: 4.98% } - lr: 0.001 - weight decay: 2e-06
# Epoch 194/200
# [49/49] - 12s - train: { MAE (loss): 1.8 - RMSE: 4.05 - MAPE: 4.02% } - val: { MAE: 2.06 - RMSE: 4.69 - MAPE: 5.07% } - lr: 0.001 - weight decay: 2e-06
# Epoch 195/200
# [49/49] - 12s - train: { MAE (loss): 1.8 - RMSE: 4.05 - MAPE: 4.02% } - val: { MAE: 2.06 - RMSE: 4.75 - MAPE: 5.09% } - lr: 0.001 - weight decay: 2e-06
# Epoch 196/200
# [49/49] - 12s - train: { MAE (loss): 1.8 - RMSE: 4.06 - MAPE: 4.02% } - val: { MAE: 2.07 - RMSE: 4.69 - MAPE: 4.98% } - lr: 0.001 - weight decay: 2e-06
# Epoch 197/200
# [49/49] - 12s - train: { MAE (loss): 1.8 - RMSE: 4.05 - MAPE: 4.03% } - val: { MAE: 2.06 - RMSE: 4.69 - MAPE: 4.89% } - lr: 0.001 - weight decay: 2e-06
# Epoch 198/200
# [49/49] - 12s - train: { MAE (loss): 1.78 - RMSE: 4.01 - MAPE: 3.98% } - val: { MAE: 2.06 - RMSE: 4.7 - MAPE: 4.94% } - lr: 0.001 - weight decay: 2e-06
# Epoch 199/200
# [49/49] - 12s - train: { MAE (loss): 1.79 - RMSE: 4.04 - MAPE: 4% } - val: { MAE: 2.07 - RMSE: 4.72 - MAPE: 5.07% } - lr: 0.001 - weight decay: 2e-06
# Epoch 200/200
# [49/49] - 12s - train: { MAE (loss): 1.79 - RMSE: 4.02 - MAPE: 3.98% } - val: { MAE: 2.06 - RMSE: 4.71 - MAPE: 5.03% } - lr: 0.001 - weight decay: 2e-06

# %%
from src.spatial_temporal_gnn.training import plot_training_history

plot_training_history(history)

# %% [markdown]
# # 3 Evaluation and Error Analysis
# The model is finally evaluated on the test dataset and a brief error analysis is performed.

# %% [markdown]
# The trained model is evaluated on the test dataset, considering the error results on predictions of the next $15$, $30$ and $60$ minutes.
#
# As expected, predictions of closer events in term of time lead to lower errors.

# %%
from src.spatial_temporal_gnn.training import validate

test_mae_15_min, test_rmse_15_min, test_mape_15_min = validate(
    model, test_dataloader, scaler,
    DEVICE, 3)
print('Results on the test set considering the next 15 minutes:',
      f'MAE {test_mae_15_min:.3g} - RMSE {test_rmse_15_min:.3g}',
      f'- MAPE {test_mape_15_min * 100.:.3g} %')

test_mae_30_min, test_rmse_30_min, test_mape_30_min = validate(
    model, test_dataloader, scaler,
    DEVICE, 6)
print('Results on the test set considering the next 30 minutes:',
      f'MAE {test_mae_30_min:.3g} - RMSE {test_rmse_30_min:.3g}',
      f'- MAPE {test_mape_30_min * 100.:.3g} %')

test_mae_60_min, test_rmse_60_min, test_mape_60_min = validate(
    model, test_dataloader, scaler,
    DEVICE)
print('Results on the test set considering the next 60 minutes:',
      f'MAE {test_mae_60_min:.3g} - RMSE {test_rmse_60_min:.3g}',
      f'- MAPE {test_mape_60_min * 100.:.3g} %')
# Out:
# Results on the test set considering the next 15 minutes: MAE 1.2 - RMSE 2.5 - MAPE 2.49 %
# Results on the test set considering the next 30 minutes: MAE 1.5 - RMSE 3.36 - MAPE 3.27 %
# Results on the test set considering the next 60 minutes: MAE 1.92 - RMSE 4.44 - MAPE 4.49 %

# %%
from src.spatial_temporal_gnn.prediction import (
    get_ground_truth_and_predictions)

y_true, y_pred = get_ground_truth_and_predictions(
    model, test_dataloader, DEVICE, scaler, use_standardized_scale=False)

# %% [markdown]
# The next plot represents the comparison of ground truth speeds and predicted speeds in the test dataset for a series of randomly selected nodes and timestamps. We can observe that the model performs quite well, although some speed peaks and troughs are hardly predicted correctly.

# %%
from src.spatial_temporal_gnn.prediction import plot_results_comparison

plot_results_comparison(y_true, y_pred, ['Speed'])

# %% [markdown]
# Finally, we observe the scatter plot represents the fitness of ground truth speeds and predicted speeds in the test dataset for a series of randomly selected nodes and timestamps.
#
# It looks like that the error variation for lower speed nodes is higher than for slower speed ones. This is unexpected as the distribution of speed in the dataset is particularly left skewed. Probably the model put more effort in understanding patterns that guarnatee a contnuation of high speed over time.

# %%
from src.spatial_temporal_gnn.prediction import plot_results_fitness

plot_results_fitness(y_true, y_pred, ['Speed'])
