# %% [markdown]
# <center>
#     <h1>Verbal Explanation of Spatial Temporal GNNs for Traffic Forecasting</h1>
#     <h2>Building a STGNN for the Metr-LA dataset</h2>
#     <h3>Riccardo Spolaor</h3>
#     <h4>riccardo.spolaor@studio.unibo.it - rspolaor@tudelft.nl</h4>
# </center>
#
# ---
#
# In this notebook the *Spatial Temporal Graph Neural Network (STGNN)* proposed in the paper *Traffic Flow Prediction via Spatial Temporal Graph Neural Network* <a name="cite_paper"></a>[<sup>[1]</sup>](#note_paper) is built, trained and evaluated on the *Metr-LA* dataset.
#
# Firstly, the data is pre-processed for the task and its distribution is analysed. Next, the model is built and it is trained on the processed data. Finally the model is tested on a subset of the data not used in the training procedure.
#
# For more detailed informations about the used functions, look into the corresponding docstrings inside the python files, inside the `src` folder.
#
# The dataset used in the work is the one presented in the experiment providing the original benchmark, which code is available at the following link: https://github.com/liyaguang/DCRNN.
#
# The architecture of the model proposed for the task takes inspiration from the one provided at the following link: https://github.com/LMissher/STGNN. although it presents certain architectural differences.
#
# ---
# <small>
#
# <a name="note_paper"></a>[1] Xiaoyang Wang et al. “Traffic Flow Prediction via Spatial Temporal Graph Neural Network”. In:
# *Proceedings of The Web Conference 2020*. WWW ’20. Taipei, Taiwan: Association for Computing
# Machinery, 2020, pp. 1082–1092. ISBN: 9781450370233. DOI: 10.1145/3366423.3380186. URL:
# https://doi.org/10.1145/3366423.3380186.
#
# </small>

# %%
import sys
import os

# Set the main path in the root folder of the project.
sys.path.append(os.path.join('..'))

# %%
# Settings for autoreloading.
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from src.utils.seed import set_random_seed

# Set the random seed for deterministic operations.
SEED = 42
set_random_seed(SEED)

# %%
import torch

# Set the device for training and querying the model.
DEVICE = 'cuda' if torch.cuda.is_available() else 'cpu'
print(f'The selected device is: "{DEVICE}"')
# Out:
# The selected device is: "cuda"

# %% [markdown]
# DEPENDENCY Pytables

# %% [markdown]
# # 1 Data Preparation
# The ***Metr-LA*** dataset contains traffic information collected from loop detectors in the highway of Los Angeles County (Jagadish et al., 2014). A selection of $207$ sensors along with a 4 month span of data ranging from Mar $1^{st}$ $2012$ to Jun $30^{th}$ $2012$ is used in the experiment.
#
# The traffic speed readings are aggregated in $5$ minutes windows.
#
# The total number of observed traffic data points is $6,519,002$.

# %%
# Set the base data directory.
BASE_DATA_DIR = os.path.join('..', 'data', 'metr-la')

# %% [markdown]
# ## 1.1 Dataset Extraction and Preparation
# Firstly, the dataset illustrating the speed of the nodes at different timestamps is extracted along with the adjacency matrix containing the spatial correlation among the different nodes.
#
# Next, the time information is encoded and integrated in the dataset containing the node values in order to guarantee its format is suitable for the model operations.
#
# ---
# *Note: In order to obtain comparable results for the evaluation task, the speed information and the adjacency matrix computed distances consider the original metrics of the experiment (miles/hour and miles respectively).*

# %%
# Set the base data directory.
BASE_DATA_DIR = os.path.join('..', 'data', 'metr-la')

# %% [markdown]
# The obtained data has the following structure:
# * The node values dataset is in the form $\mathbb{R}^{T \times N \times F}$.
# * The adjacency matrix is in the form $\mathbb{R}^{N \times N}$.
#
# Where $T$ is the number of timestamps, $N$ is the number of nodes and $F$ the number of features.
#
# In this experiment the feature used for the *Metr-LA* dataset are in the order:
# * Speed in miles/hour observed by the node at a certain timestamp.
# * The encoded hour of the day of the observed speed.
# * The encoded minute of the our of the observed speed.

# %%
from src.data.data_extraction import get_node_values_dataframe

# Get the dataframe containing the node values at different timestamps.
node_values_df = get_node_values_dataframe(
    os.path.join(BASE_DATA_DIR, 'metr-la.h5'), turn_in_kmph=False)

# %%
from src.data.data_processing import get_node_values_numpy_matrix

# Set the methods in which the time is aggregated and encoded
TIME_AGGREGATIONS = [ 'time_of_day', 'day_of_week' ]

# Get the numpy matrix encoding the speed of the nodes and time
# information about the hour of the day and the minute of the hour.
node_values = get_node_values_numpy_matrix(
    node_values_df, time_aggregations=TIME_AGGREGATIONS)

# %%
# print(node_values[..., 5][2])

# %%
print('Shape of the node value matrix:', node_values.shape)
# Out:
# Shape of the node value matrix: (34272, 207, 9)

# %% [markdown]
# Finally, the data is divided into train, validation and test datasets which will be structured in other sections in order to meet the problem requisites.
#
# The adjacency matrix is built by exploiting the pairwise road network distances between sensors through a thresholded Gaussian kernel.
#
# $$
# W_{ij} = \begin{cases}
# \text{exp} \left ( - \frac{\text{dist}(v_i - v_j)^2}{\sigma^2} \right ) & \text{if} \ \leq k \\
# 0 & \text{otherwise}\\
# \end{cases}
# $$
#
# Where $W_{ij}$ represents the edge weight between sensor $v_i$ and sensor $v_j$, $\text{dist}(v_i - v_j)$ denotes the road network distance from sensor $v_i$ to sensor $v_j$ . $\sigma$ is the standard deviation of distances and $k$ ($0.1$ in the original experiment) is the threshold.

# %%
from src.data.data_extraction import get_adjacency_matrix

# Get the adjacency matrix
adj_matrix_structure = get_adjacency_matrix(
    os.path.join(BASE_DATA_DIR, 'adj_mx_metr_la.pkl'))

# Get the header of the adjacency matrix and the matrix itself.
header, _, adj_matrix = adj_matrix_structure

# %%
# Assert that the adjacency matrix header nodes order corresponds to
# the order of the columns node header of the node values dataframe.
assert all(header == node_values_df.columns.values), \
'The columns of the node values dataframe are not ordered in the ' +\
'same fashion as the adjacency matrix header.'

# %%
print('Shape of the adjacency matrix:', adj_matrix.shape)
# Out:
# Shape of the adjacency matrix: (207, 207)

# %% [markdown]
# The dataset is split in *train*, *validation* and *test*, following the ratios $0.7$ $0.1$ and $0.2$ respectively.

# %%
from src.data.dataset_builder import train_test_val_split

# Split the dataset in train, validation and test.
train_dataset, val_dataset, test_dataset = train_test_val_split(
    node_values, test_size=.2, val_size=.1)

# %% [markdown]
# ## 1.2 Data Pre-Processing
# In this section the data is preprocessed in order to better fit the model structure.
#
# The data standardization procedure is explained, and the datasets are divided in input data and ground truth data for the self-supervised regression task through the use of a sliding window.

# %% [markdown]
# First of all, a `scaler` is created to apply *Standard Scaling* to the data. This procedure leads the model to better performances.
#
# Given an instance $x$ and considering that a feature of $x$ is denoted as $x_f$, its processed version $x'_f$ is obtained as:
# $$ \forall \ f \ \text{of} \ x, \ x'_f = \frac{x_f - \mu_f}{\sigma_f}$$
# Where $\mu_f$ is the mean of the feature $f$ and $\sigma_f$ its standard deviation.
#
# The mean and standard deviation are estimated on the data that is used for training the model.

# %%
from src.data.data_processing import Scaler

# Fit the standard scaler with the train_dataset values.
scaler = Scaler(torch.tensor(train_dataset, dtype=torch.float32),
                has_day_of_week=True)

# %%
import pickle

with open(os.path.join(BASE_DATA_DIR, 'processed', 'scaler.pkl'), 'wb') as f:
    pickle.dump(scaler, f)

# %%
print('The scaler mean values:', scaler.mean.cpu().numpy())
print('The scaler standard deviation values:', scaler.std.cpu().numpy())
# Out:
# The scaler mean values: [54.401062    0.49733332  0.          0.          0.          0.
#   0.          0.          0.        ]
# The scaler standard deviation values: [19.416021  0.28861   1.        1.        1.        1.        1.
#   1.        1.      ]

# %% [markdown]
# The statistics of the original training data are observed.
#
# We can see that in the original data no feature has mean in $0$ and standard deviation in $1$ and it is hence no normalized. By observing the distribution of the features, it is clear how the `speed` feature presents a left skewed normal distribution. This is expected, as speed in highways tend to be closer to high values than to lower speeds. The high peak on $0$ is due to the large amount of missing values in the dataset.
#
# The features encoding time present a uniform distribution. This is also an expected behavior as the train dataset covers a large period of time and present a timestamp every $5$ minutes without skipping any specific day or hour of the day.

# %%
from src.data.data_analysis import get_node_values_statistics_dataframe

statistics_df = get_node_values_statistics_dataframe(
    train_dataset, feature_names=['speed', 'time of the day',
                                  'day of the week'],
    has_day_of_the_week=True)

# %%
statistics_df.describe()
# Out:
#               speed  time of the day  day of the week
# count  5.107725e+06     5.107725e+06     5.107725e+06
# mean   5.440107e+01     4.973333e-01     3.007903e+00
# std    1.941602e+01     2.886100e-01     1.982308e+00
# min    0.000000e+00     0.000000e+00     0.000000e+00
# 25%    5.400000e+01     2.466991e-01     1.000000e+00
# 50%    6.250000e+01     4.968728e-01     3.000000e+00
# 75%    6.625000e+01     7.470466e-01     5.000000e+00
# max    7.000000e+01     9.972203e-01     6.000000e+00

# %%
from src.data.data_analysis import plot_features_distribution

plot_features_distribution(
    statistics_df, bins=[200, 24 + 60 // 5, 7], 
    x_labels=['Speed (miles/h)', 'Encoded time of the day',
              'Encoded day of the week'],
    title='Distribution of the training features.')

# %%
# Scale the train dataset through standard scaling.
scaled_train_dataset = scaler.scale(
    torch.tensor(train_dataset, dtype=torch.float32))

# %% [markdown]
# The statistics of the scaled training data are observed.
#
# The distributions are the same as the ones present in the un-scaled dataset, although we can observe that every variable has mean in $0$ and standard deviation in $1$ and it is thus normalized.

# %%
from src.data.data_analysis import get_node_values_statistics_dataframe

statistics_df = get_node_values_statistics_dataframe(
    scaled_train_dataset, feature_names=['speed', 'time of the day',
                                         'day of the week'],
    has_day_of_the_week=True)

# %%
statistics_df.describe()
# Out:
#               speed  time of the day  day of the week
# count  5.107725e+06     5.107725e+06     5.107725e+06
# mean   4.333645e-07    -7.225194e-08     3.007903e+00
# std    1.000000e+00     1.000000e+00     1.982308e+00
# min   -2.801865e+00    -1.723202e+00     0.000000e+00
# 25%   -2.065624e-02    -8.684183e-01     1.000000e+00
# 50%    4.171265e-01    -1.595494e-03     3.000000e+00
# 75%    6.102660e-01     8.652273e-01     5.000000e+00
# max    8.034055e-01     1.732050e+00     6.000000e+00

# %%
from src.data.data_analysis import plot_features_distribution

plot_features_distribution(
    statistics_df, bins=[200, 24 + 60 // 5, 7], 
    x_labels=['Scaled speed (miles/h)', 'Scaled encoded time of the day',
              'Scaled encoded day of the week'],
    title='Distribution of the training features after scaling.')

# %% [markdown]
# Next, a sliding window of size $(T_{in} + T_{out})$ is applied to each dataset, in order to obtain a self-supervised version of it, where in each window:
# * The first $T_{in}$ elements are part of the input variables.
# * The last $T_{out}$ elements are part of the ground truth.
#
# For the experiment, both $T_{in}$ and $T_{out}$ are set to $12$

# %%
# Set the number of input and output timesteps.
N_IN_TIMESTEPS = 12
N_OUT_TIMESTEPS = 12

# %%
from src.data.data_processing import get_dataset_by_sliding_window

# Get self-supervised training validation and test sets.
x_train, y_train = get_dataset_by_sliding_window(
    train_dataset, x_stepsize=N_IN_TIMESTEPS, y_stepsize=N_OUT_TIMESTEPS)
x_val, y_val = get_dataset_by_sliding_window(
    val_dataset, x_stepsize=N_IN_TIMESTEPS, y_stepsize=N_OUT_TIMESTEPS)
x_test, y_test = get_dataset_by_sliding_window(
    test_dataset, x_stepsize=N_IN_TIMESTEPS, y_stepsize=N_OUT_TIMESTEPS)

# %%
print('Train dataset shapes:', x_train.shape, y_train.shape)
print('Validation dataset shapes:', x_val.shape, y_val.shape)
print('Test dataset shapes:', x_test.shape, y_test.shape)
# Out:
# Train dataset shapes: (1028, 12, 207, 9) (1028, 12, 207, 9)
# Validation dataset shapes: (114, 12, 207, 9) (114, 12, 207, 9)
# Test dataset shapes: (285, 12, 207, 9) (285, 12, 207, 9)

# %% [markdown]
# The time encoding features are removed from the ground truth data, as we are interested in predicting solely the speed value.
#
# Thus the resulting datasets have the shape:
# * $x \in \mathbb{R}^{T \times N \times (1 + F)}$
# * $y \in \mathbb{R}^{T \times N \times 1}$
#
# Where $x$ is the input data and $y$ the ground truth of the train, validation or test dataset. $T$ corresponds to the number of timesteps, $N$ to the number of nodes and $F$ indicates the amount of features that represent an encoding of the time steps.

# %%
# Remove the time encoding features from the ground truth.
y_train = y_train[..., :1]
y_val = y_val[..., :1]
y_test = y_test[..., :1]

# %%
print('Adjusted train dataset shapes:', x_train.shape, y_train.shape)
print('Adjusted validation dataset shapes:', x_val.shape, y_val.shape)
print('Adjusted test dataset shapes:', x_test.shape, y_test.shape)
# Out:
# Adjusted train dataset shapes: (1028, 12, 207, 9) (1028, 12, 207, 1)
# Adjusted validation dataset shapes: (114, 12, 207, 9) (114, 12, 207, 1)
# Adjusted test dataset shapes: (285, 12, 207, 9) (285, 12, 207, 1)

# %%
from numpy import save

# Save the processed datasets.
save(os.path.join(BASE_DATA_DIR, 'processed', 'x_train.npy'), x_train)
save(os.path.join(BASE_DATA_DIR, 'processed', 'y_train.npy'), y_train)
save(os.path.join(BASE_DATA_DIR, 'processed', 'x_val.npy'), x_val)
save(os.path.join(BASE_DATA_DIR, 'processed', 'y_val.npy'), y_val)
save(os.path.join(BASE_DATA_DIR, 'processed', 'x_test.npy'), x_test)
save(os.path.join(BASE_DATA_DIR, 'processed', 'y_test.npy'), y_test)

# %% [markdown]
# # 2 Model definition and training procedure
# In this section the model is defined and the training procedure is performed.

# %% [markdown]
# ## 2.1 Model definition
# The *Spatial Temporal Graph Neural Network* model is created.
#
# Its aim is to predict future traffic speed for each node of the graph according to historical speed information.
# In particular, it predicts the next $T_{out}$ consecutive time representations of the graph with respect to the previous consecutive $T_{in}$ historical representations of the graph.
#
# The model architecture consists in:
# * An encoder that extracts hidden features from the input sequence of graphs.
# * A series of *Spatial Graph Neural Network (S-GNN)* blocks, that extract information by modeling the spatial structure of each input instance of the graph with respect to the feature information. Furthermore, the adjacency matrix is used to help in the task.
# * A series of *Gated Recurrent Units (GRU)* blocks to extract information about the temporal realtion among successive time steps of the input graphs. The resulting output of a *GRU* block is passed as the hidden input state of the next *GRU* block and processed along with the next time step of the graph. The output of each *GRU* block is processed through a *S-GNN* block before being given to the next *GRU* block.
# * A *Transformer* block performing *Multi-Head Attention* in order to compute the global temporal relation among each time step. The outputs of the *GRU* are stacked together and concatenated with their *positional encoding*.
# * A *multi layer* regression head to infer the speed of the output $T_{out}$ sequences.
# <center>
#
# ![](../images/stgnn.png)
#
# </center>

# %%
from src.spatial_temporal_gnn.model import SpatialTemporalGNN

model = SpatialTemporalGNN(9, 1, N_IN_TIMESTEPS, N_OUT_TIMESTEPS, adj_matrix,
                           DEVICE, 64)

# %%
from torchinfo import summary

print(summary(model, input_size=(64, *x_train.shape[1:])))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# SpatialTemporalGNN                       [64, 12, 207, 1]          --
# ├─Linear: 1-1                            [64, 12, 207, 64]         576
# ├─ModuleList: 1-34                       --                        (recursive)
# │    └─S_GNN: 2-1                        [64, 207, 64]             --
# │    │    └─Sequential: 3-1              [64, 207, 32]             6,144
# │    │    └─Linear: 3-2                  [64, 207, 64]             4,096
# ├─ModuleList: 1-36                       --                        (recursive)
# │    └─GRU: 2-2                          [64, 207, 64]             --
# │    │    └─Linear: 3-3                  [64, 207, 64]             4,096
# │    │    └─Linear: 3-4                  [64, 207, 64]             4,096
# │    │    └─Linear: 3-5                  [64, 207, 64]             4,096
# │    │    └─Linear: 3-6                  [64, 207, 64]             4,096
# │    │    └─Linear: 3-7                  [64, 207, 64]             4,096
# │    │    └─Linear: 3-8                  [64, 207, 64]             4,096
# ├─ModuleList: 1-34                       --                        (recursive)
# │    └─S_GNN: 2-3                        [64, 207, 64]             --
# │    │    └─Sequential: 3-9              [64, 207, 32]             6,144
# │    │    └─Linear: 3-10                 [64, 207, 64]             4,096
# ├─ModuleList: 1-35                       --                        (recursive)
# │    └─S_GNN: 2-4                        [64, 207, 64]             --
# │    │    └─Sequential: 3-11             [64, 207, 32]             6,144
# │    │    └─Linear: 3-12                 [64, 207, 64]             4,096
# ├─ModuleList: 1-36                       --                        (recursive)
# │    └─GRU: 2-5                          [64, 207, 64]             --
# │    │    └─Linear: 3-13                 [64, 207, 64]             4,096
# │    │    └─Linear: 3-14                 [64, 207, 64]             4,096
# │    │    └─Linear: 3-15                 [64, 207, 64]             4,096
# │    │    └─Linear: 3-16                 [64, 207, 64]             4,096
# │    │    └─Linear: 3-17                 [64, 207, 64]             4,096
# │    │    └─Linear: 3-18                 [64, 207, 64]             4,096
# ├─ModuleList: 1-34                       --                        (recursive)
# │    └─S_GNN: 2-6                        [64, 207, 64]             --
# │    │    └─Sequential: 3-19             [64, 207, 32]             6,144
# │    │    └─Linear: 3-20                 [64, 207, 64]             4,096
# ├─ModuleList: 1-35                       --                        (recursive)
# │    └─S_GNN: 2-7                        [64, 207, 64]             --
# │    │    └─Sequential: 3-21             [64, 207, 32]             6,144
# │    │    └─Linear: 3-22                 [64, 207, 64]             4,096
# ├─ModuleList: 1-36                       --                        (recursive)
# │    └─GRU: 2-8                          [64, 207, 64]             --
# │    │    └─Linear: 3-23                 [64, 207, 64]             4,096
# │    │    └─Linear: 3-24                 [64, 207, 64]             4,096
# │    │    └─Linear: 3-25                 [64, 207, 64]             4,096
# │    │    └─Linear: 3-26                 [64, 207, 64]             4,096
# │    │    └─Linear: 3-27                 [64, 207, 64]             4,096
# │    │    └─Linear: 3-28                 [64, 207, 64]             4,096
# ├─ModuleList: 1-34                       --                        (recursive)
# │    └─S_GNN: 2-9                        [64, 207, 64]             --
# │    │    └─Sequential: 3-29             [64, 207, 32]             6,144
# │    │    └─Linear: 3-30                 [64, 207, 64]             4,096
# ├─ModuleList: 1-35                       --                        (recursive)
# │    └─S_GNN: 2-10                       [64, 207, 64]             --
# │    │    └─Sequential: 3-31             [64, 207, 32]             6,144
# │    │    └─Linear: 3-32                 [64, 207, 64]             4,096
# ├─ModuleList: 1-36                       --                        (recursive)
# │    └─GRU: 2-11                         [64, 207, 64]             --
# │    │    └─Linear: 3-33                 [64, 207, 64]             4,096
# │    │    └─Linear: 3-34                 [64, 207, 64]             4,096
# │    │    └─Linear: 3-35                 [64, 207, 64]             4,096
# │    │    └─Linear: 3-36                 [64, 207, 64]             4,096
# │    │    └─Linear: 3-37                 [64, 207, 64]             4,096
# │    │    └─Linear: 3-38                 [64, 207, 64]             4,096
# ├─ModuleList: 1-34                       --                        (recursive)
# │    └─S_GNN: 2-12                       [64, 207, 64]             --
# │    │    └─Sequential: 3-39             [64, 207, 32]             6,144
# │    │    └─Linear: 3-40                 [64, 207, 64]             4,096
# ├─ModuleList: 1-35                       --                        (recursive)
# │    └─S_GNN: 2-13                       [64, 207, 64]             --
# │    │    └─Sequential: 3-41             [64, 207, 32]             6,144
# │    │    └─Linear: 3-42                 [64, 207, 64]             4,096
# ├─ModuleList: 1-36                       --                        (recursive)
# │    └─GRU: 2-14                         [64, 207, 64]             --
# │    │    └─Linear: 3-43                 [64, 207, 64]             4,096
# │    │    └─Linear: 3-44                 [64, 207, 64]             4,096
# │    │    └─Linear: 3-45                 [64, 207, 64]             4,096
# │    │    └─Linear: 3-46                 [64, 207, 64]             4,096
# │    │    └─Linear: 3-47                 [64, 207, 64]             4,096
# │    │    └─Linear: 3-48                 [64, 207, 64]             4,096
# ├─ModuleList: 1-34                       --                        (recursive)
# │    └─S_GNN: 2-15                       [64, 207, 64]             --
# │    │    └─Sequential: 3-49             [64, 207, 32]             6,144
# │    │    └─Linear: 3-50                 [64, 207, 64]             4,096
# ├─ModuleList: 1-35                       --                        (recursive)
# │    └─S_GNN: 2-16                       [64, 207, 64]             --
# │    │    └─Sequential: 3-51             [64, 207, 32]             6,144
# │    │    └─Linear: 3-52                 [64, 207, 64]             4,096
# ├─ModuleList: 1-36                       --                        (recursive)
# │    └─GRU: 2-17                         [64, 207, 64]             --
# │    │    └─Linear: 3-53                 [64, 207, 64]             4,096
# │    │    └─Linear: 3-54                 [64, 207, 64]             4,096
# │    │    └─Linear: 3-55                 [64, 207, 64]             4,096
# │    │    └─Linear: 3-56                 [64, 207, 64]             4,096
# │    │    └─Linear: 3-57                 [64, 207, 64]             4,096
# │    │    └─Linear: 3-58                 [64, 207, 64]             4,096
# ├─ModuleList: 1-34                       --                        (recursive)
# │    └─S_GNN: 2-18                       [64, 207, 64]             --
# │    │    └─Sequential: 3-59             [64, 207, 32]             6,144
# │    │    └─Linear: 3-60                 [64, 207, 64]             4,096
# ├─ModuleList: 1-35                       --                        (recursive)
# │    └─S_GNN: 2-19                       [64, 207, 64]             --
# │    │    └─Sequential: 3-61             [64, 207, 32]             6,144
# │    │    └─Linear: 3-62                 [64, 207, 64]             4,096
# ├─ModuleList: 1-36                       --                        (recursive)
# │    └─GRU: 2-20                         [64, 207, 64]             --
# │    │    └─Linear: 3-63                 [64, 207, 64]             4,096
# │    │    └─Linear: 3-64                 [64, 207, 64]             4,096
# │    │    └─Linear: 3-65                 [64, 207, 64]             4,096
# │    │    └─Linear: 3-66                 [64, 207, 64]             4,096
# │    │    └─Linear: 3-67                 [64, 207, 64]             4,096
# │    │    └─Linear: 3-68                 [64, 207, 64]             4,096
# ├─ModuleList: 1-34                       --                        (recursive)
# │    └─S_GNN: 2-21                       [64, 207, 64]             --
# │    │    └─Sequential: 3-69             [64, 207, 32]             6,144
# │    │    └─Linear: 3-70                 [64, 207, 64]             4,096
# ├─ModuleList: 1-35                       --                        (recursive)
# │    └─S_GNN: 2-22                       [64, 207, 64]             --
# │    │    └─Sequential: 3-71             [64, 207, 32]             6,144
# │    │    └─Linear: 3-72                 [64, 207, 64]             4,096
# ├─ModuleList: 1-36                       --                        (recursive)
# │    └─GRU: 2-23                         [64, 207, 64]             --
# │    │    └─Linear: 3-73                 [64, 207, 64]             4,096
# │    │    └─Linear: 3-74                 [64, 207, 64]             4,096
# │    │    └─Linear: 3-75                 [64, 207, 64]             4,096
# │    │    └─Linear: 3-76                 [64, 207, 64]             4,096
# │    │    └─Linear: 3-77                 [64, 207, 64]             4,096
# │    │    └─Linear: 3-78                 [64, 207, 64]             4,096
# ├─ModuleList: 1-34                       --                        (recursive)
# │    └─S_GNN: 2-24                       [64, 207, 64]             --
# │    │    └─Sequential: 3-79             [64, 207, 32]             6,144
# │    │    └─Linear: 3-80                 [64, 207, 64]             4,096
# ├─ModuleList: 1-35                       --                        (recursive)
# │    └─S_GNN: 2-25                       [64, 207, 64]             --
# │    │    └─Sequential: 3-81             [64, 207, 32]             6,144
# │    │    └─Linear: 3-82                 [64, 207, 64]             4,096
# ├─ModuleList: 1-36                       --                        (recursive)
# │    └─GRU: 2-26                         [64, 207, 64]             --
# │    │    └─Linear: 3-83                 [64, 207, 64]             4,096
# │    │    └─Linear: 3-84                 [64, 207, 64]             4,096
# │    │    └─Linear: 3-85                 [64, 207, 64]             4,096
# │    │    └─Linear: 3-86                 [64, 207, 64]             4,096
# │    │    └─Linear: 3-87                 [64, 207, 64]             4,096
# │    │    └─Linear: 3-88                 [64, 207, 64]             4,096
# ├─ModuleList: 1-34                       --                        (recursive)
# │    └─S_GNN: 2-27                       [64, 207, 64]             --
# │    │    └─Sequential: 3-89             [64, 207, 32]             6,144
# │    │    └─Linear: 3-90                 [64, 207, 64]             4,096
# ├─ModuleList: 1-35                       --                        (recursive)
# │    └─S_GNN: 2-28                       [64, 207, 64]             --
# │    │    └─Sequential: 3-91             [64, 207, 32]             6,144
# │    │    └─Linear: 3-92                 [64, 207, 64]             4,096
# ├─ModuleList: 1-36                       --                        (recursive)
# │    └─GRU: 2-29                         [64, 207, 64]             --
# │    │    └─Linear: 3-93                 [64, 207, 64]             4,096
# │    │    └─Linear: 3-94                 [64, 207, 64]             4,096
# │    │    └─Linear: 3-95                 [64, 207, 64]             4,096
# │    │    └─Linear: 3-96                 [64, 207, 64]             4,096
# │    │    └─Linear: 3-97                 [64, 207, 64]             4,096
# │    │    └─Linear: 3-98                 [64, 207, 64]             4,096
# ├─ModuleList: 1-34                       --                        (recursive)
# │    └─S_GNN: 2-30                       [64, 207, 64]             --
# │    │    └─Sequential: 3-99             [64, 207, 32]             6,144
# │    │    └─Linear: 3-100                [64, 207, 64]             4,096
# ├─ModuleList: 1-35                       --                        (recursive)
# │    └─S_GNN: 2-31                       [64, 207, 64]             --
# │    │    └─Sequential: 3-101            [64, 207, 32]             6,144
# │    │    └─Linear: 3-102                [64, 207, 64]             4,096
# ├─ModuleList: 1-36                       --                        (recursive)
# │    └─GRU: 2-32                         [64, 207, 64]             --
# │    │    └─Linear: 3-103                [64, 207, 64]             4,096
# │    │    └─Linear: 3-104                [64, 207, 64]             4,096
# │    │    └─Linear: 3-105                [64, 207, 64]             4,096
# │    │    └─Linear: 3-106                [64, 207, 64]             4,096
# │    │    └─Linear: 3-107                [64, 207, 64]             4,096
# │    │    └─Linear: 3-108                [64, 207, 64]             4,096
# ├─ModuleList: 1-34                       --                        (recursive)
# │    └─S_GNN: 2-33                       [64, 207, 64]             --
# │    │    └─Sequential: 3-109            [64, 207, 32]             6,144
# │    │    └─Linear: 3-110                [64, 207, 64]             4,096
# ├─ModuleList: 1-35                       --                        (recursive)
# │    └─S_GNN: 2-34                       [64, 207, 64]             --
# │    │    └─Sequential: 3-111            [64, 207, 32]             6,144
# │    │    └─Linear: 3-112                [64, 207, 64]             4,096
# ├─ModuleList: 1-36                       --                        (recursive)
# │    └─GRU: 2-35                         [64, 207, 64]             --
# │    │    └─Linear: 3-113                [64, 207, 64]             4,096
# │    │    └─Linear: 3-114                [64, 207, 64]             4,096
# │    │    └─Linear: 3-115                [64, 207, 64]             4,096
# │    │    └─Linear: 3-116                [64, 207, 64]             4,096
# │    │    └─Linear: 3-117                [64, 207, 64]             4,096
# │    │    └─Linear: 3-118                [64, 207, 64]             4,096
# ├─PositionalEncoder: 1-37                [64, 12, 207, 64]         --
# ├─Transformer: 1-38                      [64, 12, 207, 64]         --
# │    └─Linear: 2-36                      [64, 12, 207, 64]         4,096
# │    └─Linear: 2-37                      [64, 12, 207, 64]         4,096
# │    └─Linear: 2-38                      [64, 12, 207, 64]         4,096
# │    └─BatchNorm2d: 2-39                 [64, 12, 207, 64]         24
# │    └─Sequential: 2-40                  [64, 12, 207, 64]         --
# │    │    └─Linear: 3-119                [64, 12, 207, 64]         4,096
# │    │    └─ReLU: 3-120                  [64, 12, 207, 64]         --
# │    │    └─Linear: 3-121                [64, 12, 207, 64]         4,096
# │    └─BatchNorm2d: 2-41                 [64, 12, 207, 64]         24
# ├─Sequential: 1-39                       [64, 12, 207, 1]          --
# │    └─Linear: 2-42                      [64, 12, 207, 64]         4,096
# │    └─ReLU: 2-43                        [64, 12, 207, 64]         --
# │    └─Linear: 2-44                      [64, 12, 207, 1]          64
# ==========================================================================================
# Total params: 555,696
# Trainable params: 555,696
# Non-trainable params: 0
# Total mult-adds (M): 35.56
# ==========================================================================================
# Input size (MB): 5.72
# Forward/backward pass size (MB): 1612.23
# Params size (MB): 2.22
# Estimated Total Size (MB): 1620.17
# ==========================================================================================
# c:\Users\riccardo\AppData\Local\Programs\Python\Python310\lib\site-packages\torchinfo\torchinfo.py:477: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   action_fn=lambda data: sys.getsizeof(data.storage()),
# c:\Users\riccardo\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\storage.py:665: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return super().__sizeof__() + self.nbytes()

# %% [markdown]
# ## 2.2 Training procedure
# In this section the training of the model is performed. In addition, the train validation and test dataloaders are built and the important parameters and training utilities are set.

# %% [markdown]
# The train, validation and test dataloaders are built. Solely the data of the train dataloader is shuffled, in order for the model to overfit less, guaranteeing a more generalized training procedure.

# %%
from src.data.dataloaders import get_dataloader

train_dataloader = get_dataloader(x_train, y_train, batch_size=64,
                                  shuffle=True)
val_dataloader = get_dataloader(x_val, y_val, batch_size=64,
                                shuffle=False)
test_dataloader = get_dataloader(x_test, y_test, batch_size=64,
                                 shuffle=False)

# %% [markdown]
# The training utilities and parameters are assigned.
# * `Adam` is used as an optimizer with learning rate $1e-3$ and weight decay $2e-6$.
# * A checkpoint monitor is initialized to control the performances of the model on the validation set, by saving the best resulting weights which consist in the minimal error computed as the sum of the *Mean Absolute Error (MAE)*, the *Root Mean Squared Error (RMSE)* and the *Mean Absolute Percentage Error (MAPE)*.
# * The number of *epochs* is set to $200$.

# %%
from src.spatial_temporal_gnn.training import Checkpoint

optimizer = torch.optim.Adam(model.parameters(), lr=1e-3, weight_decay=2e-6)

lr_scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
    optimizer, mode='min', factor=.1, patience=10, verbose=False,
    threshold=.001, threshold_mode='rel', cooldown=0, min_lr=1e-3, eps=1e-08)

checkpoint_file_path = os.path.join('..', 'models', 'checkpoints',
                                    'st_gnn_metr_la.pth')
checkpoint = Checkpoint(checkpoint_file_path)

EPOCHS = 200

# %% [markdown]
# The training procedure is performed. The loss criterion is the *Mean Absolute Error (MAE)* computed on the unscaled speed predictins and ground truths.
#
# Even the *Root Mean Squared Error (RMSE)* and the *Mean Absolute Percentage Error (MAPE)* are tracked which respect to the train and validation prediction performances.
#
# The model is trained on scaled data and evaluated on unscaled data. The reason behind this decision is found in the increased performance of the model under this situation. Furthermore, the computation of the loss function on unscaled data consists in a more severe error penality and a more faithful comparison to the results of the original experiment.

# %%
from src.spatial_temporal_gnn.training import train

history = train(model, optimizer, train_dataloader, val_dataloader, scaler,
                EPOCHS, DEVICE, checkpoint=checkpoint, 
                lr_scheduler=lr_scheduler, reload_best_weights=True)
# Out:
# Epoch 1/200
# [17/17] - 4s - train: { MAE (loss): 8.14 - RMSE: 13.1 - MAPE: 26.2% } - val: { MAE: 6.82 - RMSE: 11.8 - MAPE: 22.8% } - lr: 0.001 - weight decay: 2e-06
# Epoch 2/200
# [17/17] - 4s - train: { MAE (loss): 6.51 - RMSE: 11.4 - MAPE: 22.1% } - val: { MAE: 5.51 - RMSE: 9.83 - MAPE: 16.6% } - lr: 0.001 - weight decay: 2e-06
# Epoch 3/200
# [17/17] - 4s - train: { MAE (loss): 5.22 - RMSE: 9.43 - MAPE: 15.3% } - val: { MAE: 5.06 - RMSE: 9.61 - MAPE: 13.7% } - lr: 0.001 - weight decay: 2e-06
# Epoch 4/200
# [17/17] - 4s - train: { MAE (loss): 4.9 - RMSE: 9.13 - MAPE: 14.1% } - val: { MAE: 4.49 - RMSE: 8.98 - MAPE: 11.9% } - lr: 0.001 - weight decay: 2e-06
# Epoch 5/200
# [17/17] - 4s - train: { MAE (loss): 4.41 - RMSE: 8.38 - MAPE: 12.6% } - val: { MAE: 4.28 - RMSE: 8.49 - MAPE: 11.7% } - lr: 0.001 - weight decay: 2e-06
# Epoch 6/200
# [17/17] - 4s - train: { MAE (loss): 4.23 - RMSE: 8.36 - MAPE: 11.9% } - val: { MAE: 4.02 - RMSE: 8.19 - MAPE: 10.9% } - lr: 0.001 - weight decay: 2e-06
# Epoch 7/200
# [17/17] - 4s - train: { MAE (loss): 4.31 - RMSE: 8.45 - MAPE: 12.7% } - val: { MAE: 4.2 - RMSE: 8.16 - MAPE: 11.1% } - lr: 0.001 - weight decay: 2e-06
# Epoch 8/200
# [17/17] - 4s - train: { MAE (loss): 4.22 - RMSE: 8.14 - MAPE: 12.2% } - val: { MAE: 3.84 - RMSE: 8.16 - MAPE: 10.3% } - lr: 0.001 - weight decay: 2e-06
# Epoch 9/200
# [17/17] - 4s - train: { MAE (loss): 4.1 - RMSE: 8.21 - MAPE: 11.7% } - val: { MAE: 3.75 - RMSE: 7.65 - MAPE: 11% } - lr: 0.001 - weight decay: 2e-06
# Epoch 10/200
# [17/17] - 3s - train: { MAE (loss): 4.07 - RMSE: 8.05 - MAPE: 11.7% } - val: { MAE: 3.75 - RMSE: 7.65 - MAPE: 10.6% } - lr: 0.001 - weight decay: 2e-06
# Epoch 11/200
# [17/17] - 4s - train: { MAE (loss): 4.09 - RMSE: 8.1 - MAPE: 11.8% } - val: { MAE: 3.82 - RMSE: 7.45 - MAPE: 10.5% } - lr: 0.001 - weight decay: 2e-06
# Epoch 12/200
# [17/17] - 4s - train: { MAE (loss): 4.1 - RMSE: 8.11 - MAPE: 11.7% } - val: { MAE: 3.55 - RMSE: 7.28 - MAPE: 10.6% } - lr: 0.001 - weight decay: 2e-06
# Epoch 13/200
# [17/17] - 3s - train: { MAE (loss): 3.98 - RMSE: 7.9 - MAPE: 11.6% } - val: { MAE: 3.46 - RMSE: 7.22 - MAPE: 10.3% } - lr: 0.001 - weight decay: 2e-06
# Epoch 14/200
# [17/17] - 3s - train: { MAE (loss): 4 - RMSE: 7.95 - MAPE: 11.5% } - val: { MAE: 3.48 - RMSE: 7.04 - MAPE: 9.4% } - lr: 0.001 - weight decay: 2e-06
# Epoch 15/200
# [17/17] - 4s - train: { MAE (loss): 3.85 - RMSE: 7.63 - MAPE: 10.9% } - val: { MAE: 3.37 - RMSE: 7.02 - MAPE: 9.95% } - lr: 0.001 - weight decay: 2e-06
# Epoch 16/200
# [17/17] - 4s - train: { MAE (loss): 4.08 - RMSE: 8.08 - MAPE: 12.1% } - val: { MAE: 3.35 - RMSE: 6.97 - MAPE: 9.21% } - lr: 0.001 - weight decay: 2e-06
# Epoch 17/200
# [17/17] - 4s - train: { MAE (loss): 4.04 - RMSE: 8.01 - MAPE: 11.7% } - val: { MAE: 3.29 - RMSE: 6.88 - MAPE: 9.09% } - lr: 0.001 - weight decay: 2e-06
# Epoch 18/200
# [17/17] - 4s - train: { MAE (loss): 3.9 - RMSE: 7.8 - MAPE: 11.1% } - val: { MAE: 3.33 - RMSE: 6.77 - MAPE: 9.67% } - lr: 0.001 - weight decay: 2e-06
# Epoch 19/200
# [17/17] - 4s - train: { MAE (loss): 3.82 - RMSE: 7.69 - MAPE: 10.7% } - val: { MAE: 3.28 - RMSE: 6.81 - MAPE: 9.62% } - lr: 0.001 - weight decay: 2e-06
# Epoch 20/200
# [17/17] - 4s - train: { MAE (loss): 3.78 - RMSE: 7.6 - MAPE: 10.7% } - val: { MAE: 3.24 - RMSE: 6.85 - MAPE: 8.9% } - lr: 0.001 - weight decay: 2e-06
# Epoch 21/200
# [17/17] - 4s - train: { MAE (loss): 3.93 - RMSE: 7.92 - MAPE: 11.2% } - val: { MAE: 3.29 - RMSE: 6.74 - MAPE: 9.21% } - lr: 0.001 - weight decay: 2e-06
# Epoch 22/200
# [17/17] - 4s - train: { MAE (loss): 3.97 - RMSE: 8.06 - MAPE: 11.6% } - val: { MAE: 3.35 - RMSE: 6.91 - MAPE: 8.86% } - lr: 0.001 - weight decay: 2e-06
# Epoch 23/200
# [17/17] - 4s - train: { MAE (loss): 3.91 - RMSE: 7.89 - MAPE: 11.1% } - val: { MAE: 3.29 - RMSE: 6.74 - MAPE: 9.39% } - lr: 0.001 - weight decay: 2e-06
# Epoch 24/200
# [17/17] - 4s - train: { MAE (loss): 3.79 - RMSE: 7.7 - MAPE: 10.6% } - val: { MAE: 3.24 - RMSE: 6.83 - MAPE: 9.27% } - lr: 0.001 - weight decay: 2e-06
# Epoch 25/200
# [17/17] - 4s - train: { MAE (loss): 3.85 - RMSE: 7.78 - MAPE: 11% } - val: { MAE: 3.34 - RMSE: 6.98 - MAPE: 8.97% } - lr: 0.001 - weight decay: 2e-06
# Epoch 26/200
# [17/17] - 4s - train: { MAE (loss): 3.91 - RMSE: 7.86 - MAPE: 11.2% } - val: { MAE: 3.28 - RMSE: 6.8 - MAPE: 9.23% } - lr: 0.001 - weight decay: 2e-06
# Epoch 27/200
# [17/17] - 4s - train: { MAE (loss): 3.82 - RMSE: 7.7 - MAPE: 10.5% } - val: { MAE: 3.31 - RMSE: 6.68 - MAPE: 9.19% } - lr: 0.001 - weight decay: 2e-06
# Epoch 28/200
# [17/17] - 3s - train: { MAE (loss): 3.77 - RMSE: 7.58 - MAPE: 10.5% } - val: { MAE: 3.24 - RMSE: 6.78 - MAPE: 8.91% } - lr: 0.001 - weight decay: 2e-06
# Epoch 29/200
# [17/17] - 4s - train: { MAE (loss): 3.82 - RMSE: 7.73 - MAPE: 10.7% } - val: { MAE: 3.21 - RMSE: 6.74 - MAPE: 9% } - lr: 0.001 - weight decay: 2e-06
# Epoch 30/200
# [17/17] - 4s - train: { MAE (loss): 3.85 - RMSE: 7.79 - MAPE: 10.8% } - val: { MAE: 3.22 - RMSE: 6.79 - MAPE: 9.04% } - lr: 0.001 - weight decay: 2e-06
# Epoch 31/200
# [17/17] - 4s - train: { MAE (loss): 3.87 - RMSE: 7.76 - MAPE: 10.8% } - val: { MAE: 3.55 - RMSE: 6.77 - MAPE: 9.29% } - lr: 0.001 - weight decay: 2e-06
# Epoch 32/200
# [17/17] - 4s - train: { MAE (loss): 3.88 - RMSE: 7.67 - MAPE: 10.7% } - val: { MAE: 3.22 - RMSE: 6.68 - MAPE: 8.99% } - lr: 0.001 - weight decay: 2e-06
# Epoch 33/200
# [17/17] - 4s - train: { MAE (loss): 3.78 - RMSE: 7.57 - MAPE: 10.5% } - val: { MAE: 3.26 - RMSE: 6.65 - MAPE: 9.14% } - lr: 0.001 - weight decay: 2e-06
# Epoch 34/200
# [17/17] - 4s - train: { MAE (loss): 3.83 - RMSE: 7.71 - MAPE: 10.6% } - val: { MAE: 3.29 - RMSE: 6.66 - MAPE: 9.29% } - lr: 0.001 - weight decay: 2e-06
# Epoch 35/200
# [17/17] - 4s - train: { MAE (loss): 3.93 - RMSE: 7.88 - MAPE: 11.4% } - val: { MAE: 3.18 - RMSE: 6.72 - MAPE: 8.83% } - lr: 0.001 - weight decay: 2e-06
# Epoch 36/200
# [17/17] - 4s - train: { MAE (loss): 3.82 - RMSE: 7.74 - MAPE: 10.8% } - val: { MAE: 3.41 - RMSE: 6.74 - MAPE: 9.03% } - lr: 0.001 - weight decay: 2e-06
# Epoch 37/200
# [17/17] - 4s - train: { MAE (loss): 3.87 - RMSE: 7.8 - MAPE: 11.1% } - val: { MAE: 3.23 - RMSE: 6.81 - MAPE: 8.75% } - lr: 0.001 - weight decay: 2e-06
# Epoch 38/200
# [17/17] - 4s - train: { MAE (loss): 4.07 - RMSE: 8.23 - MAPE: 12.4% } - val: { MAE: 3.88 - RMSE: 7.98 - MAPE: 10.2% } - lr: 0.001 - weight decay: 2e-06
# Epoch 39/200
# [17/17] - 4s - train: { MAE (loss): 3.91 - RMSE: 7.84 - MAPE: 11% } - val: { MAE: 3.34 - RMSE: 6.88 - MAPE: 9.16% } - lr: 0.001 - weight decay: 2e-06
# Epoch 40/200
# [17/17] - 4s - train: { MAE (loss): 3.92 - RMSE: 7.8 - MAPE: 11.1% } - val: { MAE: 3.21 - RMSE: 6.7 - MAPE: 8.83% } - lr: 0.001 - weight decay: 2e-06
# Epoch 41/200
# [17/17] - 4s - train: { MAE (loss): 3.74 - RMSE: 7.59 - MAPE: 10.4% } - val: { MAE: 3.29 - RMSE: 6.64 - MAPE: 9.05% } - lr: 0.001 - weight decay: 2e-06
# Epoch 42/200
# [17/17] - 4s - train: { MAE (loss): 3.86 - RMSE: 7.84 - MAPE: 11.1% } - val: { MAE: 3.19 - RMSE: 6.73 - MAPE: 8.7% } - lr: 0.001 - weight decay: 2e-06
# Epoch 43/200
# [17/17] - 4s - train: { MAE (loss): 3.8 - RMSE: 7.7 - MAPE: 10.4% } - val: { MAE: 3.23 - RMSE: 6.64 - MAPE: 9.3% } - lr: 0.001 - weight decay: 2e-06
# Epoch 44/200
# [17/17] - 4s - train: { MAE (loss): 3.74 - RMSE: 7.62 - MAPE: 10.6% } - val: { MAE: 3.19 - RMSE: 6.68 - MAPE: 8.69% } - lr: 0.001 - weight decay: 2e-06
# Epoch 45/200
# [17/17] - 4s - train: { MAE (loss): 3.91 - RMSE: 7.86 - MAPE: 10.9% } - val: { MAE: 3.23 - RMSE: 6.61 - MAPE: 8.96% } - lr: 0.001 - weight decay: 2e-06
# Epoch 46/200
# [17/17] - 4s - train: { MAE (loss): 3.72 - RMSE: 7.56 - MAPE: 10.5% } - val: { MAE: 3.19 - RMSE: 6.65 - MAPE: 8.85% } - lr: 0.001 - weight decay: 2e-06
# Epoch 47/200
# [17/17] - 4s - train: { MAE (loss): 3.74 - RMSE: 7.6 - MAPE: 10.6% } - val: { MAE: 3.2 - RMSE: 6.63 - MAPE: 8.72% } - lr: 0.001 - weight decay: 2e-06
# Epoch 48/200
# [17/17] - 4s - train: { MAE (loss): 3.79 - RMSE: 7.69 - MAPE: 10.4% } - val: { MAE: 3.17 - RMSE: 6.62 - MAPE: 8.92% } - lr: 0.001 - weight decay: 2e-06
# Epoch 49/200
# [17/17] - 4s - train: { MAE (loss): 3.78 - RMSE: 7.68 - MAPE: 10.6% } - val: { MAE: 3.2 - RMSE: 6.64 - MAPE: 8.71% } - lr: 0.001 - weight decay: 2e-06
# Epoch 50/200
# [17/17] - 4s - train: { MAE (loss): 3.7 - RMSE: 7.42 - MAPE: 10.3% } - val: { MAE: 3.23 - RMSE: 6.63 - MAPE: 8.85% } - lr: 0.001 - weight decay: 2e-06
# Epoch 51/200
# [17/17] - 4s - train: { MAE (loss): 3.82 - RMSE: 7.74 - MAPE: 10.5% } - val: { MAE: 3.24 - RMSE: 6.66 - MAPE: 9.57% } - lr: 0.001 - weight decay: 2e-06
# Epoch 52/200
# [17/17] - 4s - train: { MAE (loss): 3.77 - RMSE: 7.55 - MAPE: 10.5% } - val: { MAE: 3.22 - RMSE: 6.65 - MAPE: 9.38% } - lr: 0.001 - weight decay: 2e-06
# Epoch 53/200
# [17/17] - 4s - train: { MAE (loss): 3.74 - RMSE: 7.52 - MAPE: 10.4% } - val: { MAE: 3.2 - RMSE: 6.64 - MAPE: 9.37% } - lr: 0.001 - weight decay: 2e-06
# Epoch 54/200
# [17/17] - 4s - train: { MAE (loss): 3.74 - RMSE: 7.56 - MAPE: 10.5% } - val: { MAE: 3.21 - RMSE: 6.62 - MAPE: 9.13% } - lr: 0.001 - weight decay: 2e-06
# Epoch 55/200
# [17/17] - 4s - train: { MAE (loss): 3.68 - RMSE: 7.52 - MAPE: 10.4% } - val: { MAE: 3.23 - RMSE: 6.62 - MAPE: 9.06% } - lr: 0.001 - weight decay: 2e-06
# Epoch 56/200
# [17/17] - 4s - train: { MAE (loss): 3.79 - RMSE: 7.68 - MAPE: 10.8% } - val: { MAE: 3.16 - RMSE: 6.58 - MAPE: 9.05% } - lr: 0.001 - weight decay: 2e-06
# Epoch 57/200
# [17/17] - 4s - train: { MAE (loss): 3.71 - RMSE: 7.46 - MAPE: 10.4% } - val: { MAE: 3.17 - RMSE: 6.55 - MAPE: 8.76% } - lr: 0.001 - weight decay: 2e-06
# Epoch 58/200
# [17/17] - 4s - train: { MAE (loss): 3.73 - RMSE: 7.53 - MAPE: 10.3% } - val: { MAE: 3.18 - RMSE: 6.54 - MAPE: 8.93% } - lr: 0.001 - weight decay: 2e-06
# Epoch 59/200
# [17/17] - 4s - train: { MAE (loss): 3.66 - RMSE: 7.41 - MAPE: 10.3% } - val: { MAE: 3.16 - RMSE: 6.5 - MAPE: 8.99% } - lr: 0.001 - weight decay: 2e-06
# Epoch 60/200
# [17/17] - 4s - train: { MAE (loss): 3.78 - RMSE: 7.57 - MAPE: 10.7% } - val: { MAE: 3.14 - RMSE: 6.51 - MAPE: 8.76% } - lr: 0.001 - weight decay: 2e-06
# Epoch 61/200
# [17/17] - 4s - train: { MAE (loss): 3.77 - RMSE: 7.59 - MAPE: 10.8% } - val: { MAE: 3.17 - RMSE: 6.57 - MAPE: 8.57% } - lr: 0.001 - weight decay: 2e-06
# Epoch 62/200
# [17/17] - 4s - train: { MAE (loss): 3.69 - RMSE: 7.51 - MAPE: 10.2% } - val: { MAE: 3.26 - RMSE: 6.47 - MAPE: 9.05% } - lr: 0.001 - weight decay: 2e-06
# Epoch 63/200
# [17/17] - 4s - train: { MAE (loss): 3.72 - RMSE: 7.46 - MAPE: 10.6% } - val: { MAE: 3.25 - RMSE: 6.48 - MAPE: 8.84% } - lr: 0.001 - weight decay: 2e-06
# Epoch 64/200
# [17/17] - 4s - train: { MAE (loss): 3.69 - RMSE: 7.49 - MAPE: 10.3% } - val: { MAE: 3.19 - RMSE: 6.49 - MAPE: 9.23% } - lr: 0.001 - weight decay: 2e-06
# Epoch 65/200
# [17/17] - 4s - train: { MAE (loss): 3.72 - RMSE: 7.46 - MAPE: 10.5% } - val: { MAE: 3.19 - RMSE: 6.5 - MAPE: 9.19% } - lr: 0.001 - weight decay: 2e-06
# Epoch 66/200
# [17/17] - 4s - train: { MAE (loss): 3.66 - RMSE: 7.41 - MAPE: 10.4% } - val: { MAE: 3.14 - RMSE: 6.56 - MAPE: 8.86% } - lr: 0.001 - weight decay: 2e-06
# Epoch 67/200
# [17/17] - 4s - train: { MAE (loss): 3.67 - RMSE: 7.33 - MAPE: 10.2% } - val: { MAE: 3.12 - RMSE: 6.49 - MAPE: 8.59% } - lr: 0.001 - weight decay: 2e-06
# Epoch 68/200
# [17/17] - 4s - train: { MAE (loss): 3.66 - RMSE: 7.37 - MAPE: 10.3% } - val: { MAE: 3.19 - RMSE: 6.53 - MAPE: 8.93% } - lr: 0.001 - weight decay: 2e-06
# Epoch 69/200
# [17/17] - 4s - train: { MAE (loss): 3.72 - RMSE: 7.46 - MAPE: 10.5% } - val: { MAE: 3.18 - RMSE: 6.45 - MAPE: 8.79% } - lr: 0.001 - weight decay: 2e-06
# Epoch 70/200
# [17/17] - 4s - train: { MAE (loss): 3.7 - RMSE: 7.45 - MAPE: 10.5% } - val: { MAE: 3.11 - RMSE: 6.43 - MAPE: 8.75% } - lr: 0.001 - weight decay: 2e-06
# Epoch 71/200
# [17/17] - 4s - train: { MAE (loss): 3.65 - RMSE: 7.34 - MAPE: 10.3% } - val: { MAE: 3.11 - RMSE: 6.5 - MAPE: 8.66% } - lr: 0.001 - weight decay: 2e-06
# Epoch 72/200
# [17/17] - 4s - train: { MAE (loss): 3.72 - RMSE: 7.49 - MAPE: 10.7% } - val: { MAE: 3.12 - RMSE: 6.47 - MAPE: 8.87% } - lr: 0.001 - weight decay: 2e-06
# Epoch 73/200
# [17/17] - 4s - train: { MAE (loss): 3.73 - RMSE: 7.53 - MAPE: 10.7% } - val: { MAE: 3.1 - RMSE: 6.49 - MAPE: 8.59% } - lr: 0.001 - weight decay: 2e-06
# Epoch 74/200
# [17/17] - 4s - train: { MAE (loss): 3.64 - RMSE: 7.39 - MAPE: 10.3% } - val: { MAE: 3.1 - RMSE: 6.42 - MAPE: 8.61% } - lr: 0.001 - weight decay: 2e-06
# Epoch 75/200
# [17/17] - 4s - train: { MAE (loss): 3.64 - RMSE: 7.35 - MAPE: 10.4% } - val: { MAE: 3.15 - RMSE: 6.49 - MAPE: 8.62% } - lr: 0.001 - weight decay: 2e-06
# Epoch 76/200
# [17/17] - 4s - train: { MAE (loss): 3.72 - RMSE: 7.48 - MAPE: 10.7% } - val: { MAE: 3.13 - RMSE: 6.44 - MAPE: 8.77% } - lr: 0.001 - weight decay: 2e-06
# Epoch 77/200
# [17/17] - 4s - train: { MAE (loss): 3.56 - RMSE: 7.09 - MAPE: 9.87% } - val: { MAE: 3.11 - RMSE: 6.42 - MAPE: 8.76% } - lr: 0.001 - weight decay: 2e-06
# Epoch 78/200
# [17/17] - 4s - train: { MAE (loss): 3.65 - RMSE: 7.35 - MAPE: 10.3% } - val: { MAE: 3.13 - RMSE: 6.39 - MAPE: 8.83% } - lr: 0.001 - weight decay: 2e-06
# Epoch 79/200
# [17/17] - 4s - train: { MAE (loss): 3.61 - RMSE: 7.3 - MAPE: 10.4% } - val: { MAE: 3.09 - RMSE: 6.38 - MAPE: 8.58% } - lr: 0.001 - weight decay: 2e-06
# Epoch 80/200
# [17/17] - 4s - train: { MAE (loss): 3.99 - RMSE: 8.26 - MAPE: 12.9% } - val: { MAE: 3.81 - RMSE: 8.06 - MAPE: 9.99% } - lr: 0.001 - weight decay: 2e-06
# Epoch 81/200
# [17/17] - 4s - train: { MAE (loss): 3.84 - RMSE: 7.75 - MAPE: 11% } - val: { MAE: 3.28 - RMSE: 6.7 - MAPE: 8.91% } - lr: 0.001 - weight decay: 2e-06
# Epoch 82/200
# [17/17] - 4s - train: { MAE (loss): 3.62 - RMSE: 7.23 - MAPE: 10.1% } - val: { MAE: 3.16 - RMSE: 6.42 - MAPE: 8.79% } - lr: 0.001 - weight decay: 2e-06
# Epoch 83/200
# [17/17] - 4s - train: { MAE (loss): 3.64 - RMSE: 7.34 - MAPE: 10.3% } - val: { MAE: 3.1 - RMSE: 6.41 - MAPE: 8.58% } - lr: 0.001 - weight decay: 2e-06
# Epoch 84/200
# [17/17] - 4s - train: { MAE (loss): 3.57 - RMSE: 7.22 - MAPE: 10% } - val: { MAE: 3.1 - RMSE: 6.43 - MAPE: 8.69% } - lr: 0.001 - weight decay: 2e-06
# Epoch 85/200
# [17/17] - 4s - train: { MAE (loss): 3.6 - RMSE: 7.26 - MAPE: 10.1% } - val: { MAE: 3.11 - RMSE: 6.37 - MAPE: 8.66% } - lr: 0.001 - weight decay: 2e-06
# Epoch 86/200
# [17/17] - 4s - train: { MAE (loss): 3.51 - RMSE: 7.05 - MAPE: 9.79% } - val: { MAE: 3.08 - RMSE: 6.42 - MAPE: 8.63% } - lr: 0.001 - weight decay: 2e-06
# Epoch 87/200
# [17/17] - 4s - train: { MAE (loss): 3.61 - RMSE: 7.29 - MAPE: 10.3% } - val: { MAE: 3.1 - RMSE: 6.43 - MAPE: 8.95% } - lr: 0.001 - weight decay: 2e-06
# Epoch 88/200
# [17/17] - 4s - train: { MAE (loss): 3.52 - RMSE: 7.07 - MAPE: 9.84% } - val: { MAE: 3.11 - RMSE: 6.38 - MAPE: 8.55% } - lr: 0.001 - weight decay: 2e-06
# Epoch 89/200
# [17/17] - 4s - train: { MAE (loss): 3.61 - RMSE: 7.23 - MAPE: 10.1% } - val: { MAE: 3.08 - RMSE: 6.38 - MAPE: 8.82% } - lr: 0.001 - weight decay: 2e-06
# Epoch 90/200
# [17/17] - 4s - train: { MAE (loss): 3.64 - RMSE: 7.34 - MAPE: 10.2% } - val: { MAE: 3.17 - RMSE: 6.36 - MAPE: 8.97% } - lr: 0.001 - weight decay: 2e-06
# Epoch 91/200
# [17/17] - 4s - train: { MAE (loss): 3.59 - RMSE: 7.25 - MAPE: 10.3% } - val: { MAE: 3.06 - RMSE: 6.37 - MAPE: 8.49% } - lr: 0.001 - weight decay: 2e-06
# Epoch 92/200
# [17/17] - 4s - train: { MAE (loss): 3.56 - RMSE: 7.16 - MAPE: 10.1% } - val: { MAE: 3.14 - RMSE: 6.55 - MAPE: 8.36% } - lr: 0.001 - weight decay: 2e-06
# Epoch 93/200
# [17/17] - 4s - train: { MAE (loss): 3.74 - RMSE: 7.56 - MAPE: 10.4% } - val: { MAE: 3.16 - RMSE: 6.44 - MAPE: 8.55% } - lr: 0.001 - weight decay: 2e-06
# Epoch 94/200
# [17/17] - 4s - train: { MAE (loss): 3.69 - RMSE: 7.45 - MAPE: 10.3% } - val: { MAE: 3.12 - RMSE: 6.36 - MAPE: 8.89% } - lr: 0.001 - weight decay: 2e-06
# Epoch 95/200
# [17/17] - 4s - train: { MAE (loss): 3.57 - RMSE: 7.13 - MAPE: 9.97% } - val: { MAE: 3.17 - RMSE: 6.36 - MAPE: 8.9% } - lr: 0.001 - weight decay: 2e-06
# Epoch 96/200
# [17/17] - 4s - train: { MAE (loss): 3.57 - RMSE: 7.22 - MAPE: 10.1% } - val: { MAE: 3.08 - RMSE: 6.39 - MAPE: 8.88% } - lr: 0.001 - weight decay: 2e-06
# Epoch 97/200
# [17/17] - 4s - train: { MAE (loss): 3.59 - RMSE: 7.3 - MAPE: 10.4% } - val: { MAE: 3.07 - RMSE: 6.4 - MAPE: 8.68% } - lr: 0.001 - weight decay: 2e-06
# Epoch 98/200
# [17/17] - 4s - train: { MAE (loss): 3.56 - RMSE: 7.13 - MAPE: 9.9% } - val: { MAE: 3.12 - RMSE: 6.32 - MAPE: 8.68% } - lr: 0.001 - weight decay: 2e-06
# Epoch 99/200
# [17/17] - 4s - train: { MAE (loss): 3.56 - RMSE: 7.2 - MAPE: 10.1% } - val: { MAE: 3.08 - RMSE: 6.32 - MAPE: 8.8% } - lr: 0.001 - weight decay: 2e-06
# Epoch 100/200
# [17/17] - 4s - train: { MAE (loss): 3.54 - RMSE: 7.16 - MAPE: 9.95% } - val: { MAE: 3.08 - RMSE: 6.34 - MAPE: 8.78% } - lr: 0.001 - weight decay: 2e-06
# Epoch 101/200
# [17/17] - 4s - train: { MAE (loss): 3.54 - RMSE: 7.14 - MAPE: 9.92% } - val: { MAE: 3.08 - RMSE: 6.33 - MAPE: 8.61% } - lr: 0.001 - weight decay: 2e-06
# Epoch 102/200
# [17/17] - 4s - train: { MAE (loss): 3.56 - RMSE: 7.13 - MAPE: 9.98% } - val: { MAE: 3.09 - RMSE: 6.33 - MAPE: 8.51% } - lr: 0.001 - weight decay: 2e-06
# Epoch 103/200
# [17/17] - 4s - train: { MAE (loss): 3.64 - RMSE: 7.29 - MAPE: 10.5% } - val: { MAE: 3.06 - RMSE: 6.38 - MAPE: 8.77% } - lr: 0.001 - weight decay: 2e-06
# Epoch 104/200
# [17/17] - 4s - train: { MAE (loss): 3.5 - RMSE: 7.03 - MAPE: 9.79% } - val: { MAE: 3.09 - RMSE: 6.3 - MAPE: 8.58% } - lr: 0.001 - weight decay: 2e-06
# Epoch 105/200
# [17/17] - 4s - train: { MAE (loss): 3.52 - RMSE: 7.13 - MAPE: 9.98% } - val: { MAE: 3.05 - RMSE: 6.33 - MAPE: 8.58% } - lr: 0.001 - weight decay: 2e-06
# Epoch 106/200
# [17/17] - 4s - train: { MAE (loss): 3.57 - RMSE: 7.14 - MAPE: 10% } - val: { MAE: 3.09 - RMSE: 6.31 - MAPE: 8.56% } - lr: 0.001 - weight decay: 2e-06
# Epoch 107/200
# [17/17] - 4s - train: { MAE (loss): 3.53 - RMSE: 7.07 - MAPE: 9.8% } - val: { MAE: 3.1 - RMSE: 6.34 - MAPE: 9.08% } - lr: 0.001 - weight decay: 2e-06
# Epoch 108/200
# [17/17] - 4s - train: { MAE (loss): 3.46 - RMSE: 6.92 - MAPE: 9.73% } - val: { MAE: 3.07 - RMSE: 6.34 - MAPE: 8.62% } - lr: 0.001 - weight decay: 2e-06
# Epoch 109/200
# [17/17] - 4s - train: { MAE (loss): 3.52 - RMSE: 7.12 - MAPE: 9.8% } - val: { MAE: 3.13 - RMSE: 6.28 - MAPE: 8.8% } - lr: 0.001 - weight decay: 2e-06
# Epoch 110/200
# [17/17] - 4s - train: { MAE (loss): 3.56 - RMSE: 7.13 - MAPE: 10.1% } - val: { MAE: 3.08 - RMSE: 6.39 - MAPE: 8.99% } - lr: 0.001 - weight decay: 2e-06
# Epoch 111/200
# [17/17] - 4s - train: { MAE (loss): 3.54 - RMSE: 7.11 - MAPE: 10% } - val: { MAE: 3.07 - RMSE: 6.34 - MAPE: 8.58% } - lr: 0.001 - weight decay: 2e-06
# Epoch 112/200
# [17/17] - 4s - train: { MAE (loss): 3.6 - RMSE: 7.27 - MAPE: 10.4% } - val: { MAE: 3.12 - RMSE: 6.37 - MAPE: 8.54% } - lr: 0.001 - weight decay: 2e-06
# Epoch 113/200
# [17/17] - 4s - train: { MAE (loss): 3.44 - RMSE: 6.86 - MAPE: 9.54% } - val: { MAE: 3.06 - RMSE: 6.36 - MAPE: 8.73% } - lr: 0.001 - weight decay: 2e-06
# Epoch 114/200
# [17/17] - 4s - train: { MAE (loss): 3.45 - RMSE: 6.88 - MAPE: 9.57% } - val: { MAE: 3.1 - RMSE: 6.35 - MAPE: 8.51% } - lr: 0.001 - weight decay: 2e-06
# Epoch 115/200
# [17/17] - 4s - train: { MAE (loss): 3.43 - RMSE: 6.98 - MAPE: 9.68% } - val: { MAE: 3.05 - RMSE: 6.4 - MAPE: 8.76% } - lr: 0.001 - weight decay: 2e-06
# Epoch 116/200
# [17/17] - 4s - train: { MAE (loss): 3.55 - RMSE: 7.16 - MAPE: 10.2% } - val: { MAE: 3.03 - RMSE: 6.33 - MAPE: 8.65% } - lr: 0.001 - weight decay: 2e-06
# Epoch 117/200
# [17/17] - 4s - train: { MAE (loss): 3.53 - RMSE: 7.15 - MAPE: 9.99% } - val: { MAE: 3.06 - RMSE: 6.36 - MAPE: 8.86% } - lr: 0.001 - weight decay: 2e-06
# Epoch 118/200
# [17/17] - 4s - train: { MAE (loss): 3.64 - RMSE: 7.3 - MAPE: 10.6% } - val: { MAE: 3.06 - RMSE: 6.32 - MAPE: 8.37% } - lr: 0.001 - weight decay: 2e-06
# Epoch 119/200
# [17/17] - 4s - train: { MAE (loss): 3.63 - RMSE: 7.32 - MAPE: 10.3% } - val: { MAE: 3.06 - RMSE: 6.35 - MAPE: 8.89% } - lr: 0.001 - weight decay: 2e-06
# Epoch 120/200
# [17/17] - 4s - train: { MAE (loss): 3.56 - RMSE: 7.16 - MAPE: 10.1% } - val: { MAE: 3.07 - RMSE: 6.36 - MAPE: 8.5% } - lr: 0.001 - weight decay: 2e-06
# Epoch 121/200
# [17/17] - 4s - train: { MAE (loss): 3.46 - RMSE: 7.02 - MAPE: 9.79% } - val: { MAE: 3.04 - RMSE: 6.34 - MAPE: 8.57% } - lr: 0.001 - weight decay: 2e-06
# Epoch 122/200
# [17/17] - 4s - train: { MAE (loss): 3.54 - RMSE: 7.14 - MAPE: 10.2% } - val: { MAE: 3.08 - RMSE: 6.34 - MAPE: 8.58% } - lr: 0.001 - weight decay: 2e-06
# Epoch 123/200
# [17/17] - 4s - train: { MAE (loss): 3.53 - RMSE: 7.12 - MAPE: 9.88% } - val: { MAE: 3.08 - RMSE: 6.29 - MAPE: 8.7% } - lr: 0.001 - weight decay: 2e-06
# Epoch 124/200
# [17/17] - 4s - train: { MAE (loss): 3.48 - RMSE: 7.02 - MAPE: 9.83% } - val: { MAE: 3.17 - RMSE: 6.32 - MAPE: 9.06% } - lr: 0.001 - weight decay: 2e-06
# Epoch 125/200
# [17/17] - 4s - train: { MAE (loss): 3.5 - RMSE: 7.02 - MAPE: 9.86% } - val: { MAE: 3.11 - RMSE: 6.34 - MAPE: 8.94% } - lr: 0.001 - weight decay: 2e-06
# Epoch 126/200
# [17/17] - 4s - train: { MAE (loss): 3.43 - RMSE: 6.87 - MAPE: 9.58% } - val: { MAE: 3.08 - RMSE: 6.37 - MAPE: 9.15% } - lr: 0.001 - weight decay: 2e-06
# Epoch 127/200
# [17/17] - 4s - train: { MAE (loss): 3.51 - RMSE: 7.1 - MAPE: 9.98% } - val: { MAE: 3.12 - RMSE: 6.32 - MAPE: 8.71% } - lr: 0.001 - weight decay: 2e-06
# Epoch 128/200
# [17/17] - 4s - train: { MAE (loss): 3.4 - RMSE: 6.87 - MAPE: 9.47% } - val: { MAE: 3.05 - RMSE: 6.38 - MAPE: 8.61% } - lr: 0.001 - weight decay: 2e-06
# Epoch 129/200
# [17/17] - 4s - train: { MAE (loss): 3.39 - RMSE: 6.86 - MAPE: 9.46% } - val: { MAE: 3.05 - RMSE: 6.36 - MAPE: 8.64% } - lr: 0.001 - weight decay: 2e-06
# Epoch 130/200
# [17/17] - 4s - train: { MAE (loss): 3.49 - RMSE: 7.01 - MAPE: 9.7% } - val: { MAE: 3.06 - RMSE: 6.32 - MAPE: 8.82% } - lr: 0.001 - weight decay: 2e-06
# Epoch 131/200
# [17/17] - 4s - train: { MAE (loss): 3.5 - RMSE: 7.05 - MAPE: 9.92% } - val: { MAE: 3.1 - RMSE: 6.31 - MAPE: 8.56% } - lr: 0.001 - weight decay: 2e-06
# Epoch 132/200
# [17/17] - 4s - train: { MAE (loss): 3.49 - RMSE: 7.03 - MAPE: 9.81% } - val: { MAE: 3.12 - RMSE: 6.31 - MAPE: 8.77% } - lr: 0.001 - weight decay: 2e-06
# Epoch 133/200
# [17/17] - 4s - train: { MAE (loss): 3.48 - RMSE: 7.03 - MAPE: 9.78% } - val: { MAE: 3.14 - RMSE: 6.31 - MAPE: 8.93% } - lr: 0.001 - weight decay: 2e-06
# Epoch 134/200
# [17/17] - 4s - train: { MAE (loss): 3.5 - RMSE: 7.04 - MAPE: 9.9% } - val: { MAE: 3.09 - RMSE: 6.29 - MAPE: 8.62% } - lr: 0.001 - weight decay: 2e-06
# Epoch 135/200
# [17/17] - 4s - train: { MAE (loss): 3.39 - RMSE: 6.81 - MAPE: 9.41% } - val: { MAE: 3.04 - RMSE: 6.32 - MAPE: 8.58% } - lr: 0.001 - weight decay: 2e-06
# Epoch 136/200
# [17/17] - 4s - train: { MAE (loss): 3.46 - RMSE: 7 - MAPE: 9.71% } - val: { MAE: 3.17 - RMSE: 6.34 - MAPE: 8.87% } - lr: 0.001 - weight decay: 2e-06
# Epoch 137/200
# [17/17] - 4s - train: { MAE (loss): 3.43 - RMSE: 6.86 - MAPE: 9.51% } - val: { MAE: 3.08 - RMSE: 6.4 - MAPE: 9.04% } - lr: 0.001 - weight decay: 2e-06
# Epoch 138/200
# [17/17] - 4s - train: { MAE (loss): 3.48 - RMSE: 6.95 - MAPE: 9.77% } - val: { MAE: 3.11 - RMSE: 6.32 - MAPE: 8.87% } - lr: 0.001 - weight decay: 2e-06
# Epoch 139/200
# [17/17] - 4s - train: { MAE (loss): 3.4 - RMSE: 6.84 - MAPE: 9.44% } - val: { MAE: 3.08 - RMSE: 6.33 - MAPE: 8.7% } - lr: 0.001 - weight decay: 2e-06
# Epoch 140/200
# [17/17] - 4s - train: { MAE (loss): 3.4 - RMSE: 6.89 - MAPE: 9.57% } - val: { MAE: 3.07 - RMSE: 6.33 - MAPE: 8.45% } - lr: 0.001 - weight decay: 2e-06
# Epoch 141/200
# [17/17] - 4s - train: { MAE (loss): 3.46 - RMSE: 6.98 - MAPE: 9.62% } - val: { MAE: 3.06 - RMSE: 6.34 - MAPE: 8.73% } - lr: 0.001 - weight decay: 2e-06
# Epoch 142/200
# [17/17] - 4s - train: { MAE (loss): 3.54 - RMSE: 7.13 - MAPE: 10% } - val: { MAE: 3.04 - RMSE: 6.34 - MAPE: 8.67% } - lr: 0.001 - weight decay: 2e-06
# Epoch 143/200
# [17/17] - 4s - train: { MAE (loss): 3.4 - RMSE: 6.85 - MAPE: 9.51% } - val: { MAE: 3.03 - RMSE: 6.32 - MAPE: 8.55% } - lr: 0.001 - weight decay: 2e-06
# Epoch 144/200
# [17/17] - 4s - train: { MAE (loss): 3.53 - RMSE: 7.1 - MAPE: 10.1% } - val: { MAE: 3.08 - RMSE: 6.26 - MAPE: 8.5% } - lr: 0.001 - weight decay: 2e-06
# Epoch 145/200
# [17/17] - 4s - train: { MAE (loss): 3.41 - RMSE: 6.76 - MAPE: 9.38% } - val: { MAE: 3.04 - RMSE: 6.31 - MAPE: 8.64% } - lr: 0.001 - weight decay: 2e-06
# Epoch 146/200
# [17/17] - 4s - train: { MAE (loss): 3.46 - RMSE: 6.99 - MAPE: 9.92% } - val: { MAE: 3.06 - RMSE: 6.3 - MAPE: 8.52% } - lr: 0.001 - weight decay: 2e-06
# Epoch 147/200
# [17/17] - 4s - train: { MAE (loss): 3.51 - RMSE: 7.02 - MAPE: 9.96% } - val: { MAE: 3.06 - RMSE: 6.46 - MAPE: 8.43% } - lr: 0.001 - weight decay: 2e-06
# Epoch 148/200
# [17/17] - 4s - train: { MAE (loss): 3.44 - RMSE: 6.92 - MAPE: 9.52% } - val: { MAE: 3.07 - RMSE: 6.34 - MAPE: 8.67% } - lr: 0.001 - weight decay: 2e-06
# Epoch 149/200
# [17/17] - 4s - train: { MAE (loss): 3.43 - RMSE: 6.89 - MAPE: 9.52% } - val: { MAE: 3.13 - RMSE: 6.33 - MAPE: 8.76% } - lr: 0.001 - weight decay: 2e-06
# Epoch 150/200
# [17/17] - 4s - train: { MAE (loss): 3.53 - RMSE: 7.12 - MAPE: 9.99% } - val: { MAE: 3.08 - RMSE: 6.28 - MAPE: 8.66% } - lr: 0.001 - weight decay: 2e-06
# Epoch 151/200
# [17/17] - 4s - train: { MAE (loss): 3.44 - RMSE: 6.91 - MAPE: 9.61% } - val: { MAE: 3.06 - RMSE: 6.35 - MAPE: 8.76% } - lr: 0.001 - weight decay: 2e-06
# Epoch 152/200
# [17/17] - 4s - train: { MAE (loss): 3.45 - RMSE: 6.98 - MAPE: 9.76% } - val: { MAE: 3.09 - RMSE: 6.33 - MAPE: 8.56% } - lr: 0.001 - weight decay: 2e-06
# Epoch 153/200
# [17/17] - 4s - train: { MAE (loss): 3.43 - RMSE: 6.95 - MAPE: 9.6% } - val: { MAE: 3.08 - RMSE: 6.3 - MAPE: 8.73% } - lr: 0.001 - weight decay: 2e-06
# Epoch 154/200
# [17/17] - 4s - train: { MAE (loss): 3.4 - RMSE: 6.89 - MAPE: 9.59% } - val: { MAE: 3.03 - RMSE: 6.33 - MAPE: 8.67% } - lr: 0.001 - weight decay: 2e-06
# Epoch 155/200
# [17/17] - 4s - train: { MAE (loss): 3.48 - RMSE: 6.99 - MAPE: 9.84% } - val: { MAE: 3.06 - RMSE: 6.44 - MAPE: 8.43% } - lr: 0.001 - weight decay: 2e-06
# Epoch 156/200
# [17/17] - 4s - train: { MAE (loss): 3.48 - RMSE: 7 - MAPE: 9.84% } - val: { MAE: 3.06 - RMSE: 6.36 - MAPE: 8.5% } - lr: 0.001 - weight decay: 2e-06
# Epoch 157/200
# [17/17] - 4s - train: { MAE (loss): 3.49 - RMSE: 7.06 - MAPE: 9.99% } - val: { MAE: 3.02 - RMSE: 6.32 - MAPE: 8.51% } - lr: 0.001 - weight decay: 2e-06
# Epoch 158/200
# [17/17] - 4s - train: { MAE (loss): 3.38 - RMSE: 6.83 - MAPE: 9.4% } - val: { MAE: 3.05 - RMSE: 6.38 - MAPE: 8.93% } - lr: 0.001 - weight decay: 2e-06
# Epoch 159/200
# [17/17] - 4s - train: { MAE (loss): 3.42 - RMSE: 6.89 - MAPE: 9.67% } - val: { MAE: 3.14 - RMSE: 6.29 - MAPE: 8.87% } - lr: 0.001 - weight decay: 2e-06
# Epoch 160/200
# [17/17] - 4s - train: { MAE (loss): 3.49 - RMSE: 7.06 - MAPE: 9.91% } - val: { MAE: 3.04 - RMSE: 6.33 - MAPE: 8.63% } - lr: 0.001 - weight decay: 2e-06
# Epoch 161/200
# [17/17] - 4s - train: { MAE (loss): 3.45 - RMSE: 6.93 - MAPE: 9.65% } - val: { MAE: 3.04 - RMSE: 6.32 - MAPE: 8.7% } - lr: 0.001 - weight decay: 2e-06
# Epoch 162/200
# [17/17] - 4s - train: { MAE (loss): 3.4 - RMSE: 6.85 - MAPE: 9.55% } - val: { MAE: 3.02 - RMSE: 6.34 - MAPE: 8.53% } - lr: 0.001 - weight decay: 2e-06
# Epoch 163/200
# [17/17] - 4s - train: { MAE (loss): 3.37 - RMSE: 6.75 - MAPE: 9.33% } - val: { MAE: 3.11 - RMSE: 6.32 - MAPE: 8.54% } - lr: 0.001 - weight decay: 2e-06
# Epoch 164/200
# [17/17] - 4s - train: { MAE (loss): 3.41 - RMSE: 6.89 - MAPE: 9.51% } - val: { MAE: 3.08 - RMSE: 6.3 - MAPE: 8.7% } - lr: 0.001 - weight decay: 2e-06
# Epoch 165/200
# [17/17] - 4s - train: { MAE (loss): 3.43 - RMSE: 6.9 - MAPE: 9.53% } - val: { MAE: 3.04 - RMSE: 6.3 - MAPE: 8.8% } - lr: 0.001 - weight decay: 2e-06
# Epoch 166/200
# [17/17] - 4s - train: { MAE (loss): 3.45 - RMSE: 6.96 - MAPE: 9.65% } - val: { MAE: 3.06 - RMSE: 6.4 - MAPE: 9.04% } - lr: 0.001 - weight decay: 2e-06
# Epoch 167/200
# [17/17] - 4s - train: { MAE (loss): 3.44 - RMSE: 6.94 - MAPE: 9.7% } - val: { MAE: 3.07 - RMSE: 6.3 - MAPE: 8.79% } - lr: 0.001 - weight decay: 2e-06
# Epoch 168/200
# [17/17] - 4s - train: { MAE (loss): 3.44 - RMSE: 6.93 - MAPE: 9.67% } - val: { MAE: 3.06 - RMSE: 6.31 - MAPE: 8.52% } - lr: 0.001 - weight decay: 2e-06
# Epoch 169/200
# [17/17] - 4s - train: { MAE (loss): 3.54 - RMSE: 7.09 - MAPE: 10.2% } - val: { MAE: 3.06 - RMSE: 6.33 - MAPE: 8.38% } - lr: 0.001 - weight decay: 2e-06
# Epoch 170/200
# [17/17] - 4s - train: { MAE (loss): 3.36 - RMSE: 6.77 - MAPE: 9.27% } - val: { MAE: 3.02 - RMSE: 6.34 - MAPE: 8.7% } - lr: 0.001 - weight decay: 2e-06
# Epoch 171/200
# [17/17] - 3s - train: { MAE (loss): 3.4 - RMSE: 6.91 - MAPE: 9.51% } - val: { MAE: 3.05 - RMSE: 6.3 - MAPE: 8.33% } - lr: 0.001 - weight decay: 2e-06
# Epoch 172/200
# [17/17] - 4s - train: { MAE (loss): 3.41 - RMSE: 6.83 - MAPE: 9.47% } - val: { MAE: 3.02 - RMSE: 6.3 - MAPE: 8.55% } - lr: 0.001 - weight decay: 2e-06
# Epoch 173/200
# [17/17] - 4s - train: { MAE (loss): 3.39 - RMSE: 6.86 - MAPE: 9.4% } - val: { MAE: 3.06 - RMSE: 6.34 - MAPE: 8.87% } - lr: 0.001 - weight decay: 2e-06
# Epoch 174/200
# [17/17] - 4s - train: { MAE (loss): 3.36 - RMSE: 6.74 - MAPE: 9.32% } - val: { MAE: 3.03 - RMSE: 6.32 - MAPE: 8.71% } - lr: 0.001 - weight decay: 2e-06
# Epoch 175/200
# [17/17] - 4s - train: { MAE (loss): 3.42 - RMSE: 6.88 - MAPE: 9.71% } - val: { MAE: 3.02 - RMSE: 6.38 - MAPE: 8.46% } - lr: 0.001 - weight decay: 2e-06
# Epoch 176/200
# [17/17] - 4s - train: { MAE (loss): 3.5 - RMSE: 7.04 - MAPE: 10% } - val: { MAE: 3.08 - RMSE: 6.32 - MAPE: 8.7% } - lr: 0.001 - weight decay: 2e-06
# Epoch 177/200
# [17/17] - 4s - train: { MAE (loss): 3.42 - RMSE: 6.89 - MAPE: 9.5% } - val: { MAE: 3.18 - RMSE: 6.27 - MAPE: 9% } - lr: 0.001 - weight decay: 2e-06
# Epoch 178/200
# [17/17] - 4s - train: { MAE (loss): 3.41 - RMSE: 6.87 - MAPE: 9.56% } - val: { MAE: 3.03 - RMSE: 6.45 - MAPE: 8.7% } - lr: 0.001 - weight decay: 2e-06
# Epoch 179/200
# [17/17] - 4s - train: { MAE (loss): 3.47 - RMSE: 6.98 - MAPE: 9.8% } - val: { MAE: 3.08 - RMSE: 6.33 - MAPE: 8.45% } - lr: 0.001 - weight decay: 2e-06
# Epoch 180/200
# [17/17] - 4s - train: { MAE (loss): 3.42 - RMSE: 6.9 - MAPE: 9.63% } - val: { MAE: 3.06 - RMSE: 6.41 - MAPE: 8.6% } - lr: 0.001 - weight decay: 2e-06
# Epoch 181/200
# [17/17] - 4s - train: { MAE (loss): 3.32 - RMSE: 6.75 - MAPE: 9.22% } - val: { MAE: 3.03 - RMSE: 6.31 - MAPE: 8.65% } - lr: 0.001 - weight decay: 2e-06
# Epoch 182/200
# [17/17] - 4s - train: { MAE (loss): 3.44 - RMSE: 6.95 - MAPE: 10.1% } - val: { MAE: 3.04 - RMSE: 6.32 - MAPE: 8.4% } - lr: 0.001 - weight decay: 2e-06
# Epoch 183/200
# [17/17] - 4s - train: { MAE (loss): 3.41 - RMSE: 6.84 - MAPE: 9.51% } - val: { MAE: 3.03 - RMSE: 6.4 - MAPE: 8.57% } - lr: 0.001 - weight decay: 2e-06
# Epoch 184/200
# [17/17] - 4s - train: { MAE (loss): 3.51 - RMSE: 7.09 - MAPE: 9.99% } - val: { MAE: 3.04 - RMSE: 6.35 - MAPE: 8.55% } - lr: 0.001 - weight decay: 2e-06
# Epoch 185/200
# [17/17] - 4s - train: { MAE (loss): 3.35 - RMSE: 6.76 - MAPE: 9.34% } - val: { MAE: 3.02 - RMSE: 6.32 - MAPE: 8.62% } - lr: 0.001 - weight decay: 2e-06
# Epoch 186/200
# [17/17] - 4s - train: { MAE (loss): 3.38 - RMSE: 6.82 - MAPE: 9.42% } - val: { MAE: 3.05 - RMSE: 6.31 - MAPE: 8.68% } - lr: 0.001 - weight decay: 2e-06
# Epoch 187/200
# [17/17] - 4s - train: { MAE (loss): 3.31 - RMSE: 6.66 - MAPE: 9.13% } - val: { MAE: 3.02 - RMSE: 6.38 - MAPE: 8.75% } - lr: 0.001 - weight decay: 2e-06
# Epoch 188/200
# [17/17] - 4s - train: { MAE (loss): 3.41 - RMSE: 6.89 - MAPE: 9.53% } - val: { MAE: 3.04 - RMSE: 6.3 - MAPE: 8.65% } - lr: 0.001 - weight decay: 2e-06
# Epoch 189/200
# [17/17] - 4s - train: { MAE (loss): 3.37 - RMSE: 6.75 - MAPE: 9.31% } - val: { MAE: 3.06 - RMSE: 6.42 - MAPE: 8.64% } - lr: 0.001 - weight decay: 2e-06
# Epoch 190/200
# [17/17] - 4s - train: { MAE (loss): 3.37 - RMSE: 6.85 - MAPE: 9.47% } - val: { MAE: 3.02 - RMSE: 6.35 - MAPE: 8.67% } - lr: 0.001 - weight decay: 2e-06
# Epoch 191/200
# [17/17] - 4s - train: { MAE (loss): 3.32 - RMSE: 6.62 - MAPE: 9.14% } - val: { MAE: 3.05 - RMSE: 6.35 - MAPE: 8.81% } - lr: 0.001 - weight decay: 2e-06
# Epoch 192/200
# [17/17] - 4s - train: { MAE (loss): 3.41 - RMSE: 6.89 - MAPE: 9.58% } - val: { MAE: 3.07 - RMSE: 6.31 - MAPE: 8.58% } - lr: 0.001 - weight decay: 2e-06
# Epoch 193/200
# [17/17] - 4s - train: { MAE (loss): 3.34 - RMSE: 6.73 - MAPE: 9.28% } - val: { MAE: 3.04 - RMSE: 6.38 - MAPE: 8.77% } - lr: 0.001 - weight decay: 2e-06
# Epoch 194/200
# [17/17] - 4s - train: { MAE (loss): 3.43 - RMSE: 6.9 - MAPE: 9.65% } - val: { MAE: 3.01 - RMSE: 6.38 - MAPE: 8.58% } - lr: 0.001 - weight decay: 2e-06
# Epoch 195/200
# [17/17] - 4s - train: { MAE (loss): 3.36 - RMSE: 6.83 - MAPE: 9.39% } - val: { MAE: 3.02 - RMSE: 6.36 - MAPE: 8.44% } - lr: 0.001 - weight decay: 2e-06
# Epoch 196/200
# [17/17] - 4s - train: { MAE (loss): 3.42 - RMSE: 6.89 - MAPE: 9.5% } - val: { MAE: 3.04 - RMSE: 6.31 - MAPE: 8.76% } - lr: 0.001 - weight decay: 2e-06
# Epoch 197/200
# [17/17] - 4s - train: { MAE (loss): 3.38 - RMSE: 6.8 - MAPE: 9.49% } - val: { MAE: 3.09 - RMSE: 6.33 - MAPE: 8.68% } - lr: 0.001 - weight decay: 2e-06
# Epoch 198/200
# [17/17] - 4s - train: { MAE (loss): 3.33 - RMSE: 6.75 - MAPE: 9.24% } - val: { MAE: 3.02 - RMSE: 6.3 - MAPE: 8.71% } - lr: 0.001 - weight decay: 2e-06
# Epoch 199/200
# [17/17] - 4s - train: { MAE (loss): 3.33 - RMSE: 6.75 - MAPE: 9.24% } - val: { MAE: 3.06 - RMSE: 6.34 - MAPE: 8.81% } - lr: 0.001 - weight decay: 2e-06
# Epoch 200/200
# [17/17] - 4s - train: { MAE (loss): 3.34 - RMSE: 6.75 - MAPE: 9.29% } - val: { MAE: 3.08 - RMSE: 6.29 - MAPE: 8.73% } - lr: 0.001 - weight decay: 2e-06

# %%
from src.spatial_temporal_gnn.training import plot_training_history

plot_training_history(history)

# %% [markdown]
# # 3 Evaluation and Error Analysis
# The model is finally evaluated on the test dataset and a brief error analysis is performed.

# %% [markdown]
# The trained model is evaluated on the test dataset, considering the error results on predictions of the next $15$, $30$ and $60$ minutes.
#
# As expected, predictions of closer events in term of time lead to lower errors.

# %%
from src.spatial_temporal_gnn.training import validate

test_mae_15_min, test_rmse_15_min, test_mape_15_min = validate(
    model, test_dataloader, scaler,
    DEVICE, 3)
print('Results on the test set considering the next 15 minutes:',
      f'MAE {test_mae_15_min:.3g} - RMSE {test_rmse_15_min:.3g}',
      f'- MAPE {test_mape_15_min * 100.:.3g} %')

test_mae_30_min, test_rmse_30_min, test_mape_30_min = validate(
    model, test_dataloader, scaler,
    DEVICE, 6)
print('Results on the test set considering the next 30 minutes:',
      f'MAE {test_mae_30_min:.3g} - RMSE {test_rmse_30_min:.3g}',
      f'- MAPE {test_mape_30_min * 100.:.3g} %')

test_mae_60_min, test_rmse_60_min, test_mape_60_min = validate(
    model, test_dataloader, scaler,
    DEVICE)
print('Results on the test set considering the next 60 minutes:',
      f'MAE {test_mae_60_min:.3g} - RMSE {test_rmse_60_min:.3g}',
      f'- MAPE {test_mape_60_min * 100.:.3g} %')
# Out:
# Results on the test set considering the next 15 minutes: MAE 2.83 - RMSE 5.35 - MAPE 7.43 %
# Results on the test set considering the next 30 minutes: MAE 3.17 - RMSE 6.23 - MAPE 8.62 %
# Results on the test set considering the next 60 minutes: MAE 3.75 - RMSE 7.5 - MAPE 10.9 %

# %%
from src.spatial_temporal_gnn.prediction import (
    get_ground_truth_and_predictions)

y_true, y_pred = get_ground_truth_and_predictions(
    model, test_dataloader, DEVICE, scaler, use_standardized_scale=False)

# %% [markdown]
# The next plot represents the comparison of ground truth speeds and predicted speeds in the test dataset for a series of randomly selected nodes and timestamps. We can observe that the model performs quite well, although some speed peaks and troughs are hardly predicted correctly.

# %%
from src.spatial_temporal_gnn.prediction import plot_results_comparison

plot_results_comparison(y_true, y_pred, ['Speed'])

# %% [markdown]
# Finally, we observe the scatter plot represents the fitness of ground truth speeds and predicted speeds in the test dataset for a series of randomly selected nodes and timestamps.
#
# It looks like that the error variation for higher speed nodes is higher than for slower speed ones. This is expected as the distribution of speed in the dataset is particularly left skewed.

# %%
from src.spatial_temporal_gnn.prediction import plot_results_fitness

plot_results_fitness(y_true, y_pred, ['Speed'])
