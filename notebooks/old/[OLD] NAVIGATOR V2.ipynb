# %%
import sys
import os

# Set the main path in the root folder of the project.
sys.path.append(os.path.join('..'))

# %%
# Settings for autoreloading.
# %load_ext autoreload
# %autoreload 2

# %%
from src.utils.seed import set_random_seed

# Set the random seed for deterministic operations.
SEED = 42
set_random_seed(SEED)

# %%
import torch

# Set the device for training and querying the model.
DEVICE = 'cuda' if torch.cuda.is_available() else 'cpu'
print(f'The selected device is: "{DEVICE}"')
# Out:
# The selected device is: "cuda"

# %% [markdown]
# # Building the event set

# %%
import os

BASE_DATA_DIR = os.path.join('..', 'data', 'metr-la')

# %%
import pickle
with open(os.path.join(BASE_DATA_DIR, 'processed', 'scaler.pkl'), 'rb') as f:
    scaler = pickle.load(f)

# %%
from src.spatial_temporal_gnn.model import SpatialTemporalGNN
from src.data.data_extraction import get_adjacency_matrix

# Get the adjacency matrix
adj_matrix_structure = get_adjacency_matrix(
    os.path.join(BASE_DATA_DIR, 'adj_mx_metr_la.pkl'))

# Get the header of the adjacency matrix and the matrix itself.
header, _, adj_matrix = adj_matrix_structure

spatial_temporal_gnn = SpatialTemporalGNN(9, 1, 12, 12, adj_matrix, DEVICE, 64)

stgnn_checkpoints_path = os.path.join('..', 'models', 'checkpoints',
                                      'st_gnn_metr_la.pth')

stgnn_checkpoints = torch.load(stgnn_checkpoints_path)
spatial_temporal_gnn.load_state_dict(stgnn_checkpoints['model_state_dict'])

spatial_temporal_gnn.eval()
# Out:
# SpatialTemporalGNN(
#   (encoder): Linear(in_features=9, out_features=64, bias=False)
#   (s_gnns): ModuleList(
#     (0): S_GNN(
#       (latent_encoder): Sequential(
#         (0): Linear(in_features=64, out_features=64, bias=False)
#         (1): Linear(in_features=64, out_features=32, bias=False)
#       )
#       (linear): Linear(in_features=64, out_features=64, bias=False)
#     )
#     (1): S_GNN(
#       (latent_encoder): Sequential(
#         (0): Linear(in_features=64, out_features=64, bias=False)
#         (1): Linear(in_features=64, out_features=32, bias=False)
#       )
#       (linear): Linear(in_features=64, out_features=64, bias=False)
#     )
#     (2): S_GNN(
#       (latent_encoder): Sequential(
#         (0): Linear(in_features=64, out_features=64, bias=False)
#         (1): Linear(in_features=64, out_features=32, bias=False)
#       )
#       (linear): Linear(in_features=64, out_features=64, bias=False)
#     )
#     (3): S_GNN(
#       (latent_encoder): Sequential(
#         (0): Linear(in_features=64, out_features=64, bias=False)
#         (1): Linear(in_features=64, out_features=32, bias=False)
#       )
#       (linear): Linear(in_features=64, out_features=64, bias=False)
#     )
#     (4): S_GNN(
#       (latent_encoder): Sequential(
#         (0): Linear(in_features=64, out_features=64, bias=False)
#         (1): Linear(in_features=64, out_features=32, bias=False)
#       )
#       (linear): Linear(in_features=64, out_features=64, bias=False)
#     )
#     (5): S_GNN(
#       (latent_encoder): Sequential(
#         (0): Linear(in_features=64, out_features=64, bias=False)
#         (1): Linear(in_features=64, out_features=32, bias=False)
#       )
#       (linear): Linear(in_features=64, out_features=64, bias=False)
#     )
#     (6): S_GNN(
#       (latent_encoder): Sequential(
#         (0): Linear(in_features=64, out_features=64, bias=False)
#         (1): Linear(in_features=64, out_features=32, bias=False)
#       )
#       (linear): Linear(in_features=64, out_features=64, bias=False)
#     )
#     (7): S_GNN(
#       (latent_encoder): Sequential(
#         (0): Linear(in_features=64, out_features=64, bias=False)
#         (1): Linear(in_features=64, out_features=32, bias=False)
#       )
#       (linear): Linear(in_features=64, out_features=64, bias=False)
#     )
#     (8): S_GNN(
#       (latent_encoder): Sequential(
#         (0): Linear(in_features=64, out_features=64, bias=False)
#         (1): Linear(in_features=64, out_features=32, bias=False)
#       )
#       (linear): Linear(in_features=64, out_features=64, bias=False)
#     )
#     (9): S_GNN(
#       (latent_encoder): Sequential(
#         (0): Linear(in_features=64, out_features=64, bias=False)
#         (1): Linear(in_features=64, out_features=32, bias=False)
#       )
#       (linear): Linear(in_features=64, out_features=64, bias=False)
#     )
#     (10): S_GNN(
#       (latent_encoder): Sequential(
#         (0): Linear(in_features=64, out_features=64, bias=False)
#         (1): Linear(in_features=64, out_features=32, bias=False)
#       )
#       (linear): Linear(in_features=64, out_features=64, bias=False)
#     )
#     (11): S_GNN(
#       (latent_encoder): Sequential(
#         (0): Linear(in_features=64, out_features=64, bias=False)
#         (1): Linear(in_features=64, out_features=32, bias=False)
#       )
#       (linear): Linear(in_features=64, out_features=64, bias=False)
#     )
#   )
#   (hidden_s_gnns): ModuleList(
#     (0): S_GNN(
#       (latent_encoder): Sequential(
#         (0): Linear(in_features=64, out_features=64, bias=False)
#         (1): Linear(in_features=64, out_features=32, bias=False)
#       )
#       (linear): Linear(in_features=64, out_features=64, bias=False)
#     )
#     (1): S_GNN(
#       (latent_encoder): Sequential(
#         (0): Linear(in_features=64, out_features=64, bias=False)
#         (1): Linear(in_features=64, out_features=32, bias=False)
#       )
#       (linear): Linear(in_features=64, out_features=64, bias=False)
#     )
#     (2): S_GNN(
#       (latent_encoder): Sequential(
#         (0): Linear(in_features=64, out_features=64, bias=False)
#         (1): Linear(in_features=64, out_features=32, bias=False)
#       )
#       (linear): Linear(in_features=64, out_features=64, bias=False)
#     )
#     (3): S_GNN(
#       (latent_encoder): Sequential(
#         (0): Linear(in_features=64, out_features=64, bias=False)
#         (1): Linear(in_features=64, out_features=32, bias=False)
#       )
#       (linear): Linear(in_features=64, out_features=64, bias=False)
#     )
#     (4): S_GNN(
#       (latent_encoder): Sequential(
#         (0): Linear(in_features=64, out_features=64, bias=False)
#         (1): Linear(in_features=64, out_features=32, bias=False)
#       )
#       (linear): Linear(in_features=64, out_features=64, bias=False)
#     )
#     (5): S_GNN(
#       (latent_encoder): Sequential(
#         (0): Linear(in_features=64, out_features=64, bias=False)
#         (1): Linear(in_features=64, out_features=32, bias=False)
#       )
#       (linear): Linear(in_features=64, out_features=64, bias=False)
#     )
#     (6): S_GNN(
#       (latent_encoder): Sequential(
#         (0): Linear(in_features=64, out_features=64, bias=False)
#         (1): Linear(in_features=64, out_features=32, bias=False)
#       )
#       (linear): Linear(in_features=64, out_features=64, bias=False)
#     )
#     (7): S_GNN(
#       (latent_encoder): Sequential(
#         (0): Linear(in_features=64, out_features=64, bias=False)
#         (1): Linear(in_features=64, out_features=32, bias=False)
#       )
#       (linear): Linear(in_features=64, out_features=64, bias=False)
#     )
#     (8): S_GNN(
#       (latent_encoder): Sequential(
#         (0): Linear(in_features=64, out_features=64, bias=False)
#         (1): Linear(in_features=64, out_features=32, bias=False)
#       )
#       (linear): Linear(in_features=64, out_features=64, bias=False)
#     )
#     (9): S_GNN(
#       (latent_encoder): Sequential(
#         (0): Linear(in_features=64, out_features=64, bias=False)
#         (1): Linear(in_features=64, out_features=32, bias=False)
#       )
#       (linear): Linear(in_features=64, out_features=64, bias=False)
#     )
#     (10): S_GNN(
#       (latent_encoder): Sequential(
#         (0): Linear(in_features=64, out_features=64, bias=False)
#         (1): Linear(in_features=64, out_features=32, bias=False)
#       )
#       (linear): Linear(in_features=64, out_features=64, bias=False)
#     )
#   )
#   (grus): ModuleList(
#     (0): GRU(
#       (z_x_linear): Linear(in_features=64, out_features=64, bias=False)
#       (z_h_linear): Linear(in_features=64, out_features=64, bias=False)
#       (r_x_linear): Linear(in_features=64, out_features=64, bias=False)
#       (r_h_linear): Linear(in_features=64, out_features=64, bias=False)
#       (h_x_linear): Linear(in_features=64, out_features=64, bias=False)
#       (h_h_linear): Linear(in_features=64, out_features=64, bias=False)
#     )
#     (1): GRU(
#       (z_x_linear): Linear(in_features=64, out_features=64, bias=False)
#       (z_h_linear): Linear(in_features=64, out_features=64, bias=False)
#       (r_x_linear): Linear(in_features=64, out_features=64, bias=False)
#       (r_h_linear): Linear(in_features=64, out_features=64, bias=False)
#       (h_x_linear): Linear(in_features=64, out_features=64, bias=False)
#       (h_h_linear): Linear(in_features=64, out_features=64, bias=False)
#     )
#     (2): GRU(
#       (z_x_linear): Linear(in_features=64, out_features=64, bias=False)
#       (z_h_linear): Linear(in_features=64, out_features=64, bias=False)
#       (r_x_linear): Linear(in_features=64, out_features=64, bias=False)
#       (r_h_linear): Linear(in_features=64, out_features=64, bias=False)
#       (h_x_linear): Linear(in_features=64, out_features=64, bias=False)
#       (h_h_linear): Linear(in_features=64, out_features=64, bias=False)
#     )
#     (3): GRU(
#       (z_x_linear): Linear(in_features=64, out_features=64, bias=False)
#       (z_h_linear): Linear(in_features=64, out_features=64, bias=False)
#       (r_x_linear): Linear(in_features=64, out_features=64, bias=False)
#       (r_h_linear): Linear(in_features=64, out_features=64, bias=False)
#       (h_x_linear): Linear(in_features=64, out_features=64, bias=False)
#       (h_h_linear): Linear(in_features=64, out_features=64, bias=False)
#     )
#     (4): GRU(
#       (z_x_linear): Linear(in_features=64, out_features=64, bias=False)
#       (z_h_linear): Linear(in_features=64, out_features=64, bias=False)
#       (r_x_linear): Linear(in_features=64, out_features=64, bias=False)
#       (r_h_linear): Linear(in_features=64, out_features=64, bias=False)
#       (h_x_linear): Linear(in_features=64, out_features=64, bias=False)
#       (h_h_linear): Linear(in_features=64, out_features=64, bias=False)
#     )
#     (5): GRU(
#       (z_x_linear): Linear(in_features=64, out_features=64, bias=False)
#       (z_h_linear): Linear(in_features=64, out_features=64, bias=False)
#       (r_x_linear): Linear(in_features=64, out_features=64, bias=False)
#       (r_h_linear): Linear(in_features=64, out_features=64, bias=False)
#       (h_x_linear): Linear(in_features=64, out_features=64, bias=False)
#       (h_h_linear): Linear(in_features=64, out_features=64, bias=False)
#     )
#     (6): GRU(
#       (z_x_linear): Linear(in_features=64, out_features=64, bias=False)
#       (z_h_linear): Linear(in_features=64, out_features=64, bias=False)
#       (r_x_linear): Linear(in_features=64, out_features=64, bias=False)
#       (r_h_linear): Linear(in_features=64, out_features=64, bias=False)
#       (h_x_linear): Linear(in_features=64, out_features=64, bias=False)
#       (h_h_linear): Linear(in_features=64, out_features=64, bias=False)
#     )
#     (7): GRU(
#       (z_x_linear): Linear(in_features=64, out_features=64, bias=False)
#       (z_h_linear): Linear(in_features=64, out_features=64, bias=False)
#       (r_x_linear): Linear(in_features=64, out_features=64, bias=False)
#       (r_h_linear): Linear(in_features=64, out_features=64, bias=False)
#       (h_x_linear): Linear(in_features=64, out_features=64, bias=False)
#       (h_h_linear): Linear(in_features=64, out_features=64, bias=False)
#     )
#     (8): GRU(
#       (z_x_linear): Linear(in_features=64, out_features=64, bias=False)
#       (z_h_linear): Linear(in_features=64, out_features=64, bias=False)
#       (r_x_linear): Linear(in_features=64, out_features=64, bias=False)
#       (r_h_linear): Linear(in_features=64, out_features=64, bias=False)
#       (h_x_linear): Linear(in_features=64, out_features=64, bias=False)
#       (h_h_linear): Linear(in_features=64, out_features=64, bias=False)
#     )
#     (9): GRU(
#       (z_x_linear): Linear(in_features=64, out_features=64, bias=False)
#       (z_h_linear): Linear(in_features=64, out_features=64, bias=False)
#       (r_x_linear): Linear(in_features=64, out_features=64, bias=False)
#       (r_h_linear): Linear(in_features=64, out_features=64, bias=False)
#       (h_x_linear): Linear(in_features=64, out_features=64, bias=False)
#       (h_h_linear): Linear(in_features=64, out_features=64, bias=False)
#     )
#     (10): GRU(
#       (z_x_linear): Linear(in_features=64, out_features=64, bias=False)
#       (z_h_linear): Linear(in_features=64, out_features=64, bias=False)
#       (r_x_linear): Linear(in_features=64, out_features=64, bias=False)
#       (r_h_linear): Linear(in_features=64, out_features=64, bias=False)
#       (h_x_linear): Linear(in_features=64, out_features=64, bias=False)
#       (h_h_linear): Linear(in_features=64, out_features=64, bias=False)
#     )
#     (11): GRU(
#       (z_x_linear): Linear(in_features=64, out_features=64, bias=False)
#       (z_h_linear): Linear(in_features=64, out_features=64, bias=False)
#       (r_x_linear): Linear(in_features=64, out_features=64, bias=False)
#       (r_h_linear): Linear(in_features=64, out_features=64, bias=False)
#       (h_x_linear): Linear(in_features=64, out_features=64, bias=False)
#       (h_h_linear): Linear(in_features=64, out_features=64, bias=False)
#     )
#   )
#   (positional_encoder): PositionalEncoder()
#   (transformer): Transformer(
#     (queries_linear): Linear(in_features=64, out_features=64, bias=False)
#     (keys_linear): Linear(in_features=64, out_features=64, bias=False)
#     (values_linear): Linear(in_features=64, out_features=64, bias=False)
#     (normalization): BatchNorm2d(12, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#     (normalization_out): BatchNorm2d(12, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#     (feed_forward): Sequential(
#       (0): Linear(in_features=64, out_features=64, bias=False)
#       (1): ReLU()
#       (2): Linear(in_features=64, out_features=64, bias=False)
#     )
#   )
#   (prediction_head): Sequential(
#     (0): Linear(in_features=64, out_features=64, bias=False)
#     (1): ReLU()
#     (2): Linear(in_features=64, out_features=1, bias=False)
#   )
# )

# %%
import os
import numpy as np
from src.spatial_temporal_gnn.prediction import predict

x_train = np.load(os.path.join(BASE_DATA_DIR, 'processed', 'x_train.npy'))
y_train = predict(spatial_temporal_gnn, x_train, scaler, DEVICE)
x_val = np.load(os.path.join(BASE_DATA_DIR, 'processed', 'x_val.npy'))
y_val = predict(spatial_temporal_gnn, x_val, scaler, DEVICE)
x_test = np.load(os.path.join(BASE_DATA_DIR, 'processed', 'x_test.npy'))
y_test = predict(spatial_temporal_gnn, x_test, scaler, DEVICE)

# %%
from typing import List, Optional, Tuple

from src.data.data_analysis import days_encoder

def get_largest_event_set(data: np.ndarray
                          ) -> List[Tuple[str, Optional[int], Optional[int]]]:
    n_time_steps, n_nodes, _ = data.shape[-3:]
    
    # Get the largest event set related to the speed.
    speed_events = [
        (0, time_step, node) 
        for time_step in range(n_time_steps) 
        for node in range(n_nodes) 
        if data[..., time_step, node, 0] > 0]
    # Get the largest event set related to the time of day.
    time_of_day_events = [
        (1, time_step, None) for time_step in range(n_time_steps)]
    # Get the largest event set related to the day of week.
    day_of_week_events = [(2, None, None)]
    # Get the largest event set related to the kind of day.
    #kind_of_day_events = [(3, None, None)]
    
    return speed_events + time_of_day_events + day_of_week_events #+\
    #    kind_of_day_events

# %%
s = get_largest_event_set(x_test[11])

# %% [markdown]
# # Map the event set to the graph

# %%
from typing import List, Optional, Tuple, Union
import torch

def remove_features_by_events(
    data: Union[np.ndarray, torch.FloatTensor],
    events: List[Tuple[int, Optional[int], Optional[int]]]
    ) -> Union[np.ndarray, torch.FloatTensor]:
    if isinstance(data, torch.FloatTensor):
        filtered_data = data.clone()
    else:
        filtered_data = data.copy()
    n_time_steps, n_nodes, n_features = filtered_data.shape[-3:]
    
    speed_events = [tuple(event) for event in events if event[0] == 0]
    time_of_day_events = [tuple(event) for event in events if event[0] == 1]
    day_of_week_events = [tuple(event) for event in events if event[0] == 2]
    #kind_of_day_events = [event for event in events if event[0] == 3]
    
    if n_features > 1 and not len(day_of_week_events):
        filtered_data[..., -7:] = 0
    
    for time_step in range(n_time_steps):
        for node in range(n_nodes):
            if (0, time_step, node) not in speed_events:
                filtered_data[..., time_step, node, 0] = 0

            '''if n_features > 1 and len(kind_of_day_events):
                if 1 in data[..., -7:-2]:
                    filtered_data[..., time_step, node, -7:-2] = 1
                else:
                    filtered_data[..., time_step, node, -2:] = 1'''

        if n_features > 1 and (1, time_step, None) not in time_of_day_events:
            filtered_data[..., time_step, :, 1] = -1
    
    return filtered_data

# %%
def remove_single_event_from_data(
    data: Union[np.ndarray, torch.FloatTensor],
    event: Union[np.ndarray, torch.FloatTensor]
    ) -> Union[np.ndarray, torch.FloatTensor]:
    # n_time_steps, n_nodes, _ = data.shape[-3:]
    event_kind = event[0]
    time_step = int(event[1].item())
    node = int(event[2].item())
    if event_kind == 0:
        data[..., time_step, node, 0] = 0
    elif event_kind == 1:
        data[..., time_step, :, 1] = -1
    elif event_kind == 2:
        data[..., -7:] = 0
    #elif event[0] == 3:
    #    pass

    '''if event_kind in [0, 1]: 
        for time_step in range(n_time_steps):
            for node in range(n_nodes):
                if 1 in data[..., -7:-2]:
                    data[..., time_step, node, -7:-2] = 1
                else:
                    data[..., time_step, node, -2:] = 1'''

    return data

# %%
s = remove_features_by_events(x_test[0], [(1, 0, None)])

# %%
# (event_type, speed, time_of_day, ...day, speed_target, time_of_day_target, ...day_target)

# ->

# -> score

# %%
y_test[0].shape
# Out:
# (12, 207, 1)

# %%
import torch
from torch import nn
import numpy as np

def simulate_model(
    instance: torch.FloatTensor, events_scores: torch.FloatTensor) -> torch.FloatTensor:
    #eps = torch.rand_like(events_scores).float().to(instance.device)
    #eps_hat = (eps.log() - (1 - eps).log() + instance) / 1.0
    events_scores = events_scores.sigmoid()
    #eps = torch.rand_like(events_scores)
    eps = torch.rand(1).to(instance.device)
    events_scores = torch.sigmoid((eps.log() - (1 - eps).log() + events_scores) / 2.0)
    # TODO: Simulate all events, not just the speed events.
    #relaxed_bernoulli = torch.distributions.RelaxedBernoulli(2.0, events_scores)
    #e = torch.sigmoid(events_scores)
    #e = relaxed_bernoulli.sample()
    #e = torch.rand(1).float().to(instance.device)
    #e_hat = torch.sigmoid((torch.log(e) - torch.log(1 - e) + events_scores) / .05)
    result = events_scores >= .5
    #print(result)
    #result = torch.bernoulli(events_scores)
    instance = result * instance
    return instance

# %%
import torch
from torch import nn

class Navigator(nn.Module):
    def __init__(self, device: str, hidden_features: int = 64) -> None:
        super().__init__()
        self.graph_encoder = nn.Conv2d(12, 6, kernel_size=(207, 1))


        # Set the linear encoder.
        self.linear_encoder = nn.LazyLinear(hidden_features)
        # Set the linear decoder.
        self.linear_decoder = nn.Linear(hidden_features, 1)
        # Set the device that is used for training and querying the model.
        self.device = device
        self.to(device)

    def forward(self, candidate_event: torch.FloatTensor, target_events: torch.FloatTensor) -> torch.FloatTensor:
        # Flatten the target events.
        y = self.graph_encoder(target_events)
        y = y.flatten(start_dim=1)
        # print(y.shape, y)
        #target_events = target_events.flatten(start_dim=1)
        # Concatenate the candidate event and the target events.
        x = torch.cat((candidate_event, y), dim=1)
        # Encode the input.
        out = self.linear_encoder(x)
        # Decode the output to get the logits prediction.
        out = self.linear_decoder(out)
        return out

# %%
model = Navigator(DEVICE)
# Out:
# c:\Users\riccardo\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\nn\modules\lazy.py:180: UserWarning: Lazy modules are a new feature under heavy development so changes to the API or functionality can happen at any moment.
#   warnings.warn('Lazy modules are a new feature under heavy development '

# %%
from typing import Tuple
from torch.utils.data.dataloader import DataLoader, Dataset
import numpy as np

from src.spatial_temporal_gnn.prediction import predict


class EventsDataset(Dataset):
    def __init__(self, x: np.ndarray, y: np.ndarray) -> None:
        """Initialize the dataset

        Parameters
        ----------
        x : ndarray
            The input values of the dataset.
        y : ndarray
            The ground truth of the dataset's input data.
        """
        # Filter out the instances that do not have speed values at all.
        self.x = x[np.any(x[..., 0] != 0, axis=(1, 2))]
        self.y = y[np.any(x[..., 0] != 0, axis=(1, 2))]
        self.len = self.x.shape[0]

    def _mask_random_instance_features(self, instance: np.ndarray) -> np.ndarray:
        """Mask random features of a Spatial-Temporal Graph instance.

        Parameters
        ----------
        instance : ndarray
            The Spatial-Temporal Graph instance to mask random features
            from.

        Returns
        -------
        ndarray
            The Spatial-Temporal Graph instance with masked random
            features.
        """
        # Get the largest event set of the input instance.
        events = np.array(get_largest_event_set(instance))

        # TODO: consider all events, not solely speed events.
        events = events[events[..., 0] == 0]

        # Get the possible subset sizes of the input and target events.
        events_subset_sizes = np.arange(1, len(events) + 1)
        
        # Compute the probabilities of selecting certain subset sizes.
        # Favor larger subset sizes.
        sizes_probs = np.array(
            events_subset_sizes / np.sum(events_subset_sizes))

        # Select the size of the input events subset.
        [size] = np.random.choice(range(1, len(events) + 1), 1, p=sizes_probs)

        # Randomly select the events subset based on the selected size.
        selected_events_idx = np.random.choice(
            np.arange(len(events)), size=size, replace=False)
        selected_events = events[selected_events_idx]
        # Remove the features corresponding to the selected events.
        instance = remove_features_by_events(instance, selected_events.tolist())
        return instance

    def __getitem__(self, index: int) -> Tuple[np.ndarray, np.ndarray]:
        """Get a dataset 

        Parameters
        ----------
        index : int
            The index from where to extract the dataset instance.

        Returns
        -------
        ndarray
            The input data at the given index with masked random
            features.
        ndarray
            The ground truth with respect to the input data at the
            given index with masked random features.
        """
        x = self.x[index].copy()
        y = self.y[index].copy()
        
        events = np.array(get_largest_event_set(x))
        events = events[events[..., 0] == 0]
        #print(events)

        instances = []

        for event in events:
            instance = x[event[1], event[2], :]
            instance = [event[1], event[2], *instance]
            instances.append(instance)
        y = self._mask_random_instance_features(y)

        instances = np.array(instances)

        return x, instances, y #y_pred

    def __len__(self) -> int:
        """Get the length of the dataset.

        Returns
        -------
        int
            The length of the dataset.
        """
        return self.len

def get_dataloader(x: np.ndarray, y: np.ndarray, 
                   batch_size: int, shuffle: bool) -> DataLoader:
    dataset = EventsDataset(x, y)
    return DataLoader(dataset, batch_size=batch_size, shuffle=shuffle)

# %%
train_loader = get_dataloader(x_train, y_train, batch_size=None, shuffle=True)
val_loader = get_dataloader(x_val, y_val, batch_size=None, shuffle=False)

# %%
x  = next(iter(train_loader))

# %%
from src.spatial_temporal_gnn.training import Checkpoint

optimizer = torch.optim.Adam(model.parameters(), lr=1e-2, weight_decay=0)

#lr_scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
#    optimizer, mode='min', factor=.1, patience=2, verbose=False,
#    threshold=.001, threshold_mode='rel', cooldown=0, min_lr=1e-5, eps=1e-08)
lr_scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=1, gamma=0.94, verbose=False)

checkpoint_file_path = os.path.join('..', 'models', 'checkpoints',
                                    'navigator_metr_la.pth')
checkpoint = Checkpoint(checkpoint_file_path)

EPOCHS = 100

# %%
from time import time
from typing import Dict, List, Optional, Tuple, Union
import torch
from torch import nn
from torch.utils.data import DataLoader

from src.spatial_temporal_gnn.model import SpatialTemporalGNN
from src.spatial_temporal_gnn.metrics import MAE, RMSE, MAPE
from src.spatial_temporal_gnn.training import Checkpoint
from src.data.data_processing import Scaler

def train(
    model: Navigator, optimizer: torch.optim.Optimizer,
    train_dataloader: DataLoader, val_dataloader: DataLoader,
    spatial_temporal_gnn: SpatialTemporalGNN, scaler: Scaler,
    epochs: int, checkpoint: Optional[Checkpoint] = None,
    lr_scheduler: Optional[object] = None,
    reload_best_weights: bool = True) -> Dict[str, np.ndarray]:
    # Get the device that is used for training and querying the model.
    device = model.device

    # Initialize the training criterions.
    mae_criterion = MAE()
    rmse_criterion = RMSE()
    mape_criterion = MAPE()

    # Initialize the histories.
    metrics = ['train_mae', 'train_rmse', 'train_mape', 'val_mae', 'val_rmse',
               'val_mape']
    history = { m: [] for m in metrics }

    # Set model in training mode.
    model.train()

    # Iterate across the epochs.
    for epoch in range(epochs):
        print(f'Epoch {epoch + 1}/{epochs}')

        # Remove unused tensors from gpu memory.
        torch.cuda.empty_cache()

        # Initialize the running errors.
        running_train_mae = 0.
        running_train_rmse = 0.
        running_train_mape = 0.

        start_time = time()

        for batch_idx, (x, instances, y) in enumerate(train_dataloader):
            # Increment the number of batch steps.
            batch_steps = batch_idx + 1

            # Get the data.
            x = x.type(torch.float32).to(device=device)
            instances = instances.type(torch.float32).to(device=device)
            y = y.type(torch.float32).to(device=device)
            
            y_repeated = y.unsqueeze(0).repeat(instances.shape[0], 1, 1, 1)
            #print(y_repeated[0] == y)
            # Repeat y for each instance that has shape (Batch, Features)
            #t_repeated = t.unsqueeze(0).repeat(instances.shape[0], 3)

            event_scores = model(instances, y_repeated)

            ev_scores = torch.zeros((x.shape[0], x.shape[1], 1))
            
            for i, x_ in enumerate(instances):
                timestep = int(x_[0].item()); node = int(x_[1].item())
                ev_scores[timestep, node, 0] = event_scores[i]
                
            ev_scores = ev_scores.to(device=device)
            # print(ev_scores.shape, x.shape)
            x_sim = simulate_model(x, ev_scores)
            #print(x_sim.shape)
            x_sim = scaler.scale(x_sim)

            # Compute the Spatial-Temporal GNN model predictions.
            y_pred = spatial_temporal_gnn(x_sim.unsqueeze(0))

            # Un-scale the predictions.
            y_pred = scaler.un_scale(y_pred)

            loss = mae_criterion(y_pred, y.unsqueeze(0))
            
            #print(y)

            # Compute errors and update running errors.
            with torch.no_grad():
                rmse = rmse_criterion(y_pred, y.unsqueeze(0))
                mape = mape_criterion(y_pred, y.unsqueeze(0))

            running_train_mae += loss.item()
            running_train_rmse += rmse.item()
            running_train_mape += mape.item()

            # Zero the gradients.
            optimizer.zero_grad()

            # Use MAE as the loss function for backpropagation.
            loss.backward()
            
            for param in spatial_temporal_gnn.parameters():
                param.grad[:] = 0

            # Update the weights.
            optimizer.step()

            # Get the batch time.
            epoch_time = time() - start_time
            batch_time = epoch_time / batch_steps

            # Print the batch results.
            print(
                f'[{batch_steps}/{len(train_dataloader)}] -',
                f'{epoch_time:.0f}s {batch_time * 1e3:.0f}ms/step -',

                f'train {{ MAE (loss): {running_train_mae / batch_steps:.3g} -',
                f'RMSE: {running_train_rmse / batch_steps:.3g} -',
                f'MAPE: {running_train_mape * 100. / batch_steps:.3g}% }} -',

                f'lr: {optimizer.param_groups[0]["lr"]:.3g} -',
                f'weight decay: {optimizer.param_groups[0]["weight_decay"]}',
                '             ' if batch_steps < len(train_dataloader) else '',
                end='\r')

        # Set the model in evaluation mode.
        model.eval()

        # Get the average training errors and update the history.
        train_mae = running_train_mae / len(train_dataloader)
        train_rmse = running_train_rmse / len(train_dataloader)
        train_mape = running_train_mape / len(train_dataloader)

        history['train_mae'].append(train_mae)
        history['train_rmse'].append(train_rmse)
        history['train_mape'].append(train_mape)

        # Get the validation results and update the history.
        val_results = validate(model, val_dataloader, spatial_temporal_gnn,
                               scaler)
        val_mae, val_rmse, val_mape = val_results

        history['val_mae'].append(val_mae)
        history['val_rmse'].append(val_rmse)
        history['val_mape'].append(val_mape)

        # Save the checkpoints if demanded.
        if checkpoint is not None:
            err_sum = val_mae + val_rmse + val_mape
            checkpoint.save_best(model, optimizer, err_sum)

        # Print the epoch results.
        print(
            f'[{len(train_dataloader)}/{len(train_dataloader)}] -',
            f'{epoch_time:.0f}s -',

            f'train: {{ MAE (loss): {train_mae:.3g} -',
            f'RMSE: {train_rmse:.3g} -',
            f'MAPE: {train_mape * 100.:.3g}% }} -',

            f'val: {{ MAE: {val_mae:.3g} -',
            f'RMSE: {val_rmse:.3g} -',
            f'MAPE: {val_mape * 100.:.3g}% }} -',

            f'lr: {optimizer.param_groups[0]["lr"]:.3g} -',
            f'weight decay: {optimizer.param_groups[0]["weight_decay"]}')

        # Update the learning rate scheduler.
        #lr_scheduler.step(train_mae)

        # Set model in training mode.
        lr_scheduler.step()
        model.train()

    # Load the best weights of the model if demanded.
    if checkpoint is not None and reload_best_weights:
        checkpoint.load_best_weights(model)

    # Set the model in evaluation mode.
    model.eval()

    # Remove unused tensors from gpu memory.
    torch.cuda.empty_cache()

    # Turn the history to numpy arrays.
    for k, v in history.items():
        history[k] = np.array(v)

    return history

def validate(
    model: Navigator, val_dataloader: DataLoader,
    spatial_temporal_gnn: SpatialTemporalGNN, scaler: Scaler
    ) -> Tuple[float, float, float]:
    device = model.device
    torch.cuda.empty_cache()

    # Initialize the validation criterions.
    mae_criterion = MAE()
    rmse_criterion = RMSE()
    mape_criterion = MAPE()

    # Inizialize running errors.
    running_val_mae = 0.
    running_val_rmse = 0.
    running_val_mape = 0.

    with torch.no_grad():
        for x, instances, y in val_dataloader:
            # Get the data.
            x = x.type(torch.float32).to(device=device)
            instances = instances.type(torch.float32).to(device=device)
            y = y.type(torch.float32).to(device=device)
            
            y_repeated = y.unsqueeze(0).repeat(instances.shape[0], 1, 1, 1)

            event_scores = model(instances, y_repeated)

            ev_scores = torch.zeros((x.shape[0], x.shape[1], 1))
            
            for i, x_ in enumerate(instances):
                timestep = int(x_[0].item()); node = int(x_[1].item())
                ev_scores[timestep, node, 0] = event_scores[i]
                
            ev_scores = ev_scores.to(device=device)
            # print(ev_scores.shape, x.shape)
            x_sim = simulate_model(x, ev_scores)
            #print(x_sim.shape)
            x_sim = scaler.scale(x_sim)

            # Compute the Spatial-Temporal GNN model predictions.
            y_pred = spatial_temporal_gnn(x_sim.unsqueeze(0))

            # Un-scale the predictions.
            y_pred = scaler.un_scale(y_pred)

            # Get the prediction errors and update the running errors.
            mae = mae_criterion(y_pred, y.unsqueeze(0))
            rmse = rmse_criterion(y_pred, y.unsqueeze(0))
            mape = mape_criterion(y_pred, y.unsqueeze(0))

            running_val_mae += mae.item()
            running_val_rmse += rmse.item()
            running_val_mape += mape.item()

    # Remove unused tensors from gpu memory.
    torch.cuda.empty_cache()

    # Get the average MAE, RMSE and MAPE scores.
    val_mae = running_val_mae / len(val_dataloader)
    val_rmse = running_val_rmse / len(val_dataloader)
    val_mape = running_val_mape / len(val_dataloader)

    return val_mae, val_rmse, val_mape

# %%
history = train(
    model, optimizer, train_loader, val_loader, spatial_temporal_gnn, scaler,
    EPOCHS, checkpoint, lr_scheduler, reload_best_weights=True)
# Out:
# Epoch 1/100
# [988/988] - 724s - train: { MAE (loss): 3.06 - RMSE: 5 - MAPE: 9.13% } - val: { MAE: 2.82 - RMSE: 4.72 - MAPE: 7.84% } - lr: 0.01 - weight decay: 0
# Epoch 2/100
# [988/988] - 722s - train: { MAE (loss): 3.47 - RMSE: 5.66 - MAPE: 10.6% } - val: { MAE: 3.48 - RMSE: 5.57 - MAPE: 10.2% } - lr: 0.0094 - weight decay: 0
# Epoch 3/100
# [988/988] - 726s - train: { MAE (loss): 3.47 - RMSE: 5.62 - MAPE: 10.6% } - val: { MAE: 3.19 - RMSE: 5.23 - MAPE: 8.95% } - lr: 0.00884 - weight decay: 0
# Epoch 4/100
# [276/988] - 203s 734ms/step - train { MAE (loss): 3.47 - RMSE: 5.56 - MAPE: 10.5% } - lr: 0.00831 - weight decay: 0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\riccardo\Desktop\Verbal-Explanation-of-Graph-Neural-Networks-for-Traffic-Forecasting\notebooks\NAVIGATOR V2.ipynb Cell 30 in 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/riccardo/Desktop/Verbal-Explanation-of-Graph-Neural-Networks-for-Traffic-Forecasting/notebooks/NAVIGATOR%20V2.ipynb#X41sZmlsZQ%3D%3D?line=0'>1</a> history = train(
#       <a href='vscode-notebook-cell:/c%3A/Users/riccardo/Desktop/Verbal-Explanation-of-Graph-Neural-Networks-for-Traffic-Forecasting/notebooks/NAVIGATOR%20V2.ipynb#X41sZmlsZQ%3D%3D?line=1'>2</a>     model, optimizer, train_loader, val_loader, spatial_temporal_gnn, scaler,
#       <a href='vscode-notebook-cell:/c%3A/Users/riccardo/Desktop/Verbal-Explanation-of-Graph-Neural-Networks-for-Traffic-Forecasting/notebooks/NAVIGATOR%20V2.ipynb#X41sZmlsZQ%3D%3D?line=2'>3</a>     EPOCHS, checkpoint, lr_scheduler, reload_best_weights=True)
#
# c:\Users\riccardo\Desktop\Verbal-Explanation-of-Graph-Neural-Networks-for-Traffic-Forecasting\notebooks\NAVIGATOR V2.ipynb Cell 30 in 6
#      <a href='vscode-notebook-cell:/c%3A/Users/riccardo/Desktop/Verbal-Explanation-of-Graph-Neural-Networks-for-Traffic-Forecasting/notebooks/NAVIGATOR%20V2.ipynb#X41sZmlsZQ%3D%3D?line=64'>65</a> ev_scores = torch.zeros((x.shape[0], x.shape[1], 1))
#      <a href='vscode-notebook-cell:/c%3A/Users/riccardo/Desktop/Verbal-Explanation-of-Graph-Neural-Networks-for-Traffic-Forecasting/notebooks/NAVIGATOR%20V2.ipynb#X41sZmlsZQ%3D%3D?line=66'>67</a> for i, x_ in enumerate(instances):
# ---> <a href='vscode-notebook-cell:/c%3A/Users/riccardo/Desktop/Verbal-Explanation-of-Graph-Neural-Networks-for-Traffic-Forecasting/notebooks/NAVIGATOR%20V2.ipynb#X41sZmlsZQ%3D%3D?line=67'>68</a>     timestep = int(x_[0].item()); node = int(x_[1].item())
#      <a href='vscode-notebook-cell:/c%3A/Users/riccardo/Desktop/Verbal-Explanation-of-Graph-Neural-Networks-for-Traffic-Forecasting/notebooks/NAVIGATOR%20V2.ipynb#X41sZmlsZQ%3D%3D?line=68'>69</a>     ev_scores[timestep, node, 0] = event_scores[i]
#      <a href='vscode-notebook-cell:/c%3A/Users/riccardo/Desktop/Verbal-Explanation-of-Graph-Neural-Networks-for-Traffic-Forecasting/notebooks/NAVIGATOR%20V2.ipynb#X41sZmlsZQ%3D%3D?line=70'>71</a> ev_scores = ev_scores.to(device=device)
#
# KeyboardInterrupt:

# %%
#for(i, j) in zip(spatial_temporal_gnn.state_dict(), stgnn_checkpoints['model_state_dict']):
#    if i != j: print(True)

# %%
x, ev, y = next(iter(train_loader))

# %%
res = model(ev.to(DEVICE).float(), y.unsqueeze(0).repeat(ev.shape[0], 1, 1, 1).to(DEVICE).float())
ev_scores = torch.zeros((x.shape[0], x.shape[1], 1))
            
for i, x_ in enumerate(ev):
    timestep = int(x_[0].item()); node = int(x_[1].item())
    ev_scores[timestep, node, 0] = res[i]

# %%
for ev in torch.unique(ev_scores.sigmoid()):
    print(ev)
# Out:
# tensor(2.4888e-05, grad_fn=<UnbindBackward0>)
# tensor(2.5055e-05, grad_fn=<UnbindBackward0>)
# tensor(2.6995e-05, grad_fn=<UnbindBackward0>)
# tensor(2.8503e-05, grad_fn=<UnbindBackward0>)
# tensor(2.8654e-05, grad_fn=<UnbindBackward0>)
# tensor(2.9176e-05, grad_fn=<UnbindBackward0>)
# tensor(3.2264e-05, grad_fn=<UnbindBackward0>)
# tensor(3.2876e-05, grad_fn=<UnbindBackward0>)
# tensor(3.3349e-05, grad_fn=<UnbindBackward0>)
# tensor(3.3994e-05, grad_fn=<UnbindBackward0>)
# tensor(3.4439e-05, grad_fn=<UnbindBackward0>)
# tensor(3.5410e-05, grad_fn=<UnbindBackward0>)
# tensor(3.5991e-05, grad_fn=<UnbindBackward0>)
# tensor(3.6055e-05, grad_fn=<UnbindBackward0>)
# tensor(3.7073e-05, grad_fn=<UnbindBackward0>)
# tensor(3.8583e-05, grad_fn=<UnbindBackward0>)
# tensor(4.0125e-05, grad_fn=<UnbindBackward0>)
# tensor(4.0885e-05, grad_fn=<UnbindBackward0>)
# tensor(4.1972e-05, grad_fn=<UnbindBackward0>)
# tensor(4.1987e-05, grad_fn=<UnbindBackward0>)
# tensor(4.2031e-05, grad_fn=<UnbindBackward0>)
# tensor(4.2752e-05, grad_fn=<UnbindBackward0>)
# tensor(4.4373e-05, grad_fn=<UnbindBackward0>)
# tensor(4.4848e-05, grad_fn=<UnbindBackward0>)
# tensor(4.5863e-05, grad_fn=<UnbindBackward0>)
# tensor(4.7595e-05, grad_fn=<UnbindBackward0>)
# tensor(5.0480e-05, grad_fn=<UnbindBackward0>)
# tensor(5.0792e-05, grad_fn=<UnbindBackward0>)
# tensor(5.1812e-05, grad_fn=<UnbindBackward0>)
# tensor(5.3746e-05, grad_fn=<UnbindBackward0>)
# tensor(5.4459e-05, grad_fn=<UnbindBackward0>)
# tensor(5.6301e-05, grad_fn=<UnbindBackward0>)
# tensor(5.6966e-05, grad_fn=<UnbindBackward0>)
# tensor(5.7296e-05, grad_fn=<UnbindBackward0>)
# tensor(5.9555e-05, grad_fn=<UnbindBackward0>)
# tensor(5.9844e-05, grad_fn=<UnbindBackward0>)
# tensor(6.1057e-05, grad_fn=<UnbindBackward0>)
# tensor(6.1989e-05, grad_fn=<UnbindBackward0>)
# tensor(6.2917e-05, grad_fn=<UnbindBackward0>)
# tensor(6.3763e-05, grad_fn=<UnbindBackward0>)
# tensor(6.4028e-05, grad_fn=<UnbindBackward0>)
# tensor(6.4890e-05, grad_fn=<UnbindBackward0>)
# tensor(6.5551e-05, grad_fn=<UnbindBackward0>)
# tensor(6.6851e-05, grad_fn=<UnbindBackward0>)
# tensor(6.7569e-05, grad_fn=<UnbindBackward0>)
# tensor(6.7849e-05, grad_fn=<UnbindBackward0>)
# tensor(6.8066e-05, grad_fn=<UnbindBackward0>)
# tensor(6.9741e-05, grad_fn=<UnbindBackward0>)
# tensor(7.0451e-05, grad_fn=<UnbindBackward0>)
# tensor(7.1191e-05, grad_fn=<UnbindBackward0>)
# tensor(7.1230e-05, grad_fn=<UnbindBackward0>)
# tensor(7.1576e-05, grad_fn=<UnbindBackward0>)
# tensor(7.2331e-05, grad_fn=<UnbindBackward0>)
# tensor(7.2656e-05, grad_fn=<UnbindBackward0>)
# tensor(7.3144e-05, grad_fn=<UnbindBackward0>)
# tensor(7.4641e-05, grad_fn=<UnbindBackward0>)
# tensor(7.7414e-05, grad_fn=<UnbindBackward0>)
# tensor(7.8443e-05, grad_fn=<UnbindBackward0>)
# tensor(7.8712e-05, grad_fn=<UnbindBackward0>)
# tensor(8.1690e-05, grad_fn=<UnbindBackward0>)
# tensor(8.1951e-05, grad_fn=<UnbindBackward0>)
# tensor(8.2902e-05, grad_fn=<UnbindBackward0>)
# tensor(8.3559e-05, grad_fn=<UnbindBackward0>)
# tensor(8.4032e-05, grad_fn=<UnbindBackward0>)
# tensor(8.4131e-05, grad_fn=<UnbindBackward0>)
# tensor(8.4774e-05, grad_fn=<UnbindBackward0>)
# tensor(8.5412e-05, grad_fn=<UnbindBackward0>)
# tensor(8.5788e-05, grad_fn=<UnbindBackward0>)
# tensor(8.6152e-05, grad_fn=<UnbindBackward0>)
# tensor(8.6714e-05, grad_fn=<UnbindBackward0>)
# tensor(8.6953e-05, grad_fn=<UnbindBackward0>)
# tensor(8.7176e-05, grad_fn=<UnbindBackward0>)
# tensor(8.7502e-05, grad_fn=<UnbindBackward0>)
# tensor(8.8009e-05, grad_fn=<UnbindBackward0>)
# tensor(8.9835e-05, grad_fn=<UnbindBackward0>)
# tensor(9.0686e-05, grad_fn=<UnbindBackward0>)
# tensor(9.1444e-05, grad_fn=<UnbindBackward0>)
# tensor(9.2167e-05, grad_fn=<UnbindBackward0>)
# tensor(9.2207e-05, grad_fn=<UnbindBackward0>)
# tensor(9.2476e-05, grad_fn=<UnbindBackward0>)
# tensor(9.3511e-05, grad_fn=<UnbindBackward0>)
# tensor(9.4803e-05, grad_fn=<UnbindBackward0>)
# tensor(9.4818e-05, grad_fn=<UnbindBackward0>)
# tensor(9.4938e-05, grad_fn=<UnbindBackward0>)
# tensor(9.5978e-05, grad_fn=<UnbindBackward0>)
# tensor(9.6882e-05, grad_fn=<UnbindBackward0>)
# tensor(9.9438e-05, grad_fn=<UnbindBackward0>)
# tensor(0.0001, grad_fn=<UnbindBackward0>)
# tensor(0.0001, grad_fn=<UnbindBackward0>)
# tensor(0.0001, grad_fn=<UnbindBackward0>)
# tensor(0.0001, grad_fn=<UnbindBackward0>)
# tensor(0.0001, grad_fn=<UnbindBackward0>)
# tensor(0.0001, grad_fn=<UnbindBackward0>)
# tensor(0.0001, grad_fn=<UnbindBackward0>)
# tensor(0.0001, grad_fn=<UnbindBackward0>)
# tensor(0.0001, grad_fn=<UnbindBackward0>)
# tensor(0.0001, grad_fn=<UnbindBackward0>)
# tensor(0.0001, grad_fn=<UnbindBackward0>)
# tensor(0.0001, grad_fn=<UnbindBackward0>)
# tensor(0.0001, grad_fn=<UnbindBackward0>)
# tensor(0.0001, grad_fn=<UnbindBackward0>)
# tensor(0.0001, grad_fn=<UnbindBackward0>)
# tensor(0.0001, grad_fn=<UnbindBackward0>)
# tensor(0.0001, grad_fn=<UnbindBackward0>)
# tensor(0.0001, grad_fn=<UnbindBackward0>)
# tensor(0.0001, grad_fn=<UnbindBackward0>)
# tensor(0.0001, grad_fn=<UnbindBackward0>)
# tensor(0.0001, grad_fn=<UnbindBackward0>)
# tensor(0.0001, grad_fn=<UnbindBackward0>)
# tensor(0.0001, grad_fn=<UnbindBackward0>)
# tensor(0.0001, grad_fn=<UnbindBackward0>)
# tensor(0.0001, grad_fn=<UnbindBackward0>)
# tensor(0.0001, grad_fn=<UnbindBackward0>)
# tensor(0.0001, grad_fn=<UnbindBackward0>)
# tensor(0.0001, grad_fn=<UnbindBackward0>)
# tensor(0.0001, grad_fn=<UnbindBackward0>)
# tensor(0.0001, grad_fn=<UnbindBackward0>)
# tensor(0.0001, grad_fn=<UnbindBackward0>)
# tensor(0.0001, grad_fn=<UnbindBackward0>)
# tensor(0.0001, grad_fn=<UnbindBackward0>)
# tensor(0.0001, grad_fn=<UnbindBackward0>)
# tensor(0.0001, grad_fn=<UnbindBackward0>)
# tensor(0.0001, grad_fn=<UnbindBackward0>)
# tensor(0.0001, grad_fn=<UnbindBackward0>)
# tensor(0.0001, grad_fn=<UnbindBackward0>)
# tensor(0.0001, grad_fn=<UnbindBackward0>)
# tensor(0.0001, grad_fn=<UnbindBackward0>)
# tensor(0.0001, grad_fn=<UnbindBackward0>)
# tensor(0.0001, grad_fn=<UnbindBackward0>)
# tensor(0.0001, grad_fn=<UnbindBackward0>)
# tensor(0.0001, grad_fn=<UnbindBackward0>)
# tensor(0.0001, grad_fn=<UnbindBackward0>)
# tensor(0.0001, grad_fn=<UnbindBackward0>)
# tensor(0.0001, grad_fn=<UnbindBackward0>)
# tensor(0.0001, grad_fn=<UnbindBackward0>)
# tensor(0.0001, grad_fn=<UnbindBackward0>)
# tensor(0.0002, grad_fn=<UnbindBackward0>)
# tensor(0.0002, grad_fn=<UnbindBackward0>)
# tensor(0.0002, grad_fn=<UnbindBackward0>)
# tensor(0.0002, grad_fn=<UnbindBackward0>)
# tensor(0.0002, grad_fn=<UnbindBackward0>)
# tensor(0.0002, grad_fn=<UnbindBackward0>)
# tensor(0.0002, grad_fn=<UnbindBackward0>)
# tensor(0.0002, grad_fn=<UnbindBackward0>)
# tensor(0.0002, grad_fn=<UnbindBackward0>)
# tensor(0.0002, grad_fn=<UnbindBackward0>)
# tensor(0.0002, grad_fn=<UnbindBackward0>)
# tensor(0.0002, grad_fn=<UnbindBackward0>)
# tensor(0.0002, grad_fn=<UnbindBackward0>)
# tensor(0.0002, grad_fn=<UnbindBackward0>)
# tensor(0.0002, grad_fn=<UnbindBackward0>)
# tensor(0.0002, grad_fn=<UnbindBackward0>)
# tensor(0.0002, grad_fn=<UnbindBackward0>)
# tensor(0.0002, grad_fn=<UnbindBackward0>)
# tensor(0.0002, grad_fn=<UnbindBackward0>)
# tensor(0.0002, grad_fn=<UnbindBackward0>)
# tensor(0.0002, grad_fn=<UnbindBackward0>)
# tensor(0.0002, grad_fn=<UnbindBackward0>)
# tensor(0.0002, grad_fn=<UnbindBackward0>)
# tensor(0.0002, grad_fn=<UnbindBackward0>)
# tensor(0.0002, grad_fn=<UnbindBackward0>)
# tensor(0.0002, grad_fn=<UnbindBackward0>)
# tensor(0.0002, grad_fn=<UnbindBackward0>)
# tensor(0.0002, grad_fn=<UnbindBackward0>)
# tensor(0.0002, grad_fn=<UnbindBackward0>)
# tensor(0.0002, grad_fn=<UnbindBackward0>)
# tensor(0.0002, grad_fn=<UnbindBackward0>)
# tensor(0.0002, grad_fn=<UnbindBackward0>)
# tensor(0.0002, grad_fn=<UnbindBackward0>)
# tensor(0.0002, grad_fn=<UnbindBackward0>)
# tensor(0.0002, grad_fn=<UnbindBackward0>)
# tensor(0.0002, grad_fn=<UnbindBackward0>)
# tensor(0.0002, grad_fn=<UnbindBackward0>)
# tensor(0.0002, grad_fn=<UnbindBackward0>)
# tensor(0.0002, grad_fn=<UnbindBackward0>)
# tensor(0.0002, grad_fn=<UnbindBackward0>)
# tensor(0.0002, grad_fn=<UnbindBackward0>)
# tensor(0.0002, grad_fn=<UnbindBackward0>)
# tensor(0.0002, grad_fn=<UnbindBackward0>)
# tensor(0.0002, grad_fn=<UnbindBackward0>)
# tensor(0.0002, grad_fn=<UnbindBackward0>)
# tensor(0.0002, grad_fn=<UnbindBackward0>)
# tensor(0.0002, grad_fn=<UnbindBackward0>)
# tensor(0.0002, grad_fn=<UnbindBackward0>)
# tensor(0.0002, grad_fn=<UnbindBackward0>)
# tensor(0.0002, grad_fn=<UnbindBackward0>)
# tensor(0.0002, grad_fn=<UnbindBackward0>)
# tensor(0.0002, grad_fn=<UnbindBackward0>)
# tensor(0.0002, grad_fn=<UnbindBackward0>)
# tensor(0.0002, grad_fn=<UnbindBackward0>)
# tensor(0.0002, grad_fn=<UnbindBackward0>)
# tensor(0.0002, grad_fn=<UnbindBackward0>)
# tensor(0.0002, grad_fn=<UnbindBackward0>)
# tensor(0.0002, grad_fn=<UnbindBackward0>)
# tensor(0.0002, grad_fn=<UnbindBackward0>)
# tensor(0.0002, grad_fn=<UnbindBackward0>)
# tensor(0.0002, grad_fn=<UnbindBackward0>)
# tensor(0.0002, grad_fn=<UnbindBackward0>)
# tensor(0.0002, grad_fn=<UnbindBackward0>)
# tensor(0.0003, grad_fn=<UnbindBackward0>)
# tensor(0.0003, grad_fn=<UnbindBackward0>)
# tensor(0.0003, grad_fn=<UnbindBackward0>)
# tensor(0.0003, grad_fn=<UnbindBackward0>)
# tensor(0.0003, grad_fn=<UnbindBackward0>)
# tensor(0.0003, grad_fn=<UnbindBackward0>)
# tensor(0.0003, grad_fn=<UnbindBackward0>)
# tensor(0.0003, grad_fn=<UnbindBackward0>)
# tensor(0.0003, grad_fn=<UnbindBackward0>)
# tensor(0.0003, grad_fn=<UnbindBackward0>)
# tensor(0.0003, grad_fn=<UnbindBackward0>)
# tensor(0.0003, grad_fn=<UnbindBackward0>)
# tensor(0.0003, grad_fn=<UnbindBackward0>)
# tensor(0.0003, grad_fn=<UnbindBackward0>)
# tensor(0.0003, grad_fn=<UnbindBackward0>)
# tensor(0.0003, grad_fn=<UnbindBackward0>)
# tensor(0.0003, grad_fn=<UnbindBackward0>)
# tensor(0.0003, grad_fn=<UnbindBackward0>)
# tensor(0.0003, grad_fn=<UnbindBackward0>)
# tensor(0.0003, grad_fn=<UnbindBackward0>)
# tensor(0.0003, grad_fn=<UnbindBackward0>)
# tensor(0.0003, grad_fn=<UnbindBackward0>)
# tensor(0.0003, grad_fn=<UnbindBackward0>)
# tensor(0.0003, grad_fn=<UnbindBackward0>)
# tensor(0.0003, grad_fn=<UnbindBackward0>)
# tensor(0.0003, grad_fn=<UnbindBackward0>)
# tensor(0.0003, grad_fn=<UnbindBackward0>)
# tensor(0.0003, grad_fn=<UnbindBackward0>)
# tensor(0.0003, grad_fn=<UnbindBackward0>)
# tensor(0.0003, grad_fn=<UnbindBackward0>)
# tensor(0.0003, grad_fn=<UnbindBackward0>)
# tensor(0.0003, grad_fn=<UnbindBackward0>)
# tensor(0.0003, grad_fn=<UnbindBackward0>)
# tensor(0.0003, grad_fn=<UnbindBackward0>)
# tensor(0.0003, grad_fn=<UnbindBackward0>)
# tensor(0.0003, grad_fn=<UnbindBackward0>)
# tensor(0.0003, grad_fn=<UnbindBackward0>)
# tensor(0.0003, grad_fn=<UnbindBackward0>)
# tensor(0.0003, grad_fn=<UnbindBackward0>)
# tensor(0.0003, grad_fn=<UnbindBackward0>)
# tensor(0.0003, grad_fn=<UnbindBackward0>)
# tensor(0.0003, grad_fn=<UnbindBackward0>)
# tensor(0.0003, grad_fn=<UnbindBackward0>)
# tensor(0.0003, grad_fn=<UnbindBackward0>)
# tensor(0.0003, grad_fn=<UnbindBackward0>)
# tensor(0.0003, grad_fn=<UnbindBackward0>)
# tensor(0.0003, grad_fn=<UnbindBackward0>)
# tensor(0.0003, grad_fn=<UnbindBackward0>)
# tensor(0.0004, grad_fn=<UnbindBackward0>)
# tensor(0.0004, grad_fn=<UnbindBackward0>)
# tensor(0.0004, grad_fn=<UnbindBackward0>)
# tensor(0.0004, grad_fn=<UnbindBackward0>)
# tensor(0.0004, grad_fn=<UnbindBackward0>)
# tensor(0.0004, grad_fn=<UnbindBackward0>)
# tensor(0.0004, grad_fn=<UnbindBackward0>)
# tensor(0.0004, grad_fn=<UnbindBackward0>)
# tensor(0.0004, grad_fn=<UnbindBackward0>)
# tensor(0.0004, grad_fn=<UnbindBackward0>)
# tensor(0.0004, grad_fn=<UnbindBackward0>)
# tensor(0.0004, grad_fn=<UnbindBackward0>)
# tensor(0.0004, grad_fn=<UnbindBackward0>)
# tensor(0.0004, grad_fn=<UnbindBackward0>)
# tensor(0.0004, grad_fn=<UnbindBackward0>)
# tensor(0.0004, grad_fn=<UnbindBackward0>)
# tensor(0.0004, grad_fn=<UnbindBackward0>)
# tensor(0.0004, grad_fn=<UnbindBackward0>)
# tensor(0.0004, grad_fn=<UnbindBackward0>)
# tensor(0.0004, grad_fn=<UnbindBackward0>)
# tensor(0.0004, grad_fn=<UnbindBackward0>)
# tensor(0.0004, grad_fn=<UnbindBackward0>)
# tensor(0.0004, grad_fn=<UnbindBackward0>)
# tensor(0.0004, grad_fn=<UnbindBackward0>)
# tensor(0.0004, grad_fn=<UnbindBackward0>)
# tensor(0.0004, grad_fn=<UnbindBackward0>)
# tensor(0.0004, grad_fn=<UnbindBackward0>)
# tensor(0.0004, grad_fn=<UnbindBackward0>)
# tensor(0.0004, grad_fn=<UnbindBackward0>)
# tensor(0.0004, grad_fn=<UnbindBackward0>)
# tensor(0.0004, grad_fn=<UnbindBackward0>)
# tensor(0.0004, grad_fn=<UnbindBackward0>)
# tensor(0.0004, grad_fn=<UnbindBackward0>)
# tensor(0.0004, grad_fn=<UnbindBackward0>)
# tensor(0.0004, grad_fn=<UnbindBackward0>)
# tensor(0.0004, grad_fn=<UnbindBackward0>)
# tensor(0.0004, grad_fn=<UnbindBackward0>)
# tensor(0.0004, grad_fn=<UnbindBackward0>)
# tensor(0.0004, grad_fn=<UnbindBackward0>)
# tensor(0.0004, grad_fn=<UnbindBackward0>)
# tensor(0.0005, grad_fn=<UnbindBackward0>)
# tensor(0.0005, grad_fn=<UnbindBackward0>)
# tensor(0.0005, grad_fn=<UnbindBackward0>)
# tensor(0.0005, grad_fn=<UnbindBackward0>)
# tensor(0.0005, grad_fn=<UnbindBackward0>)
# tensor(0.0005, grad_fn=<UnbindBackward0>)
# tensor(0.0005, grad_fn=<UnbindBackward0>)
# tensor(0.0005, grad_fn=<UnbindBackward0>)
# tensor(0.0005, grad_fn=<UnbindBackward0>)
# tensor(0.0005, grad_fn=<UnbindBackward0>)
# tensor(0.0005, grad_fn=<UnbindBackward0>)
# tensor(0.0005, grad_fn=<UnbindBackward0>)
# tensor(0.0005, grad_fn=<UnbindBackward0>)
# tensor(0.0005, grad_fn=<UnbindBackward0>)
# tensor(0.0005, grad_fn=<UnbindBackward0>)
# tensor(0.0005, grad_fn=<UnbindBackward0>)
# tensor(0.0005, grad_fn=<UnbindBackward0>)
# tensor(0.0005, grad_fn=<UnbindBackward0>)
# tensor(0.0005, grad_fn=<UnbindBackward0>)
# tensor(0.0005, grad_fn=<UnbindBackward0>)
# tensor(0.0005, grad_fn=<UnbindBackward0>)
# tensor(0.0005, grad_fn=<UnbindBackward0>)
# tensor(0.0005, grad_fn=<UnbindBackward0>)
# tensor(0.0005, grad_fn=<UnbindBackward0>)
# tensor(0.0005, grad_fn=<UnbindBackward0>)
# tensor(0.0005, grad_fn=<UnbindBackward0>)
# tensor(0.0005, grad_fn=<UnbindBackward0>)
# tensor(0.0005, grad_fn=<UnbindBackward0>)
# tensor(0.0005, grad_fn=<UnbindBackward0>)
# tensor(0.0005, grad_fn=<UnbindBackward0>)
# tensor(0.0006, grad_fn=<UnbindBackward0>)
# tensor(0.0006, grad_fn=<UnbindBackward0>)
# tensor(0.0006, grad_fn=<UnbindBackward0>)
# tensor(0.0006, grad_fn=<UnbindBackward0>)
# tensor(0.0006, grad_fn=<UnbindBackward0>)
# tensor(0.0006, grad_fn=<UnbindBackward0>)
# tensor(0.0006, grad_fn=<UnbindBackward0>)
# tensor(0.0006, grad_fn=<UnbindBackward0>)
# tensor(0.0006, grad_fn=<UnbindBackward0>)
# tensor(0.0006, grad_fn=<UnbindBackward0>)
# tensor(0.0006, grad_fn=<UnbindBackward0>)
# tensor(0.0006, grad_fn=<UnbindBackward0>)
# tensor(0.0006, grad_fn=<UnbindBackward0>)
# tensor(0.0006, grad_fn=<UnbindBackward0>)
# tensor(0.0006, grad_fn=<UnbindBackward0>)
# tensor(0.0006, grad_fn=<UnbindBackward0>)
# tensor(0.0007, grad_fn=<UnbindBackward0>)
# tensor(0.0007, grad_fn=<UnbindBackward0>)
# tensor(0.0007, grad_fn=<UnbindBackward0>)
# tensor(0.0007, grad_fn=<UnbindBackward0>)
# tensor(0.0007, grad_fn=<UnbindBackward0>)
# tensor(0.0007, grad_fn=<UnbindBackward0>)
# tensor(0.0007, grad_fn=<UnbindBackward0>)
# tensor(0.0007, grad_fn=<UnbindBackward0>)
# tensor(0.0007, grad_fn=<UnbindBackward0>)
# tensor(0.0007, grad_fn=<UnbindBackward0>)
# tensor(0.0007, grad_fn=<UnbindBackward0>)
# tensor(0.0007, grad_fn=<UnbindBackward0>)
# tensor(0.0007, grad_fn=<UnbindBackward0>)
# tensor(0.0007, grad_fn=<UnbindBackward0>)
# tensor(0.0007, grad_fn=<UnbindBackward0>)
# tensor(0.0007, grad_fn=<UnbindBackward0>)
# tensor(0.0007, grad_fn=<UnbindBackward0>)
# tensor(0.0007, grad_fn=<UnbindBackward0>)
# tensor(0.0007, grad_fn=<UnbindBackward0>)
# tensor(0.0007, grad_fn=<UnbindBackward0>)
# tensor(0.0008, grad_fn=<UnbindBackward0>)
# tensor(0.0008, grad_fn=<UnbindBackward0>)
# tensor(0.0008, grad_fn=<UnbindBackward0>)
# tensor(0.0008, grad_fn=<UnbindBackward0>)
# tensor(0.0008, grad_fn=<UnbindBackward0>)
# tensor(0.0008, grad_fn=<UnbindBackward0>)
# tensor(0.0008, grad_fn=<UnbindBackward0>)
# tensor(0.0008, grad_fn=<UnbindBackward0>)
# tensor(0.0008, grad_fn=<UnbindBackward0>)
# tensor(0.0008, grad_fn=<UnbindBackward0>)
# tensor(0.0008, grad_fn=<UnbindBackward0>)
# tensor(0.0008, grad_fn=<UnbindBackward0>)
# tensor(0.0008, grad_fn=<UnbindBackward0>)
# tensor(0.0009, grad_fn=<UnbindBackward0>)
# tensor(0.0009, grad_fn=<UnbindBackward0>)
# tensor(0.0009, grad_fn=<UnbindBackward0>)
# tensor(0.0009, grad_fn=<UnbindBackward0>)
# tensor(0.0009, grad_fn=<UnbindBackward0>)
# tensor(0.0009, grad_fn=<UnbindBackward0>)
# tensor(0.0009, grad_fn=<UnbindBackward0>)
# tensor(0.0009, grad_fn=<UnbindBackward0>)
# tensor(0.0009, grad_fn=<UnbindBackward0>)
# tensor(0.0009, grad_fn=<UnbindBackward0>)
# tensor(0.0009, grad_fn=<UnbindBackward0>)
# tensor(0.0009, grad_fn=<UnbindBackward0>)
# tensor(0.0009, grad_fn=<UnbindBackward0>)
# tensor(0.0009, grad_fn=<UnbindBackward0>)
# tensor(0.0010, grad_fn=<UnbindBackward0>)
# tensor(0.0010, grad_fn=<UnbindBackward0>)
# tensor(0.0010, grad_fn=<UnbindBackward0>)
# tensor(0.0010, grad_fn=<UnbindBackward0>)
# tensor(0.0010, grad_fn=<UnbindBackward0>)
# tensor(0.0010, grad_fn=<UnbindBackward0>)
# tensor(0.0010, grad_fn=<UnbindBackward0>)
# tensor(0.0010, grad_fn=<UnbindBackward0>)
# tensor(0.0010, grad_fn=<UnbindBackward0>)
# tensor(0.0010, grad_fn=<UnbindBackward0>)
# tensor(0.0010, grad_fn=<UnbindBackward0>)
# tensor(0.0010, grad_fn=<UnbindBackward0>)
# tensor(0.0010, grad_fn=<UnbindBackward0>)
# tensor(0.0010, grad_fn=<UnbindBackward0>)
# tensor(0.0010, grad_fn=<UnbindBackward0>)
# tensor(0.0010, grad_fn=<UnbindBackward0>)
# tensor(0.0010, grad_fn=<UnbindBackward0>)
# tensor(0.0010, grad_fn=<UnbindBackward0>)
# tensor(0.0010, grad_fn=<UnbindBackward0>)
# tensor(0.0011, grad_fn=<UnbindBackward0>)
# tensor(0.0011, grad_fn=<UnbindBackward0>)
# tensor(0.0011, grad_fn=<UnbindBackward0>)
# tensor(0.0011, grad_fn=<UnbindBackward0>)
# tensor(0.0011, grad_fn=<UnbindBackward0>)
# tensor(0.0011, grad_fn=<UnbindBackward0>)
# tensor(0.0011, grad_fn=<UnbindBackward0>)
# tensor(0.0011, grad_fn=<UnbindBackward0>)
# tensor(0.0011, grad_fn=<UnbindBackward0>)
# tensor(0.0011, grad_fn=<UnbindBackward0>)
# tensor(0.0011, grad_fn=<UnbindBackward0>)
# tensor(0.0011, grad_fn=<UnbindBackward0>)
# tensor(0.0012, grad_fn=<UnbindBackward0>)
# tensor(0.0012, grad_fn=<UnbindBackward0>)
# tensor(0.0012, grad_fn=<UnbindBackward0>)
# tensor(0.0012, grad_fn=<UnbindBackward0>)
# tensor(0.0012, grad_fn=<UnbindBackward0>)
# tensor(0.0012, grad_fn=<UnbindBackward0>)
# tensor(0.0012, grad_fn=<UnbindBackward0>)
# tensor(0.0012, grad_fn=<UnbindBackward0>)
# tensor(0.0012, grad_fn=<UnbindBackward0>)
# tensor(0.0012, grad_fn=<UnbindBackward0>)
# tensor(0.0012, grad_fn=<UnbindBackward0>)
# tensor(0.0012, grad_fn=<UnbindBackward0>)
# tensor(0.0012, grad_fn=<UnbindBackward0>)
# tensor(0.0013, grad_fn=<UnbindBackward0>)
# tensor(0.0013, grad_fn=<UnbindBackward0>)
# tensor(0.0013, grad_fn=<UnbindBackward0>)
# tensor(0.0013, grad_fn=<UnbindBackward0>)
# tensor(0.0013, grad_fn=<UnbindBackward0>)
# tensor(0.0013, grad_fn=<UnbindBackward0>)
# tensor(0.0013, grad_fn=<UnbindBackward0>)
# tensor(0.0013, grad_fn=<UnbindBackward0>)
# tensor(0.0013, grad_fn=<UnbindBackward0>)
# tensor(0.0013, grad_fn=<UnbindBackward0>)
# tensor(0.0013, grad_fn=<UnbindBackward0>)
# tensor(0.0013, grad_fn=<UnbindBackward0>)
# tensor(0.0013, grad_fn=<UnbindBackward0>)
# tensor(0.0013, grad_fn=<UnbindBackward0>)
# tensor(0.0013, grad_fn=<UnbindBackward0>)
# tensor(0.0014, grad_fn=<UnbindBackward0>)
# tensor(0.0014, grad_fn=<UnbindBackward0>)
# tensor(0.0014, grad_fn=<UnbindBackward0>)
# tensor(0.0014, grad_fn=<UnbindBackward0>)
# tensor(0.0014, grad_fn=<UnbindBackward0>)
# tensor(0.0014, grad_fn=<UnbindBackward0>)
# tensor(0.0014, grad_fn=<UnbindBackward0>)
# tensor(0.0015, grad_fn=<UnbindBackward0>)
# tensor(0.0015, grad_fn=<UnbindBackward0>)
# tensor(0.0015, grad_fn=<UnbindBackward0>)
# tensor(0.0015, grad_fn=<UnbindBackward0>)
# tensor(0.0015, grad_fn=<UnbindBackward0>)
# tensor(0.0015, grad_fn=<UnbindBackward0>)
# tensor(0.0016, grad_fn=<UnbindBackward0>)
# tensor(0.0016, grad_fn=<UnbindBackward0>)
# tensor(0.0016, grad_fn=<UnbindBackward0>)
# tensor(0.0016, grad_fn=<UnbindBackward0>)
# tensor(0.0016, grad_fn=<UnbindBackward0>)
# tensor(0.0016, grad_fn=<UnbindBackward0>)
# tensor(0.0016, grad_fn=<UnbindBackward0>)
# tensor(0.0016, grad_fn=<UnbindBackward0>)
# tensor(0.0016, grad_fn=<UnbindBackward0>)
# tensor(0.0016, grad_fn=<UnbindBackward0>)
# tensor(0.0017, grad_fn=<UnbindBackward0>)
# tensor(0.0017, grad_fn=<UnbindBackward0>)
# tensor(0.0017, grad_fn=<UnbindBackward0>)
# tensor(0.0017, grad_fn=<UnbindBackward0>)
# tensor(0.0017, grad_fn=<UnbindBackward0>)
# tensor(0.0017, grad_fn=<UnbindBackward0>)
# tensor(0.0017, grad_fn=<UnbindBackward0>)
# tensor(0.0017, grad_fn=<UnbindBackward0>)
# tensor(0.0018, grad_fn=<UnbindBackward0>)
# tensor(0.0018, grad_fn=<UnbindBackward0>)
# tensor(0.0018, grad_fn=<UnbindBackward0>)
# tensor(0.0018, grad_fn=<UnbindBackward0>)
# tensor(0.0018, grad_fn=<UnbindBackward0>)
# tensor(0.0018, grad_fn=<UnbindBackward0>)
# tensor(0.0018, grad_fn=<UnbindBackward0>)
# tensor(0.0019, grad_fn=<UnbindBackward0>)
# tensor(0.0019, grad_fn=<UnbindBackward0>)
# tensor(0.0019, grad_fn=<UnbindBackward0>)
# tensor(0.0019, grad_fn=<UnbindBackward0>)
# tensor(0.0019, grad_fn=<UnbindBackward0>)
# tensor(0.0019, grad_fn=<UnbindBackward0>)
# tensor(0.0019, grad_fn=<UnbindBackward0>)
# tensor(0.0019, grad_fn=<UnbindBackward0>)
# tensor(0.0019, grad_fn=<UnbindBackward0>)
# tensor(0.0020, grad_fn=<UnbindBackward0>)
# tensor(0.0020, grad_fn=<UnbindBackward0>)
# tensor(0.0020, grad_fn=<UnbindBackward0>)
# tensor(0.0020, grad_fn=<UnbindBackward0>)
# tensor(0.0020, grad_fn=<UnbindBackward0>)
# tensor(0.0020, grad_fn=<UnbindBackward0>)
# tensor(0.0020, grad_fn=<UnbindBackward0>)
# tensor(0.0021, grad_fn=<UnbindBackward0>)
# tensor(0.0021, grad_fn=<UnbindBackward0>)
# tensor(0.0021, grad_fn=<UnbindBackward0>)
# tensor(0.0021, grad_fn=<UnbindBackward0>)
# tensor(0.0021, grad_fn=<UnbindBackward0>)
# tensor(0.0021, grad_fn=<UnbindBackward0>)
# tensor(0.0021, grad_fn=<UnbindBackward0>)
# tensor(0.0022, grad_fn=<UnbindBackward0>)
# tensor(0.0022, grad_fn=<UnbindBackward0>)
# tensor(0.0022, grad_fn=<UnbindBackward0>)
# tensor(0.0022, grad_fn=<UnbindBackward0>)
# tensor(0.0022, grad_fn=<UnbindBackward0>)
# tensor(0.0023, grad_fn=<UnbindBackward0>)
# tensor(0.0023, grad_fn=<UnbindBackward0>)
# tensor(0.0023, grad_fn=<UnbindBackward0>)
# tensor(0.0024, grad_fn=<UnbindBackward0>)
# tensor(0.0024, grad_fn=<UnbindBackward0>)
# tensor(0.0024, grad_fn=<UnbindBackward0>)
# tensor(0.0024, grad_fn=<UnbindBackward0>)
# tensor(0.0024, grad_fn=<UnbindBackward0>)
# tensor(0.0024, grad_fn=<UnbindBackward0>)
# tensor(0.0024, grad_fn=<UnbindBackward0>)
# tensor(0.0025, grad_fn=<UnbindBackward0>)
# tensor(0.0025, grad_fn=<UnbindBackward0>)
# tensor(0.0025, grad_fn=<UnbindBackward0>)
# tensor(0.0025, grad_fn=<UnbindBackward0>)
# tensor(0.0025, grad_fn=<UnbindBackward0>)
# tensor(0.0026, grad_fn=<UnbindBackward0>)
# tensor(0.0026, grad_fn=<UnbindBackward0>)
# tensor(0.0026, grad_fn=<UnbindBackward0>)
# tensor(0.0026, grad_fn=<UnbindBackward0>)
# tensor(0.0026, grad_fn=<UnbindBackward0>)
# tensor(0.0026, grad_fn=<UnbindBackward0>)
# tensor(0.0027, grad_fn=<UnbindBackward0>)
# tensor(0.0027, grad_fn=<UnbindBackward0>)
# tensor(0.0027, grad_fn=<UnbindBackward0>)
# tensor(0.0027, grad_fn=<UnbindBackward0>)
# tensor(0.0027, grad_fn=<UnbindBackward0>)
# tensor(0.0027, grad_fn=<UnbindBackward0>)
# tensor(0.0027, grad_fn=<UnbindBackward0>)
# tensor(0.0027, grad_fn=<UnbindBackward0>)
# tensor(0.0028, grad_fn=<UnbindBackward0>)
# tensor(0.0028, grad_fn=<UnbindBackward0>)
# tensor(0.0028, grad_fn=<UnbindBackward0>)
# tensor(0.0028, grad_fn=<UnbindBackward0>)
# tensor(0.0028, grad_fn=<UnbindBackward0>)
# tensor(0.0028, grad_fn=<UnbindBackward0>)
# tensor(0.0028, grad_fn=<UnbindBackward0>)
# tensor(0.0029, grad_fn=<UnbindBackward0>)
# tensor(0.0029, grad_fn=<UnbindBackward0>)
# tensor(0.0029, grad_fn=<UnbindBackward0>)
# tensor(0.0030, grad_fn=<UnbindBackward0>)
# tensor(0.0030, grad_fn=<UnbindBackward0>)
# tensor(0.0030, grad_fn=<UnbindBackward0>)
# tensor(0.0031, grad_fn=<UnbindBackward0>)
# tensor(0.0031, grad_fn=<UnbindBackward0>)
# tensor(0.0031, grad_fn=<UnbindBackward0>)
# tensor(0.0031, grad_fn=<UnbindBackward0>)
# tensor(0.0031, grad_fn=<UnbindBackward0>)
# tensor(0.0032, grad_fn=<UnbindBackward0>)
# tensor(0.0032, grad_fn=<UnbindBackward0>)
# tensor(0.0032, grad_fn=<UnbindBackward0>)
# tensor(0.0033, grad_fn=<UnbindBackward0>)
# tensor(0.0033, grad_fn=<UnbindBackward0>)
# tensor(0.0033, grad_fn=<UnbindBackward0>)
# tensor(0.0033, grad_fn=<UnbindBackward0>)
# tensor(0.0033, grad_fn=<UnbindBackward0>)
# tensor(0.0033, grad_fn=<UnbindBackward0>)
# tensor(0.0033, grad_fn=<UnbindBackward0>)
# tensor(0.0033, grad_fn=<UnbindBackward0>)
# tensor(0.0033, grad_fn=<UnbindBackward0>)
# tensor(0.0033, grad_fn=<UnbindBackward0>)
# tensor(0.0034, grad_fn=<UnbindBackward0>)
# tensor(0.0034, grad_fn=<UnbindBackward0>)
# tensor(0.0034, grad_fn=<UnbindBackward0>)
# tensor(0.0034, grad_fn=<UnbindBackward0>)
# tensor(0.0035, grad_fn=<UnbindBackward0>)
# tensor(0.0035, grad_fn=<UnbindBackward0>)
# tensor(0.0035, grad_fn=<UnbindBackward0>)
# tensor(0.0035, grad_fn=<UnbindBackward0>)
# tensor(0.0035, grad_fn=<UnbindBackward0>)
# tensor(0.0035, grad_fn=<UnbindBackward0>)
# tensor(0.0035, grad_fn=<UnbindBackward0>)
# tensor(0.0035, grad_fn=<UnbindBackward0>)
# tensor(0.0036, grad_fn=<UnbindBackward0>)
# tensor(0.0036, grad_fn=<UnbindBackward0>)
# tensor(0.0036, grad_fn=<UnbindBackward0>)
# tensor(0.0036, grad_fn=<UnbindBackward0>)
# tensor(0.0037, grad_fn=<UnbindBackward0>)
# tensor(0.0037, grad_fn=<UnbindBackward0>)
# tensor(0.0037, grad_fn=<UnbindBackward0>)
# tensor(0.0037, grad_fn=<UnbindBackward0>)
# tensor(0.0038, grad_fn=<UnbindBackward0>)
# tensor(0.0039, grad_fn=<UnbindBackward0>)
# tensor(0.0039, grad_fn=<UnbindBackward0>)
# tensor(0.0039, grad_fn=<UnbindBackward0>)
# tensor(0.0039, grad_fn=<UnbindBackward0>)
# tensor(0.0040, grad_fn=<UnbindBackward0>)
# tensor(0.0040, grad_fn=<UnbindBackward0>)
# tensor(0.0040, grad_fn=<UnbindBackward0>)
# tensor(0.0041, grad_fn=<UnbindBackward0>)
# tensor(0.0041, grad_fn=<UnbindBackward0>)
# tensor(0.0041, grad_fn=<UnbindBackward0>)
# tensor(0.0041, grad_fn=<UnbindBackward0>)
# tensor(0.0042, grad_fn=<UnbindBackward0>)
# tensor(0.0042, grad_fn=<UnbindBackward0>)
# tensor(0.0042, grad_fn=<UnbindBackward0>)
# tensor(0.0042, grad_fn=<UnbindBackward0>)
# tensor(0.0042, grad_fn=<UnbindBackward0>)
# tensor(0.0042, grad_fn=<UnbindBackward0>)
# tensor(0.0042, grad_fn=<UnbindBackward0>)
# tensor(0.0042, grad_fn=<UnbindBackward0>)
# tensor(0.0043, grad_fn=<UnbindBackward0>)
# tensor(0.0044, grad_fn=<UnbindBackward0>)
# tensor(0.0045, grad_fn=<UnbindBackward0>)
# tensor(0.0045, grad_fn=<UnbindBackward0>)
# tensor(0.0046, grad_fn=<UnbindBackward0>)
# tensor(0.0046, grad_fn=<UnbindBackward0>)
# tensor(0.0046, grad_fn=<UnbindBackward0>)
# tensor(0.0046, grad_fn=<UnbindBackward0>)
# tensor(0.0046, grad_fn=<UnbindBackward0>)
# tensor(0.0047, grad_fn=<UnbindBackward0>)
# tensor(0.0048, grad_fn=<UnbindBackward0>)
# tensor(0.0048, grad_fn=<UnbindBackward0>)
# tensor(0.0048, grad_fn=<UnbindBackward0>)
# tensor(0.0049, grad_fn=<UnbindBackward0>)
# tensor(0.0049, grad_fn=<UnbindBackward0>)
# tensor(0.0049, grad_fn=<UnbindBackward0>)
# tensor(0.0050, grad_fn=<UnbindBackward0>)
# tensor(0.0050, grad_fn=<UnbindBackward0>)
# tensor(0.0050, grad_fn=<UnbindBackward0>)
# tensor(0.0050, grad_fn=<UnbindBackward0>)
# tensor(0.0052, grad_fn=<UnbindBackward0>)
# tensor(0.0052, grad_fn=<UnbindBackward0>)
# tensor(0.0053, grad_fn=<UnbindBackward0>)
# tensor(0.0053, grad_fn=<UnbindBackward0>)
# tensor(0.0054, grad_fn=<UnbindBackward0>)
# tensor(0.0055, grad_fn=<UnbindBackward0>)
# tensor(0.0055, grad_fn=<UnbindBackward0>)
# tensor(0.0056, grad_fn=<UnbindBackward0>)
# tensor(0.0057, grad_fn=<UnbindBackward0>)
# tensor(0.0057, grad_fn=<UnbindBackward0>)
# tensor(0.0057, grad_fn=<UnbindBackward0>)
# tensor(0.0058, grad_fn=<UnbindBackward0>)
# tensor(0.0058, grad_fn=<UnbindBackward0>)
# tensor(0.0059, grad_fn=<UnbindBackward0>)
# tensor(0.0059, grad_fn=<UnbindBackward0>)
# tensor(0.0059, grad_fn=<UnbindBackward0>)
# tensor(0.0060, grad_fn=<UnbindBackward0>)
# tensor(0.0060, grad_fn=<UnbindBackward0>)
# tensor(0.0060, grad_fn=<UnbindBackward0>)
# tensor(0.0060, grad_fn=<UnbindBackward0>)
# tensor(0.0061, grad_fn=<UnbindBackward0>)
# tensor(0.0061, grad_fn=<UnbindBackward0>)
# tensor(0.0061, grad_fn=<UnbindBackward0>)
# tensor(0.0062, grad_fn=<UnbindBackward0>)
# tensor(0.0062, grad_fn=<UnbindBackward0>)
# tensor(0.0064, grad_fn=<UnbindBackward0>)
# tensor(0.0064, grad_fn=<UnbindBackward0>)
# tensor(0.0064, grad_fn=<UnbindBackward0>)
# tensor(0.0065, grad_fn=<UnbindBackward0>)
# tensor(0.0065, grad_fn=<UnbindBackward0>)
# tensor(0.0065, grad_fn=<UnbindBackward0>)
# tensor(0.0065, grad_fn=<UnbindBackward0>)
# tensor(0.0066, grad_fn=<UnbindBackward0>)
# tensor(0.0067, grad_fn=<UnbindBackward0>)
# tensor(0.0068, grad_fn=<UnbindBackward0>)
# tensor(0.0068, grad_fn=<UnbindBackward0>)
# tensor(0.0069, grad_fn=<UnbindBackward0>)
# tensor(0.0069, grad_fn=<UnbindBackward0>)
# tensor(0.0069, grad_fn=<UnbindBackward0>)
# tensor(0.0070, grad_fn=<UnbindBackward0>)
# tensor(0.0070, grad_fn=<UnbindBackward0>)
# tensor(0.0070, grad_fn=<UnbindBackward0>)
# tensor(0.0070, grad_fn=<UnbindBackward0>)
# tensor(0.0072, grad_fn=<UnbindBackward0>)
# tensor(0.0072, grad_fn=<UnbindBackward0>)
# tensor(0.0072, grad_fn=<UnbindBackward0>)
# tensor(0.0072, grad_fn=<UnbindBackward0>)
# tensor(0.0073, grad_fn=<UnbindBackward0>)
# tensor(0.0073, grad_fn=<UnbindBackward0>)
# tensor(0.0073, grad_fn=<UnbindBackward0>)
# tensor(0.0074, grad_fn=<UnbindBackward0>)
# tensor(0.0075, grad_fn=<UnbindBackward0>)
# tensor(0.0076, grad_fn=<UnbindBackward0>)
# tensor(0.0077, grad_fn=<UnbindBackward0>)
# tensor(0.0078, grad_fn=<UnbindBackward0>)
# tensor(0.0078, grad_fn=<UnbindBackward0>)
# tensor(0.0078, grad_fn=<UnbindBackward0>)
# tensor(0.0079, grad_fn=<UnbindBackward0>)
# tensor(0.0079, grad_fn=<UnbindBackward0>)
# tensor(0.0080, grad_fn=<UnbindBackward0>)
# tensor(0.0081, grad_fn=<UnbindBackward0>)
# tensor(0.0081, grad_fn=<UnbindBackward0>)
# tensor(0.0081, grad_fn=<UnbindBackward0>)
# tensor(0.0081, grad_fn=<UnbindBackward0>)
# tensor(0.0083, grad_fn=<UnbindBackward0>)
# tensor(0.0083, grad_fn=<UnbindBackward0>)
# tensor(0.0083, grad_fn=<UnbindBackward0>)
# tensor(0.0083, grad_fn=<UnbindBackward0>)
# tensor(0.0083, grad_fn=<UnbindBackward0>)
# tensor(0.0084, grad_fn=<UnbindBackward0>)
# tensor(0.0084, grad_fn=<UnbindBackward0>)
# tensor(0.0085, grad_fn=<UnbindBackward0>)
# tensor(0.0085, grad_fn=<UnbindBackward0>)
# tensor(0.0086, grad_fn=<UnbindBackward0>)
# tensor(0.0086, grad_fn=<UnbindBackward0>)
# tensor(0.0087, grad_fn=<UnbindBackward0>)
# tensor(0.0088, grad_fn=<UnbindBackward0>)
# tensor(0.0088, grad_fn=<UnbindBackward0>)
# tensor(0.0089, grad_fn=<UnbindBackward0>)
# tensor(0.0090, grad_fn=<UnbindBackward0>)
# tensor(0.0090, grad_fn=<UnbindBackward0>)
# tensor(0.0091, grad_fn=<UnbindBackward0>)
# tensor(0.0091, grad_fn=<UnbindBackward0>)
# tensor(0.0091, grad_fn=<UnbindBackward0>)
# tensor(0.0092, grad_fn=<UnbindBackward0>)
# tensor(0.0092, grad_fn=<UnbindBackward0>)
# tensor(0.0092, grad_fn=<UnbindBackward0>)
# tensor(0.0092, grad_fn=<UnbindBackward0>)
# tensor(0.0092, grad_fn=<UnbindBackward0>)
# tensor(0.0092, grad_fn=<UnbindBackward0>)
# tensor(0.0092, grad_fn=<UnbindBackward0>)
# tensor(0.0093, grad_fn=<UnbindBackward0>)
# tensor(0.0093, grad_fn=<UnbindBackward0>)
# tensor(0.0093, grad_fn=<UnbindBackward0>)
# tensor(0.0094, grad_fn=<UnbindBackward0>)
# tensor(0.0094, grad_fn=<UnbindBackward0>)
# tensor(0.0094, grad_fn=<UnbindBackward0>)
# tensor(0.0096, grad_fn=<UnbindBackward0>)
# tensor(0.0097, grad_fn=<UnbindBackward0>)
# tensor(0.0097, grad_fn=<UnbindBackward0>)
# tensor(0.0097, grad_fn=<UnbindBackward0>)
# tensor(0.0097, grad_fn=<UnbindBackward0>)
# tensor(0.0097, grad_fn=<UnbindBackward0>)
# tensor(0.0098, grad_fn=<UnbindBackward0>)
# tensor(0.0099, grad_fn=<UnbindBackward0>)
# tensor(0.0100, grad_fn=<UnbindBackward0>)
# tensor(0.0100, grad_fn=<UnbindBackward0>)
# tensor(0.0100, grad_fn=<UnbindBackward0>)
# tensor(0.0101, grad_fn=<UnbindBackward0>)
# tensor(0.0101, grad_fn=<UnbindBackward0>)
# tensor(0.0103, grad_fn=<UnbindBackward0>)
# tensor(0.0105, grad_fn=<UnbindBackward0>)
# tensor(0.0105, grad_fn=<UnbindBackward0>)
# tensor(0.0105, grad_fn=<UnbindBackward0>)
# tensor(0.0106, grad_fn=<UnbindBackward0>)
# tensor(0.0108, grad_fn=<UnbindBackward0>)
# tensor(0.0108, grad_fn=<UnbindBackward0>)
# tensor(0.0108, grad_fn=<UnbindBackward0>)
# tensor(0.0109, grad_fn=<UnbindBackward0>)
# tensor(0.0110, grad_fn=<UnbindBackward0>)
# tensor(0.0110, grad_fn=<UnbindBackward0>)
# tensor(0.0111, grad_fn=<UnbindBackward0>)
# tensor(0.0111, grad_fn=<UnbindBackward0>)
# tensor(0.0114, grad_fn=<UnbindBackward0>)
# tensor(0.0114, grad_fn=<UnbindBackward0>)
# tensor(0.0115, grad_fn=<UnbindBackward0>)
# tensor(0.0115, grad_fn=<UnbindBackward0>)
# tensor(0.0116, grad_fn=<UnbindBackward0>)
# tensor(0.0116, grad_fn=<UnbindBackward0>)
# tensor(0.0117, grad_fn=<UnbindBackward0>)
# tensor(0.0117, grad_fn=<UnbindBackward0>)
# tensor(0.0118, grad_fn=<UnbindBackward0>)
# tensor(0.0118, grad_fn=<UnbindBackward0>)
# tensor(0.0119, grad_fn=<UnbindBackward0>)
# tensor(0.0119, grad_fn=<UnbindBackward0>)
# tensor(0.0120, grad_fn=<UnbindBackward0>)
# tensor(0.0121, grad_fn=<UnbindBackward0>)
# tensor(0.0121, grad_fn=<UnbindBackward0>)
# tensor(0.0122, grad_fn=<UnbindBackward0>)
# tensor(0.0124, grad_fn=<UnbindBackward0>)
# tensor(0.0124, grad_fn=<UnbindBackward0>)
# tensor(0.0124, grad_fn=<UnbindBackward0>)
# tensor(0.0125, grad_fn=<UnbindBackward0>)
# tensor(0.0126, grad_fn=<UnbindBackward0>)
# tensor(0.0126, grad_fn=<UnbindBackward0>)
# tensor(0.0126, grad_fn=<UnbindBackward0>)
# tensor(0.0128, grad_fn=<UnbindBackward0>)
# tensor(0.0129, grad_fn=<UnbindBackward0>)
# tensor(0.0130, grad_fn=<UnbindBackward0>)
# tensor(0.0130, grad_fn=<UnbindBackward0>)
# tensor(0.0130, grad_fn=<UnbindBackward0>)
# tensor(0.0130, grad_fn=<UnbindBackward0>)
# tensor(0.0130, grad_fn=<UnbindBackward0>)
# tensor(0.0131, grad_fn=<UnbindBackward0>)
# tensor(0.0131, grad_fn=<UnbindBackward0>)
# tensor(0.0131, grad_fn=<UnbindBackward0>)
# tensor(0.0132, grad_fn=<UnbindBackward0>)
# tensor(0.0132, grad_fn=<UnbindBackward0>)
# tensor(0.0133, grad_fn=<UnbindBackward0>)
# tensor(0.0133, grad_fn=<UnbindBackward0>)
# tensor(0.0133, grad_fn=<UnbindBackward0>)
# tensor(0.0134, grad_fn=<UnbindBackward0>)
# tensor(0.0135, grad_fn=<UnbindBackward0>)
# tensor(0.0136, grad_fn=<UnbindBackward0>)
# tensor(0.0137, grad_fn=<UnbindBackward0>)
# tensor(0.0137, grad_fn=<UnbindBackward0>)
# tensor(0.0137, grad_fn=<UnbindBackward0>)
# tensor(0.0138, grad_fn=<UnbindBackward0>)
# tensor(0.0138, grad_fn=<UnbindBackward0>)
# tensor(0.0139, grad_fn=<UnbindBackward0>)
# tensor(0.0140, grad_fn=<UnbindBackward0>)
# tensor(0.0140, grad_fn=<UnbindBackward0>)
# tensor(0.0141, grad_fn=<UnbindBackward0>)
# tensor(0.0141, grad_fn=<UnbindBackward0>)
# tensor(0.0143, grad_fn=<UnbindBackward0>)
# tensor(0.0143, grad_fn=<UnbindBackward0>)
# tensor(0.0143, grad_fn=<UnbindBackward0>)
# tensor(0.0143, grad_fn=<UnbindBackward0>)
# tensor(0.0144, grad_fn=<UnbindBackward0>)
# tensor(0.0146, grad_fn=<UnbindBackward0>)
# tensor(0.0146, grad_fn=<UnbindBackward0>)
# tensor(0.0146, grad_fn=<UnbindBackward0>)
# tensor(0.0146, grad_fn=<UnbindBackward0>)
# tensor(0.0146, grad_fn=<UnbindBackward0>)
# tensor(0.0149, grad_fn=<UnbindBackward0>)
# tensor(0.0150, grad_fn=<UnbindBackward0>)
# tensor(0.0151, grad_fn=<UnbindBackward0>)
# tensor(0.0151, grad_fn=<UnbindBackward0>)
# tensor(0.0152, grad_fn=<UnbindBackward0>)
# tensor(0.0152, grad_fn=<UnbindBackward0>)
# tensor(0.0153, grad_fn=<UnbindBackward0>)
# tensor(0.0155, grad_fn=<UnbindBackward0>)
# tensor(0.0156, grad_fn=<UnbindBackward0>)
# tensor(0.0157, grad_fn=<UnbindBackward0>)
# tensor(0.0159, grad_fn=<UnbindBackward0>)
# tensor(0.0159, grad_fn=<UnbindBackward0>)
# tensor(0.0162, grad_fn=<UnbindBackward0>)
# tensor(0.0162, grad_fn=<UnbindBackward0>)
# tensor(0.0163, grad_fn=<UnbindBackward0>)
# tensor(0.0163, grad_fn=<UnbindBackward0>)
# tensor(0.0163, grad_fn=<UnbindBackward0>)
# tensor(0.0164, grad_fn=<UnbindBackward0>)
# tensor(0.0164, grad_fn=<UnbindBackward0>)
# tensor(0.0165, grad_fn=<UnbindBackward0>)
# tensor(0.0165, grad_fn=<UnbindBackward0>)
# tensor(0.0168, grad_fn=<UnbindBackward0>)
# tensor(0.0170, grad_fn=<UnbindBackward0>)
# tensor(0.0171, grad_fn=<UnbindBackward0>)
# tensor(0.0171, grad_fn=<UnbindBackward0>)
# tensor(0.0172, grad_fn=<UnbindBackward0>)
# tensor(0.0172, grad_fn=<UnbindBackward0>)
# tensor(0.0172, grad_fn=<UnbindBackward0>)
# tensor(0.0173, grad_fn=<UnbindBackward0>)
# tensor(0.0174, grad_fn=<UnbindBackward0>)
# tensor(0.0174, grad_fn=<UnbindBackward0>)
# tensor(0.0175, grad_fn=<UnbindBackward0>)
# tensor(0.0176, grad_fn=<UnbindBackward0>)
# tensor(0.0176, grad_fn=<UnbindBackward0>)
# tensor(0.0176, grad_fn=<UnbindBackward0>)
# tensor(0.0179, grad_fn=<UnbindBackward0>)
# tensor(0.0179, grad_fn=<UnbindBackward0>)
# tensor(0.0180, grad_fn=<UnbindBackward0>)
# tensor(0.0180, grad_fn=<UnbindBackward0>)
# tensor(0.0181, grad_fn=<UnbindBackward0>)
# tensor(0.0181, grad_fn=<UnbindBackward0>)
# tensor(0.0181, grad_fn=<UnbindBackward0>)
# tensor(0.0181, grad_fn=<UnbindBackward0>)
# tensor(0.0182, grad_fn=<UnbindBackward0>)
# tensor(0.0183, grad_fn=<UnbindBackward0>)
# tensor(0.0184, grad_fn=<UnbindBackward0>)
# tensor(0.0184, grad_fn=<UnbindBackward0>)
# tensor(0.0189, grad_fn=<UnbindBackward0>)
# tensor(0.0189, grad_fn=<UnbindBackward0>)
# tensor(0.0192, grad_fn=<UnbindBackward0>)
# tensor(0.0192, grad_fn=<UnbindBackward0>)
# tensor(0.0194, grad_fn=<UnbindBackward0>)
# tensor(0.0197, grad_fn=<UnbindBackward0>)
# tensor(0.0198, grad_fn=<UnbindBackward0>)
# tensor(0.0199, grad_fn=<UnbindBackward0>)
# tensor(0.0200, grad_fn=<UnbindBackward0>)
# tensor(0.0203, grad_fn=<UnbindBackward0>)
# tensor(0.0203, grad_fn=<UnbindBackward0>)
# tensor(0.0204, grad_fn=<UnbindBackward0>)
# tensor(0.0206, grad_fn=<UnbindBackward0>)
# tensor(0.0208, grad_fn=<UnbindBackward0>)
# tensor(0.0209, grad_fn=<UnbindBackward0>)
# tensor(0.0209, grad_fn=<UnbindBackward0>)
# tensor(0.0210, grad_fn=<UnbindBackward0>)
# tensor(0.0211, grad_fn=<UnbindBackward0>)
# tensor(0.0214, grad_fn=<UnbindBackward0>)
# tensor(0.0216, grad_fn=<UnbindBackward0>)
# tensor(0.0216, grad_fn=<UnbindBackward0>)
# tensor(0.0217, grad_fn=<UnbindBackward0>)
# tensor(0.0217, grad_fn=<UnbindBackward0>)
# tensor(0.0218, grad_fn=<UnbindBackward0>)
# tensor(0.0222, grad_fn=<UnbindBackward0>)
# tensor(0.0223, grad_fn=<UnbindBackward0>)
# tensor(0.0224, grad_fn=<UnbindBackward0>)
# tensor(0.0224, grad_fn=<UnbindBackward0>)
# tensor(0.0224, grad_fn=<UnbindBackward0>)
# tensor(0.0225, grad_fn=<UnbindBackward0>)
# tensor(0.0226, grad_fn=<UnbindBackward0>)
# tensor(0.0227, grad_fn=<UnbindBackward0>)
# tensor(0.0228, grad_fn=<UnbindBackward0>)
# tensor(0.0228, grad_fn=<UnbindBackward0>)
# tensor(0.0228, grad_fn=<UnbindBackward0>)
# tensor(0.0228, grad_fn=<UnbindBackward0>)
# tensor(0.0229, grad_fn=<UnbindBackward0>)
# tensor(0.0230, grad_fn=<UnbindBackward0>)
# tensor(0.0232, grad_fn=<UnbindBackward0>)
# tensor(0.0234, grad_fn=<UnbindBackward0>)
# tensor(0.0238, grad_fn=<UnbindBackward0>)
# tensor(0.0239, grad_fn=<UnbindBackward0>)
# tensor(0.0241, grad_fn=<UnbindBackward0>)
# tensor(0.0242, grad_fn=<UnbindBackward0>)
# tensor(0.0243, grad_fn=<UnbindBackward0>)
# tensor(0.0243, grad_fn=<UnbindBackward0>)
# tensor(0.0245, grad_fn=<UnbindBackward0>)
# tensor(0.0246, grad_fn=<UnbindBackward0>)
# tensor(0.0246, grad_fn=<UnbindBackward0>)
# tensor(0.0247, grad_fn=<UnbindBackward0>)
# tensor(0.0248, grad_fn=<UnbindBackward0>)
# tensor(0.0249, grad_fn=<UnbindBackward0>)
# tensor(0.0250, grad_fn=<UnbindBackward0>)
# tensor(0.0251, grad_fn=<UnbindBackward0>)
# tensor(0.0251, grad_fn=<UnbindBackward0>)
# tensor(0.0253, grad_fn=<UnbindBackward0>)
# tensor(0.0253, grad_fn=<UnbindBackward0>)
# tensor(0.0255, grad_fn=<UnbindBackward0>)
# tensor(0.0262, grad_fn=<UnbindBackward0>)
# tensor(0.0265, grad_fn=<UnbindBackward0>)
# tensor(0.0267, grad_fn=<UnbindBackward0>)
# tensor(0.0268, grad_fn=<UnbindBackward0>)
# tensor(0.0269, grad_fn=<UnbindBackward0>)
# tensor(0.0270, grad_fn=<UnbindBackward0>)
# tensor(0.0273, grad_fn=<UnbindBackward0>)
# tensor(0.0273, grad_fn=<UnbindBackward0>)
# tensor(0.0274, grad_fn=<UnbindBackward0>)
# tensor(0.0274, grad_fn=<UnbindBackward0>)
# tensor(0.0275, grad_fn=<UnbindBackward0>)
# tensor(0.0276, grad_fn=<UnbindBackward0>)
# tensor(0.0279, grad_fn=<UnbindBackward0>)
# tensor(0.0289, grad_fn=<UnbindBackward0>)
# tensor(0.0291, grad_fn=<UnbindBackward0>)
# tensor(0.0292, grad_fn=<UnbindBackward0>)
# tensor(0.0297, grad_fn=<UnbindBackward0>)
# tensor(0.0299, grad_fn=<UnbindBackward0>)
# tensor(0.0299, grad_fn=<UnbindBackward0>)
# tensor(0.0299, grad_fn=<UnbindBackward0>)
# tensor(0.0302, grad_fn=<UnbindBackward0>)
# tensor(0.0303, grad_fn=<UnbindBackward0>)
# tensor(0.0304, grad_fn=<UnbindBackward0>)
# tensor(0.0304, grad_fn=<UnbindBackward0>)
# tensor(0.0304, grad_fn=<UnbindBackward0>)
# tensor(0.0305, grad_fn=<UnbindBackward0>)
# tensor(0.0308, grad_fn=<UnbindBackward0>)
# tensor(0.0311, grad_fn=<UnbindBackward0>)
# tensor(0.0314, grad_fn=<UnbindBackward0>)
# tensor(0.0314, grad_fn=<UnbindBackward0>)
# tensor(0.0316, grad_fn=<UnbindBackward0>)
# tensor(0.0317, grad_fn=<UnbindBackward0>)
# tensor(0.0320, grad_fn=<UnbindBackward0>)
# tensor(0.0321, grad_fn=<UnbindBackward0>)
# tensor(0.0321, grad_fn=<UnbindBackward0>)
# tensor(0.0324, grad_fn=<UnbindBackward0>)
# tensor(0.0325, grad_fn=<UnbindBackward0>)
# tensor(0.0326, grad_fn=<UnbindBackward0>)
# tensor(0.0329, grad_fn=<UnbindBackward0>)
# tensor(0.0334, grad_fn=<UnbindBackward0>)
# tensor(0.0335, grad_fn=<UnbindBackward0>)
# tensor(0.0335, grad_fn=<UnbindBackward0>)
# tensor(0.0336, grad_fn=<UnbindBackward0>)
# tensor(0.0340, grad_fn=<UnbindBackward0>)
# tensor(0.0342, grad_fn=<UnbindBackward0>)
# tensor(0.0342, grad_fn=<UnbindBackward0>)
# tensor(0.0346, grad_fn=<UnbindBackward0>)
# tensor(0.0359, grad_fn=<UnbindBackward0>)
# tensor(0.0361, grad_fn=<UnbindBackward0>)
# tensor(0.0362, grad_fn=<UnbindBackward0>)
# tensor(0.0362, grad_fn=<UnbindBackward0>)
# tensor(0.0364, grad_fn=<UnbindBackward0>)
# tensor(0.0364, grad_fn=<UnbindBackward0>)
# tensor(0.0365, grad_fn=<UnbindBackward0>)
# tensor(0.0367, grad_fn=<UnbindBackward0>)
# tensor(0.0368, grad_fn=<UnbindBackward0>)
# tensor(0.0371, grad_fn=<UnbindBackward0>)
# tensor(0.0371, grad_fn=<UnbindBackward0>)
# tensor(0.0371, grad_fn=<UnbindBackward0>)
# tensor(0.0373, grad_fn=<UnbindBackward0>)
# tensor(0.0373, grad_fn=<UnbindBackward0>)
# tensor(0.0382, grad_fn=<UnbindBackward0>)
# tensor(0.0388, grad_fn=<UnbindBackward0>)
# tensor(0.0390, grad_fn=<UnbindBackward0>)
# tensor(0.0390, grad_fn=<UnbindBackward0>)
# tensor(0.0390, grad_fn=<UnbindBackward0>)
# tensor(0.0391, grad_fn=<UnbindBackward0>)
# tensor(0.0392, grad_fn=<UnbindBackward0>)
# tensor(0.0393, grad_fn=<UnbindBackward0>)
# tensor(0.0394, grad_fn=<UnbindBackward0>)
# tensor(0.0399, grad_fn=<UnbindBackward0>)
# tensor(0.0399, grad_fn=<UnbindBackward0>)
# tensor(0.0400, grad_fn=<UnbindBackward0>)
# tensor(0.0403, grad_fn=<UnbindBackward0>)
# tensor(0.0404, grad_fn=<UnbindBackward0>)
# tensor(0.0411, grad_fn=<UnbindBackward0>)
# tensor(0.0420, grad_fn=<UnbindBackward0>)
# tensor(0.0422, grad_fn=<UnbindBackward0>)
# tensor(0.0424, grad_fn=<UnbindBackward0>)
# tensor(0.0424, grad_fn=<UnbindBackward0>)
# tensor(0.0429, grad_fn=<UnbindBackward0>)
# tensor(0.0438, grad_fn=<UnbindBackward0>)
# tensor(0.0440, grad_fn=<UnbindBackward0>)
# tensor(0.0440, grad_fn=<UnbindBackward0>)
# tensor(0.0443, grad_fn=<UnbindBackward0>)
# tensor(0.0444, grad_fn=<UnbindBackward0>)
# tensor(0.0450, grad_fn=<UnbindBackward0>)
# tensor(0.0452, grad_fn=<UnbindBackward0>)
# tensor(0.0452, grad_fn=<UnbindBackward0>)
# tensor(0.0452, grad_fn=<UnbindBackward0>)
# tensor(0.0453, grad_fn=<UnbindBackward0>)
# tensor(0.0456, grad_fn=<UnbindBackward0>)
# tensor(0.0456, grad_fn=<UnbindBackward0>)
# tensor(0.0460, grad_fn=<UnbindBackward0>)
# tensor(0.0466, grad_fn=<UnbindBackward0>)
# tensor(0.0466, grad_fn=<UnbindBackward0>)
# tensor(0.0469, grad_fn=<UnbindBackward0>)
# tensor(0.0470, grad_fn=<UnbindBackward0>)
# tensor(0.0471, grad_fn=<UnbindBackward0>)
# tensor(0.0471, grad_fn=<UnbindBackward0>)
# tensor(0.0473, grad_fn=<UnbindBackward0>)
# tensor(0.0475, grad_fn=<UnbindBackward0>)
# tensor(0.0476, grad_fn=<UnbindBackward0>)
# tensor(0.0486, grad_fn=<UnbindBackward0>)
# tensor(0.0490, grad_fn=<UnbindBackward0>)
# tensor(0.0493, grad_fn=<UnbindBackward0>)
# tensor(0.0495, grad_fn=<UnbindBackward0>)
# tensor(0.0499, grad_fn=<UnbindBackward0>)
# tensor(0.0509, grad_fn=<UnbindBackward0>)
# tensor(0.0509, grad_fn=<UnbindBackward0>)
# tensor(0.0515, grad_fn=<UnbindBackward0>)
# tensor(0.0515, grad_fn=<UnbindBackward0>)
# tensor(0.0519, grad_fn=<UnbindBackward0>)
# tensor(0.0520, grad_fn=<UnbindBackward0>)
# tensor(0.0522, grad_fn=<UnbindBackward0>)
# tensor(0.0522, grad_fn=<UnbindBackward0>)
# tensor(0.0525, grad_fn=<UnbindBackward0>)
# tensor(0.0526, grad_fn=<UnbindBackward0>)
# tensor(0.0527, grad_fn=<UnbindBackward0>)
# tensor(0.0534, grad_fn=<UnbindBackward0>)
# tensor(0.0535, grad_fn=<UnbindBackward0>)
# tensor(0.0537, grad_fn=<UnbindBackward0>)
# tensor(0.0547, grad_fn=<UnbindBackward0>)
# tensor(0.0558, grad_fn=<UnbindBackward0>)
# tensor(0.0566, grad_fn=<UnbindBackward0>)
# tensor(0.0569, grad_fn=<UnbindBackward0>)
# tensor(0.0569, grad_fn=<UnbindBackward0>)
# tensor(0.0573, grad_fn=<UnbindBackward0>)
# tensor(0.0573, grad_fn=<UnbindBackward0>)
# tensor(0.0581, grad_fn=<UnbindBackward0>)
# tensor(0.0581, grad_fn=<UnbindBackward0>)
# tensor(0.0581, grad_fn=<UnbindBackward0>)
# tensor(0.0584, grad_fn=<UnbindBackward0>)
# tensor(0.0590, grad_fn=<UnbindBackward0>)
# tensor(0.0591, grad_fn=<UnbindBackward0>)
# tensor(0.0591, grad_fn=<UnbindBackward0>)
# tensor(0.0596, grad_fn=<UnbindBackward0>)
# tensor(0.0605, grad_fn=<UnbindBackward0>)
# tensor(0.0611, grad_fn=<UnbindBackward0>)
# tensor(0.0619, grad_fn=<UnbindBackward0>)
# tensor(0.0624, grad_fn=<UnbindBackward0>)
# tensor(0.0626, grad_fn=<UnbindBackward0>)
# tensor(0.0628, grad_fn=<UnbindBackward0>)
# tensor(0.0631, grad_fn=<UnbindBackward0>)
# tensor(0.0635, grad_fn=<UnbindBackward0>)
# tensor(0.0638, grad_fn=<UnbindBackward0>)
# tensor(0.0641, grad_fn=<UnbindBackward0>)
# tensor(0.0643, grad_fn=<UnbindBackward0>)
# tensor(0.0647, grad_fn=<UnbindBackward0>)
# tensor(0.0653, grad_fn=<UnbindBackward0>)
# tensor(0.0658, grad_fn=<UnbindBackward0>)
# tensor(0.0660, grad_fn=<UnbindBackward0>)
# tensor(0.0663, grad_fn=<UnbindBackward0>)
# tensor(0.0664, grad_fn=<UnbindBackward0>)
# tensor(0.0671, grad_fn=<UnbindBackward0>)
# tensor(0.0673, grad_fn=<UnbindBackward0>)
# tensor(0.0694, grad_fn=<UnbindBackward0>)
# tensor(0.0699, grad_fn=<UnbindBackward0>)
# tensor(0.0702, grad_fn=<UnbindBackward0>)
# tensor(0.0714, grad_fn=<UnbindBackward0>)
# tensor(0.0715, grad_fn=<UnbindBackward0>)
# tensor(0.0715, grad_fn=<UnbindBackward0>)
# tensor(0.0731, grad_fn=<UnbindBackward0>)
# tensor(0.0734, grad_fn=<UnbindBackward0>)
# tensor(0.0738, grad_fn=<UnbindBackward0>)
# tensor(0.0740, grad_fn=<UnbindBackward0>)
# tensor(0.0746, grad_fn=<UnbindBackward0>)
# tensor(0.0748, grad_fn=<UnbindBackward0>)
# tensor(0.0751, grad_fn=<UnbindBackward0>)
# tensor(0.0753, grad_fn=<UnbindBackward0>)
# tensor(0.0765, grad_fn=<UnbindBackward0>)
# tensor(0.0773, grad_fn=<UnbindBackward0>)
# tensor(0.0776, grad_fn=<UnbindBackward0>)
# tensor(0.0780, grad_fn=<UnbindBackward0>)
# tensor(0.0782, grad_fn=<UnbindBackward0>)
# tensor(0.0793, grad_fn=<UnbindBackward0>)
# tensor(0.0801, grad_fn=<UnbindBackward0>)
# tensor(0.0817, grad_fn=<UnbindBackward0>)
# tensor(0.0819, grad_fn=<UnbindBackward0>)
# tensor(0.0823, grad_fn=<UnbindBackward0>)
# tensor(0.0824, grad_fn=<UnbindBackward0>)
# tensor(0.0827, grad_fn=<UnbindBackward0>)
# tensor(0.0829, grad_fn=<UnbindBackward0>)
# tensor(0.0829, grad_fn=<UnbindBackward0>)
# tensor(0.0832, grad_fn=<UnbindBackward0>)
# tensor(0.0833, grad_fn=<UnbindBackward0>)
# tensor(0.0851, grad_fn=<UnbindBackward0>)
# tensor(0.0855, grad_fn=<UnbindBackward0>)
# tensor(0.0856, grad_fn=<UnbindBackward0>)
# tensor(0.0857, grad_fn=<UnbindBackward0>)
# tensor(0.0860, grad_fn=<UnbindBackward0>)
# tensor(0.0861, grad_fn=<UnbindBackward0>)
# tensor(0.0861, grad_fn=<UnbindBackward0>)
# tensor(0.0871, grad_fn=<UnbindBackward0>)
# tensor(0.0871, grad_fn=<UnbindBackward0>)
# tensor(0.0877, grad_fn=<UnbindBackward0>)
# tensor(0.0878, grad_fn=<UnbindBackward0>)
# tensor(0.0879, grad_fn=<UnbindBackward0>)
# tensor(0.0880, grad_fn=<UnbindBackward0>)
# tensor(0.0881, grad_fn=<UnbindBackward0>)
# tensor(0.0888, grad_fn=<UnbindBackward0>)
# tensor(0.0893, grad_fn=<UnbindBackward0>)
# tensor(0.0897, grad_fn=<UnbindBackward0>)
# tensor(0.0901, grad_fn=<UnbindBackward0>)
# tensor(0.0903, grad_fn=<UnbindBackward0>)
# tensor(0.0921, grad_fn=<UnbindBackward0>)
# tensor(0.0924, grad_fn=<UnbindBackward0>)
# tensor(0.0929, grad_fn=<UnbindBackward0>)
# tensor(0.0930, grad_fn=<UnbindBackward0>)
# tensor(0.0930, grad_fn=<UnbindBackward0>)
# tensor(0.0934, grad_fn=<UnbindBackward0>)
# tensor(0.0947, grad_fn=<UnbindBackward0>)
# tensor(0.0953, grad_fn=<UnbindBackward0>)
# tensor(0.0967, grad_fn=<UnbindBackward0>)
# tensor(0.0971, grad_fn=<UnbindBackward0>)
# tensor(0.0975, grad_fn=<UnbindBackward0>)
# tensor(0.0981, grad_fn=<UnbindBackward0>)
# tensor(0.0988, grad_fn=<UnbindBackward0>)
# tensor(0.1005, grad_fn=<UnbindBackward0>)
# tensor(0.1005, grad_fn=<UnbindBackward0>)
# ...
# tensor(0.9826, grad_fn=<UnbindBackward0>)
# tensor(0.9832, grad_fn=<UnbindBackward0>)
# tensor(0.9833, grad_fn=<UnbindBackward0>)
# tensor(0.9834, grad_fn=<UnbindBackward0>)
# tensor(0.9834, grad_fn=<UnbindBackward0>)
# tensor(0.9837, grad_fn=<UnbindBackward0>)
# tensor(0.9840, grad_fn=<UnbindBackward0>)
# tensor(0.9843, grad_fn=<UnbindBackward0>)
# tensor(0.9843, grad_fn=<UnbindBackward0>)
# tensor(0.9843, grad_fn=<UnbindBackward0>)
# tensor(0.9845, grad_fn=<UnbindBackward0>)
# tensor(0.9845, grad_fn=<UnbindBackward0>)
# tensor(0.9848, grad_fn=<UnbindBackward0>)
# tensor(0.9849, grad_fn=<UnbindBackward0>)
# tensor(0.9850, grad_fn=<UnbindBackward0>)
# tensor(0.9851, grad_fn=<UnbindBackward0>)
# tensor(0.9853, grad_fn=<UnbindBackward0>)
# tensor(0.9854, grad_fn=<UnbindBackward0>)
# tensor(0.9854, grad_fn=<UnbindBackward0>)
# tensor(0.9855, grad_fn=<UnbindBackward0>)
# tensor(0.9855, grad_fn=<UnbindBackward0>)
# tensor(0.9855, grad_fn=<UnbindBackward0>)
# tensor(0.9855, grad_fn=<UnbindBackward0>)
# tensor(0.9857, grad_fn=<UnbindBackward0>)
# tensor(0.9858, grad_fn=<UnbindBackward0>)
# tensor(0.9859, grad_fn=<UnbindBackward0>)
# tensor(0.9860, grad_fn=<UnbindBackward0>)
# tensor(0.9861, grad_fn=<UnbindBackward0>)
# tensor(0.9862, grad_fn=<UnbindBackward0>)
# tensor(0.9862, grad_fn=<UnbindBackward0>)
# tensor(0.9862, grad_fn=<UnbindBackward0>)
# tensor(0.9865, grad_fn=<UnbindBackward0>)
# tensor(0.9866, grad_fn=<UnbindBackward0>)
# tensor(0.9867, grad_fn=<UnbindBackward0>)
# tensor(0.9868, grad_fn=<UnbindBackward0>)
# tensor(0.9869, grad_fn=<UnbindBackward0>)
# tensor(0.9869, grad_fn=<UnbindBackward0>)
# tensor(0.9870, grad_fn=<UnbindBackward0>)
# tensor(0.9871, grad_fn=<UnbindBackward0>)
# tensor(0.9871, grad_fn=<UnbindBackward0>)
# tensor(0.9871, grad_fn=<UnbindBackward0>)
# tensor(0.9874, grad_fn=<UnbindBackward0>)
# tensor(0.9874, grad_fn=<UnbindBackward0>)
# tensor(0.9876, grad_fn=<UnbindBackward0>)
# tensor(0.9877, grad_fn=<UnbindBackward0>)
# tensor(0.9877, grad_fn=<UnbindBackward0>)
# tensor(0.9877, grad_fn=<UnbindBackward0>)
# tensor(0.9878, grad_fn=<UnbindBackward0>)
# tensor(0.9880, grad_fn=<UnbindBackward0>)
# tensor(0.9881, grad_fn=<UnbindBackward0>)
# tensor(0.9881, grad_fn=<UnbindBackward0>)
# tensor(0.9882, grad_fn=<UnbindBackward0>)
# tensor(0.9882, grad_fn=<UnbindBackward0>)
# tensor(0.9884, grad_fn=<UnbindBackward0>)
# tensor(0.9885, grad_fn=<UnbindBackward0>)
# tensor(0.9887, grad_fn=<UnbindBackward0>)
# tensor(0.9888, grad_fn=<UnbindBackward0>)
# tensor(0.9888, grad_fn=<UnbindBackward0>)
# tensor(0.9889, grad_fn=<UnbindBackward0>)
# tensor(0.9890, grad_fn=<UnbindBackward0>)
# tensor(0.9890, grad_fn=<UnbindBackward0>)
# tensor(0.9891, grad_fn=<UnbindBackward0>)
# tensor(0.9891, grad_fn=<UnbindBackward0>)
# tensor(0.9892, grad_fn=<UnbindBackward0>)
# tensor(0.9895, grad_fn=<UnbindBackward0>)
# tensor(0.9895, grad_fn=<UnbindBackward0>)
# tensor(0.9896, grad_fn=<UnbindBackward0>)
# tensor(0.9896, grad_fn=<UnbindBackward0>)
# tensor(0.9896, grad_fn=<UnbindBackward0>)
# tensor(0.9896, grad_fn=<UnbindBackward0>)
# tensor(0.9896, grad_fn=<UnbindBackward0>)
# tensor(0.9898, grad_fn=<UnbindBackward0>)
# tensor(0.9898, grad_fn=<UnbindBackward0>)
# tensor(0.9899, grad_fn=<UnbindBackward0>)
# tensor(0.9900, grad_fn=<UnbindBackward0>)
# tensor(0.9902, grad_fn=<UnbindBackward0>)
# tensor(0.9902, grad_fn=<UnbindBackward0>)
# tensor(0.9902, grad_fn=<UnbindBackward0>)
# tensor(0.9903, grad_fn=<UnbindBackward0>)
# tensor(0.9903, grad_fn=<UnbindBackward0>)
# tensor(0.9904, grad_fn=<UnbindBackward0>)
# tensor(0.9904, grad_fn=<UnbindBackward0>)
# tensor(0.9907, grad_fn=<UnbindBackward0>)
# tensor(0.9907, grad_fn=<UnbindBackward0>)
# tensor(0.9907, grad_fn=<UnbindBackward0>)
# tensor(0.9908, grad_fn=<UnbindBackward0>)
# tensor(0.9909, grad_fn=<UnbindBackward0>)
# tensor(0.9909, grad_fn=<UnbindBackward0>)
# tensor(0.9910, grad_fn=<UnbindBackward0>)
# tensor(0.9910, grad_fn=<UnbindBackward0>)
# tensor(0.9911, grad_fn=<UnbindBackward0>)
# tensor(0.9911, grad_fn=<UnbindBackward0>)
# tensor(0.9912, grad_fn=<UnbindBackward0>)
# tensor(0.9912, grad_fn=<UnbindBackward0>)
# tensor(0.9913, grad_fn=<UnbindBackward0>)
# tensor(0.9913, grad_fn=<UnbindBackward0>)
# tensor(0.9913, grad_fn=<UnbindBackward0>)
# tensor(0.9914, grad_fn=<UnbindBackward0>)
# tensor(0.9914, grad_fn=<UnbindBackward0>)
# tensor(0.9915, grad_fn=<UnbindBackward0>)
# tensor(0.9916, grad_fn=<UnbindBackward0>)
# tensor(0.9916, grad_fn=<UnbindBackward0>)
# tensor(0.9917, grad_fn=<UnbindBackward0>)
# tensor(0.9918, grad_fn=<UnbindBackward0>)
# tensor(0.9918, grad_fn=<UnbindBackward0>)
# tensor(0.9920, grad_fn=<UnbindBackward0>)
# tensor(0.9920, grad_fn=<UnbindBackward0>)
# tensor(0.9921, grad_fn=<UnbindBackward0>)
# tensor(0.9921, grad_fn=<UnbindBackward0>)
# tensor(0.9922, grad_fn=<UnbindBackward0>)
# tensor(0.9923, grad_fn=<UnbindBackward0>)
# tensor(0.9923, grad_fn=<UnbindBackward0>)
# tensor(0.9927, grad_fn=<UnbindBackward0>)
# tensor(0.9927, grad_fn=<UnbindBackward0>)
# tensor(0.9928, grad_fn=<UnbindBackward0>)
# tensor(0.9929, grad_fn=<UnbindBackward0>)
# tensor(0.9929, grad_fn=<UnbindBackward0>)
# tensor(0.9929, grad_fn=<UnbindBackward0>)
# tensor(0.9929, grad_fn=<UnbindBackward0>)
# tensor(0.9930, grad_fn=<UnbindBackward0>)
# tensor(0.9930, grad_fn=<UnbindBackward0>)
# tensor(0.9930, grad_fn=<UnbindBackward0>)
# tensor(0.9931, grad_fn=<UnbindBackward0>)
# tensor(0.9931, grad_fn=<UnbindBackward0>)
# tensor(0.9931, grad_fn=<UnbindBackward0>)
# tensor(0.9931, grad_fn=<UnbindBackward0>)
# tensor(0.9932, grad_fn=<UnbindBackward0>)
# tensor(0.9933, grad_fn=<UnbindBackward0>)
# tensor(0.9933, grad_fn=<UnbindBackward0>)
# tensor(0.9934, grad_fn=<UnbindBackward0>)
# tensor(0.9935, grad_fn=<UnbindBackward0>)
# tensor(0.9935, grad_fn=<UnbindBackward0>)
# tensor(0.9937, grad_fn=<UnbindBackward0>)
# tensor(0.9937, grad_fn=<UnbindBackward0>)
# tensor(0.9937, grad_fn=<UnbindBackward0>)
# tensor(0.9938, grad_fn=<UnbindBackward0>)
# tensor(0.9939, grad_fn=<UnbindBackward0>)
# tensor(0.9939, grad_fn=<UnbindBackward0>)
# tensor(0.9940, grad_fn=<UnbindBackward0>)
# tensor(0.9940, grad_fn=<UnbindBackward0>)
# tensor(0.9940, grad_fn=<UnbindBackward0>)
# tensor(0.9940, grad_fn=<UnbindBackward0>)
# tensor(0.9941, grad_fn=<UnbindBackward0>)
# tensor(0.9941, grad_fn=<UnbindBackward0>)
# tensor(0.9941, grad_fn=<UnbindBackward0>)
# tensor(0.9942, grad_fn=<UnbindBackward0>)
# tensor(0.9942, grad_fn=<UnbindBackward0>)
# tensor(0.9942, grad_fn=<UnbindBackward0>)
# tensor(0.9942, grad_fn=<UnbindBackward0>)
# tensor(0.9942, grad_fn=<UnbindBackward0>)
# tensor(0.9943, grad_fn=<UnbindBackward0>)
# tensor(0.9944, grad_fn=<UnbindBackward0>)
# tensor(0.9944, grad_fn=<UnbindBackward0>)
# tensor(0.9944, grad_fn=<UnbindBackward0>)
# tensor(0.9944, grad_fn=<UnbindBackward0>)
# tensor(0.9945, grad_fn=<UnbindBackward0>)
# tensor(0.9945, grad_fn=<UnbindBackward0>)
# tensor(0.9945, grad_fn=<UnbindBackward0>)
# tensor(0.9946, grad_fn=<UnbindBackward0>)
# tensor(0.9946, grad_fn=<UnbindBackward0>)
# tensor(0.9946, grad_fn=<UnbindBackward0>)
# tensor(0.9946, grad_fn=<UnbindBackward0>)
# tensor(0.9946, grad_fn=<UnbindBackward0>)
# tensor(0.9947, grad_fn=<UnbindBackward0>)
# tensor(0.9948, grad_fn=<UnbindBackward0>)
# tensor(0.9948, grad_fn=<UnbindBackward0>)
# tensor(0.9948, grad_fn=<UnbindBackward0>)
# tensor(0.9949, grad_fn=<UnbindBackward0>)
# tensor(0.9949, grad_fn=<UnbindBackward0>)
# tensor(0.9949, grad_fn=<UnbindBackward0>)
# tensor(0.9950, grad_fn=<UnbindBackward0>)
# tensor(0.9950, grad_fn=<UnbindBackward0>)
# tensor(0.9950, grad_fn=<UnbindBackward0>)
# tensor(0.9950, grad_fn=<UnbindBackward0>)
# tensor(0.9950, grad_fn=<UnbindBackward0>)
# tensor(0.9950, grad_fn=<UnbindBackward0>)
# tensor(0.9951, grad_fn=<UnbindBackward0>)
# tensor(0.9951, grad_fn=<UnbindBackward0>)
# tensor(0.9952, grad_fn=<UnbindBackward0>)
# tensor(0.9952, grad_fn=<UnbindBackward0>)
# tensor(0.9952, grad_fn=<UnbindBackward0>)
# tensor(0.9952, grad_fn=<UnbindBackward0>)
# tensor(0.9953, grad_fn=<UnbindBackward0>)
# tensor(0.9954, grad_fn=<UnbindBackward0>)
# tensor(0.9955, grad_fn=<UnbindBackward0>)
# tensor(0.9955, grad_fn=<UnbindBackward0>)
# tensor(0.9955, grad_fn=<UnbindBackward0>)
# tensor(0.9955, grad_fn=<UnbindBackward0>)
# tensor(0.9955, grad_fn=<UnbindBackward0>)
# tensor(0.9956, grad_fn=<UnbindBackward0>)
# tensor(0.9956, grad_fn=<UnbindBackward0>)
# tensor(0.9956, grad_fn=<UnbindBackward0>)
# tensor(0.9956, grad_fn=<UnbindBackward0>)
# tensor(0.9956, grad_fn=<UnbindBackward0>)
# tensor(0.9956, grad_fn=<UnbindBackward0>)
# tensor(0.9956, grad_fn=<UnbindBackward0>)
# tensor(0.9958, grad_fn=<UnbindBackward0>)
# tensor(0.9958, grad_fn=<UnbindBackward0>)
# tensor(0.9958, grad_fn=<UnbindBackward0>)
# tensor(0.9958, grad_fn=<UnbindBackward0>)
# tensor(0.9958, grad_fn=<UnbindBackward0>)
# tensor(0.9959, grad_fn=<UnbindBackward0>)
# tensor(0.9959, grad_fn=<UnbindBackward0>)
# tensor(0.9959, grad_fn=<UnbindBackward0>)
# tensor(0.9960, grad_fn=<UnbindBackward0>)
# tensor(0.9960, grad_fn=<UnbindBackward0>)
# tensor(0.9960, grad_fn=<UnbindBackward0>)
# tensor(0.9961, grad_fn=<UnbindBackward0>)
# tensor(0.9961, grad_fn=<UnbindBackward0>)
# tensor(0.9961, grad_fn=<UnbindBackward0>)
# tensor(0.9961, grad_fn=<UnbindBackward0>)
# tensor(0.9961, grad_fn=<UnbindBackward0>)
# tensor(0.9962, grad_fn=<UnbindBackward0>)
# tensor(0.9962, grad_fn=<UnbindBackward0>)
# tensor(0.9962, grad_fn=<UnbindBackward0>)
# tensor(0.9963, grad_fn=<UnbindBackward0>)
# tensor(0.9964, grad_fn=<UnbindBackward0>)
# tensor(0.9964, grad_fn=<UnbindBackward0>)
# tensor(0.9964, grad_fn=<UnbindBackward0>)
# tensor(0.9965, grad_fn=<UnbindBackward0>)
# tensor(0.9965, grad_fn=<UnbindBackward0>)
# tensor(0.9965, grad_fn=<UnbindBackward0>)
# tensor(0.9965, grad_fn=<UnbindBackward0>)
# tensor(0.9965, grad_fn=<UnbindBackward0>)
# tensor(0.9965, grad_fn=<UnbindBackward0>)
# tensor(0.9965, grad_fn=<UnbindBackward0>)
# tensor(0.9965, grad_fn=<UnbindBackward0>)
# tensor(0.9966, grad_fn=<UnbindBackward0>)
# tensor(0.9968, grad_fn=<UnbindBackward0>)
# tensor(0.9968, grad_fn=<UnbindBackward0>)
# tensor(0.9968, grad_fn=<UnbindBackward0>)
# tensor(0.9968, grad_fn=<UnbindBackward0>)
# tensor(0.9969, grad_fn=<UnbindBackward0>)
# tensor(0.9969, grad_fn=<UnbindBackward0>)
# tensor(0.9969, grad_fn=<UnbindBackward0>)
# tensor(0.9969, grad_fn=<UnbindBackward0>)
# tensor(0.9969, grad_fn=<UnbindBackward0>)
# tensor(0.9969, grad_fn=<UnbindBackward0>)
# tensor(0.9970, grad_fn=<UnbindBackward0>)
# tensor(0.9970, grad_fn=<UnbindBackward0>)
# tensor(0.9971, grad_fn=<UnbindBackward0>)
# tensor(0.9971, grad_fn=<UnbindBackward0>)
# tensor(0.9971, grad_fn=<UnbindBackward0>)
# tensor(0.9972, grad_fn=<UnbindBackward0>)
# tensor(0.9972, grad_fn=<UnbindBackward0>)
# tensor(0.9972, grad_fn=<UnbindBackward0>)
# tensor(0.9973, grad_fn=<UnbindBackward0>)
# tensor(0.9973, grad_fn=<UnbindBackward0>)
# tensor(0.9973, grad_fn=<UnbindBackward0>)
# tensor(0.9973, grad_fn=<UnbindBackward0>)
# tensor(0.9973, grad_fn=<UnbindBackward0>)
# tensor(0.9973, grad_fn=<UnbindBackward0>)
# tensor(0.9974, grad_fn=<UnbindBackward0>)
# tensor(0.9974, grad_fn=<UnbindBackward0>)
# tensor(0.9974, grad_fn=<UnbindBackward0>)
# tensor(0.9974, grad_fn=<UnbindBackward0>)
# tensor(0.9974, grad_fn=<UnbindBackward0>)
# tensor(0.9974, grad_fn=<UnbindBackward0>)
# tensor(0.9975, grad_fn=<UnbindBackward0>)
# tensor(0.9975, grad_fn=<UnbindBackward0>)
# tensor(0.9976, grad_fn=<UnbindBackward0>)
# tensor(0.9976, grad_fn=<UnbindBackward0>)
# tensor(0.9976, grad_fn=<UnbindBackward0>)
# tensor(0.9976, grad_fn=<UnbindBackward0>)
# tensor(0.9976, grad_fn=<UnbindBackward0>)
# tensor(0.9977, grad_fn=<UnbindBackward0>)
# tensor(0.9977, grad_fn=<UnbindBackward0>)
# tensor(0.9978, grad_fn=<UnbindBackward0>)
# tensor(0.9978, grad_fn=<UnbindBackward0>)
# tensor(0.9978, grad_fn=<UnbindBackward0>)
# tensor(0.9979, grad_fn=<UnbindBackward0>)
# tensor(0.9979, grad_fn=<UnbindBackward0>)
# tensor(0.9979, grad_fn=<UnbindBackward0>)
# tensor(0.9979, grad_fn=<UnbindBackward0>)
# tensor(0.9979, grad_fn=<UnbindBackward0>)
# tensor(0.9979, grad_fn=<UnbindBackward0>)
# tensor(0.9979, grad_fn=<UnbindBackward0>)
# tensor(0.9979, grad_fn=<UnbindBackward0>)
# tensor(0.9979, grad_fn=<UnbindBackward0>)
# tensor(0.9980, grad_fn=<UnbindBackward0>)
# tensor(0.9980, grad_fn=<UnbindBackward0>)
# tensor(0.9980, grad_fn=<UnbindBackward0>)
# tensor(0.9980, grad_fn=<UnbindBackward0>)
# tensor(0.9980, grad_fn=<UnbindBackward0>)
# tensor(0.9980, grad_fn=<UnbindBackward0>)
# tensor(0.9981, grad_fn=<UnbindBackward0>)
# tensor(0.9981, grad_fn=<UnbindBackward0>)
# tensor(0.9981, grad_fn=<UnbindBackward0>)
# tensor(0.9981, grad_fn=<UnbindBackward0>)
# tensor(0.9981, grad_fn=<UnbindBackward0>)
# tensor(0.9981, grad_fn=<UnbindBackward0>)
# tensor(0.9982, grad_fn=<UnbindBackward0>)
# tensor(0.9982, grad_fn=<UnbindBackward0>)
# tensor(0.9982, grad_fn=<UnbindBackward0>)
# tensor(0.9982, grad_fn=<UnbindBackward0>)
# tensor(0.9982, grad_fn=<UnbindBackward0>)
# tensor(0.9983, grad_fn=<UnbindBackward0>)
# tensor(0.9983, grad_fn=<UnbindBackward0>)
# tensor(0.9983, grad_fn=<UnbindBackward0>)
# tensor(0.9983, grad_fn=<UnbindBackward0>)
# tensor(0.9983, grad_fn=<UnbindBackward0>)
# tensor(0.9983, grad_fn=<UnbindBackward0>)
# tensor(0.9983, grad_fn=<UnbindBackward0>)
# tensor(0.9984, grad_fn=<UnbindBackward0>)
# tensor(0.9984, grad_fn=<UnbindBackward0>)
# tensor(0.9984, grad_fn=<UnbindBackward0>)
# tensor(0.9984, grad_fn=<UnbindBackward0>)
# tensor(0.9984, grad_fn=<UnbindBackward0>)
# tensor(0.9984, grad_fn=<UnbindBackward0>)
# tensor(0.9984, grad_fn=<UnbindBackward0>)
# tensor(0.9984, grad_fn=<UnbindBackward0>)
# tensor(0.9984, grad_fn=<UnbindBackward0>)
# tensor(0.9984, grad_fn=<UnbindBackward0>)
# tensor(0.9984, grad_fn=<UnbindBackward0>)
# tensor(0.9985, grad_fn=<UnbindBackward0>)
# tensor(0.9985, grad_fn=<UnbindBackward0>)
# tensor(0.9985, grad_fn=<UnbindBackward0>)
# tensor(0.9985, grad_fn=<UnbindBackward0>)
# tensor(0.9986, grad_fn=<UnbindBackward0>)
# tensor(0.9986, grad_fn=<UnbindBackward0>)
# tensor(0.9986, grad_fn=<UnbindBackward0>)
# tensor(0.9986, grad_fn=<UnbindBackward0>)
# tensor(0.9986, grad_fn=<UnbindBackward0>)
# tensor(0.9986, grad_fn=<UnbindBackward0>)
# tensor(0.9986, grad_fn=<UnbindBackward0>)
# tensor(0.9987, grad_fn=<UnbindBackward0>)
# tensor(0.9987, grad_fn=<UnbindBackward0>)
# tensor(0.9987, grad_fn=<UnbindBackward0>)
# tensor(0.9987, grad_fn=<UnbindBackward0>)
# tensor(0.9988, grad_fn=<UnbindBackward0>)
# tensor(0.9988, grad_fn=<UnbindBackward0>)
# tensor(0.9988, grad_fn=<UnbindBackward0>)
# tensor(0.9988, grad_fn=<UnbindBackward0>)
# tensor(0.9988, grad_fn=<UnbindBackward0>)
# tensor(0.9988, grad_fn=<UnbindBackward0>)
# tensor(0.9988, grad_fn=<UnbindBackward0>)
# tensor(0.9989, grad_fn=<UnbindBackward0>)
# tensor(0.9989, grad_fn=<UnbindBackward0>)
# tensor(0.9989, grad_fn=<UnbindBackward0>)
# tensor(0.9989, grad_fn=<UnbindBackward0>)
# tensor(0.9990, grad_fn=<UnbindBackward0>)
# tensor(0.9990, grad_fn=<UnbindBackward0>)
# tensor(0.9991, grad_fn=<UnbindBackward0>)
# tensor(0.9991, grad_fn=<UnbindBackward0>)
# tensor(0.9991, grad_fn=<UnbindBackward0>)
# tensor(0.9991, grad_fn=<UnbindBackward0>)
# tensor(0.9991, grad_fn=<UnbindBackward0>)
# tensor(0.9992, grad_fn=<UnbindBackward0>)
# tensor(0.9992, grad_fn=<UnbindBackward0>)
# tensor(0.9992, grad_fn=<UnbindBackward0>)
# tensor(0.9992, grad_fn=<UnbindBackward0>)
# tensor(0.9992, grad_fn=<UnbindBackward0>)
# tensor(0.9992, grad_fn=<UnbindBackward0>)
# tensor(0.9992, grad_fn=<UnbindBackward0>)
# tensor(0.9992, grad_fn=<UnbindBackward0>)
# tensor(0.9992, grad_fn=<UnbindBackward0>)
# tensor(0.9992, grad_fn=<UnbindBackward0>)
# tensor(0.9992, grad_fn=<UnbindBackward0>)
# tensor(0.9993, grad_fn=<UnbindBackward0>)
# tensor(0.9993, grad_fn=<UnbindBackward0>)
# tensor(0.9994, grad_fn=<UnbindBackward0>)
# tensor(0.9994, grad_fn=<UnbindBackward0>)
# tensor(0.9994, grad_fn=<UnbindBackward0>)
# tensor(0.9995, grad_fn=<UnbindBackward0>)
# tensor(0.9995, grad_fn=<UnbindBackward0>)
# tensor(0.9995, grad_fn=<UnbindBackward0>)
# tensor(0.9995, grad_fn=<UnbindBackward0>)
# tensor(0.9995, grad_fn=<UnbindBackward0>)
# tensor(0.9995, grad_fn=<UnbindBackward0>)
# tensor(0.9995, grad_fn=<UnbindBackward0>)
# tensor(0.9995, grad_fn=<UnbindBackward0>)
# tensor(0.9995, grad_fn=<UnbindBackward0>)
# tensor(0.9996, grad_fn=<UnbindBackward0>)
# tensor(0.9996, grad_fn=<UnbindBackward0>)
# tensor(0.9996, grad_fn=<UnbindBackward0>)
# tensor(0.9996, grad_fn=<UnbindBackward0>)
# tensor(0.9997, grad_fn=<UnbindBackward0>)
# tensor(0.9997, grad_fn=<UnbindBackward0>)
# tensor(0.9997, grad_fn=<UnbindBackward0>)
# tensor(0.9997, grad_fn=<UnbindBackward0>)
